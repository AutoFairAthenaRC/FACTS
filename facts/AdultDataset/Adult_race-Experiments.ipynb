# %% [markdown]
# Datasets used:
# - `adult (Adult)` :<br>The UCI Adult dataset contains 14 features, which can be divided into two categories: demographic and income-related.<br> The demographic features include:
#
#     age: continuous.<br>
#     fnlwgt : continuous, represents final weight, which is the number of units in the target population that the responding unit represents.<br>
#     workclass: categorical, with values 'Private', 'Local-gov', 'Self-emp-not-inc', 'Federal-gov', 'State-gov', 'Self-emp-inc', 'Without-pay'.<br>
#     education: categorical, with values '11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th', ..., '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'.<br>
#     education-num: continuous with values 1 to 16, one number assigned to each label of education feature.<br>
#     marital-status: categorical, with values 'Never-married', 'Married-civ-spouse', 'Widowed', 'Separated', 'Divorced', 'Married-spouse-absent', 'Married-AF-spouse'.<br>
#     occupation: categorical, with values such as 'Machine-op-inspct', 'Farming-fishing', 'Protective-serv'.<br>
#     relationship: categorical, with values 'Own-child', 'Husband', 'Not-in-family', 'Unmarried', 'Wife', 'Other-relative'.<br>
#     race: categorical, with values such as white, black, and Asian.<br>
#     sex: categorical, with values male and female.<br>
#
#     The income-related features include:<br>
#
#     hours-per-week: continuous.<br>
#     native-country: categorical, with values such as United-States, Mexico, and Germany.<br>
#     capital-gain: continuous, represent the amount of money an individual has gained from the sale of investments such as stocks, bonds, or real estate.<br>
#     capital-loss: continuous, represent the amount of money an individual has lost from the sale of investments such as stocks, bonds, or real estate..<br>
#     The target feature is the income, which is binary:<br>
#     income: categorical, with values less than or equal to 50K and greater than 50K.<br>
#
# Reference Links: https://archive.ics.uci.edu/ml/datasets/adult

# %%
import pandas as pd
import numpy as np

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import facts
from facts.clean import clean_dataset
from facts import valid_ifthens_with_coverage_correctness, rules2rulesbyif
from facts.models import customLogisticRegression
from facts.parameters import ParameterProxy
from facts.formatting import recourse_report_reverse, print_recourse_report, print_recourse_report_cumulative, print_recourse_report_KStest_cumulative
from facts.utils import load_rules_by_if
from facts.fairness_metrics_aggr import get_diff_table, get_comb_df, get_analysis_dfs

# %%
cor_thres = 0.5
cost_budget = 10
top_count = 20
c_inf = 5

# %% [markdown]
# # Dataset

# %%
urlfile= "https://raw.githubusercontent.com/columbia/fairtest/master/data/adult/adult.csv"

X = pd.read_csv(urlfile)
df = clean_dataset(X, "adult")

age = [val.left for val in df.age.unique()]
age.sort()

df.head()
# Out:
#             age          Workclass  education-num       marital-status  \
# 0  (34.0, 41.0]          State-gov             13        Never-married
# 1  (41.0, 50.0]   Self-emp-not-inc             13   Married-civ-spouse
# 2  (34.0, 41.0]            Private              9             Divorced
# 3  (50.0, 90.0]            Private              7   Married-civ-spouse
# 4  (26.0, 34.0]            Private             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Married   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Married   Black     Male             0
# 4      Prof-specialty         Married   Black   Female             0
#
#    capital-loss hours-per-week  native-country  income
# 0             0       FullTime   United-States       0
# 1             0       PartTime   United-States       0
# 2             0       FullTime   United-States       0
# 3             0       FullTime   United-States       0
# 4             0       FullTime            Cuba       0

# %%
y = df['income']
X = df.drop('income', axis=1)

num_features = X._get_numeric_data().columns.to_list()
cate_features = X.select_dtypes(include=['object','category']).columns.to_list()
ord_features = ['hours-per-week']

# %% [markdown]
# # Rules

# %%
rules_with_atomic_correctness, Xtest, model = load_rules_by_if("rules-Xtest-model-2_race (seed 131313).data")
rules_with_cumulative_correctness = load_rules_by_if("rulesAdultFairTest_race_cumulative (seed 131313).data")

# %%
feature_weights = {"race" : 100 , "sex": 100, "marital-status": 5, "relationship":5, "age": 10, "occupation": 4, "Workclass": 2, "native-country": 4,
                    "hours-per-week":2, "capital-gain": 1, "capital-loss":1, "education-num": 3}
features_with_binary_cost = cate_features
features_with_proportional_cost = num_features


comparators = facts.feature_change_builder(
    X,
    num_cols=features_with_proportional_cost,
    cate_cols=features_with_binary_cost,
    ord_cols=ord_features,
    feature_weights=feature_weights,
    num_normalization=True,
    feats_to_normalize = ["capital-gain","capital-loss"]
)
params = ParameterProxy(featureChanges=comparators)

# %% [markdown]
# # Macro Viewpoint

# %% [markdown]
# ## Minimum Cost Above Threshold -- Equal Cost of Effectiveness (Macro)

# %%
top_rules, subgroup_costs = facts.select_rules_subset(
    rules_with_atomic_correctness,
    metric="min-above-thr",
    sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
    top_count=top_count,
    cor_threshold=cor_thres,
    filter_sequence = [
        # "remove-contained",
        # "remove-below-thr",        
        # "remove-fair-rules",
        # "keep-only-min-change"
    ],
    params=params
)

print_recourse_report(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True
)
# Out:
# If Workclass =  Private, age = (34.0, 41.0], capital-loss = 0, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 61.11%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 1.07% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.08%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.58%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.88%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 34.38%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.92%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.50%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.12%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.88%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.54%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.50%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.12%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.92%.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.92%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.92%.
# 		Aggregate cost of the above recourses = 22.00
# 	Bias against  White. Unfairness score = 12.0.
# If age = (26.0, 34.0], marital-status =  Never-married, relationship =  Not-in-family, sex =  Female:
# 	Protected Subgroup ' Non-White', 2.48% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.54%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.98%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.22%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 2.34% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.43%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.57%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.14%.
# 		Aggregate cost of the above recourses = 20.00
# 	Bias against  White. Unfairness score = 10.
# If age = (26.0, 34.0], capital-gain = 0, marital-status =  Never-married, relationship =  Not-in-family, sex =  Female:
# 	Protected Subgroup ' Non-White', 2.42% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.00%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.50%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 2.21% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.58%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.52%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 36.87%.
# 		Aggregate cost of the above recourses = 20.00
# 	Bias against  White. Unfairness score = 10.0.
# If age = (26.0, 34.0], capital-loss = 0, marital-status =  Never-married, relationship =  Not-in-family, sex =  Female:
# 	Protected Subgroup ' Non-White', 2.42% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.50%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.00%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 2.23% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 49.50%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.00%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 34.50%.
# 		Aggregate cost of the above recourses = 20.00
# 	Bias against  White. Unfairness score = 10.0.
# If age = (26.0, 34.0], marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family, sex =  Female:
# 	Protected Subgroup ' Non-White', 1.81% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.33%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.00%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.33%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 2.22% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.30%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.27%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 38.19%.
# 		Aggregate cost of the above recourses = 20.00
# 	Bias against  White. Unfairness score = 10.
# If age = (26.0, 34.0], capital-loss = 0, marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family, sex =  Female:
# 	Protected Subgroup ' Non-White', 1.75% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 62.07%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.62%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.72%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 2.11% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.73%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.32%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 35.45%.
# 		Aggregate cost of the above recourses = 20.00
# 	Bias against  White. Unfairness score = 10.0.
# If age = (26.0, 34.0], capital-gain = 0, marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family, sex =  Female:
# 	Protected Subgroup ' Non-White', 1.75% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 62.07%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.62%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.72%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 2.08% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 59.36%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.48%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.97%.
# 		Aggregate cost of the above recourses = 20.00
# 	Bias against  White. Unfairness score = 10.0.
# If age = (26.0, 34.0], capital-gain = 0, capital-loss = 0, marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family, sex =  Female:
# 	Protected Subgroup ' Non-White', 1.69% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.71%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.14%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 1.97% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.63%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.41%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 35.03%.
# 		Aggregate cost of the above recourses = 20.00
# 	Bias against  White. Unfairness score = 10.0.
# If Workclass =  Private, age = (34.0, 41.0], marital-status =  Divorced, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 1.69% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 28.57%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 32.14%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 32.14%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 64.29%.
# 		Make Workclass =  Self-emp-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Self-emp-not-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 21.43%.
# 		Make Workclass =  Self-emp-not-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 17.86%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.00%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 75.00%.
# 		Make Workclass =  Local-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.00%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 10.71%.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 67.86%.
# 		Make Workclass =  State-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.00%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 21.43%.
# 		Make Workclass =  State-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.00%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 64.29%.
# 		Aggregate cost of the above recourses = 12.00
# 	Protected Subgroup ' White', 1.41% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.01%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 23.62%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 28.35%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 28.35%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 48.82%.
# 		Make Workclass =  Self-emp-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.37%.
# 		Make Workclass =  Self-emp-not-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 11.81%.
# 		Make Workclass =  Self-emp-not-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 11.02%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.01%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 17.32%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.48%.
# 		Make Workclass =  Local-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 23.62%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 10.24%.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 48.82%.
# 		Make Workclass =  State-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 23.62%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 11.81%.
# 		Make Workclass =  State-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 14.96%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 48.82%.
# 		Aggregate cost of the above recourses = 22.00
# 	Bias against  White. Unfairness score = 10.
# If Workclass =  Private, age = (34.0, 41.0], capital-loss = 0, marital-status =  Never-married, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.63% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.85%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make Workclass =  Self-emp-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.85%.
# 		Make Workclass =  Self-emp-not-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 33.33%.
# 		Make Workclass =  Self-emp-not-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 33.33%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.85%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.04%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 66.67%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 33.33%.
# 		Make Workclass =  Local-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 40.74%.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 59.26%.
# 		Make Workclass =  State-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 40.74%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 33.33%.
# 		Aggregate cost of the above recourses = 12.00
# 	Protected Subgroup ' White', 2.08% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.45%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.71%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.32%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.32%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.48%.
# 		Make Workclass =  Self-emp-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 49.20%.
# 		Make Workclass =  Self-emp-not-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 28.88%.
# 		Make Workclass =  Self-emp-not-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 22.46%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.45%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 36.36%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 61.50%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 21.93%.
# 		Make Workclass =  Local-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 38.50%.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.75%.
# 		Make Workclass =  State-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 40.11%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 29.41%.
# 		Aggregate cost of the above recourses = 22.00
# 	Bias against  White. Unfairness score = 10.0.
# If age = (34.0, 41.0], capital-gain = 0, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.39% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make age = (41.0, 50.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.13%.
# 		Aggregate cost of the above recourses = 22.00
# 	Protected Subgroup ' White', 1.41% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.48%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.46%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.97%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.88%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.73%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.76%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.27%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.97%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.76%.
# 		Make age = (41.0, 50.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 33.07%.
# 		Aggregate cost of the above recourses = 12.00
# 	Bias against  Non-White. Unfairness score = 10.0.
# If age = (34.0, 41.0], capital-loss = 0, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.39% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make age = (41.0, 50.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.13%.
# 		Make age = (50.0, 90.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 34.78%.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 34.78%.
# 		Aggregate cost of the above recourses = 22.00
# 	Protected Subgroup ' White', 1.37% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 56.10%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.72%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.41%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.09%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.84%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.22%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 56.91%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.41%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.22%.
# 		Make age = (41.0, 50.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.89%.
# 		Make age = (50.0, 90.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 19.51%.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 17.89%.
# 		Aggregate cost of the above recourses = 12.00
# 	Bias against  Non-White. Unfairness score = 10.0.
# If Workclass =  Private, age = (34.0, 41.0], marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.39% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.83%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make Workclass =  Self-emp-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make Workclass =  Self-emp-not-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 34.78%.
# 		Make Workclass =  Self-emp-not-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 34.78%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.17%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.13%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 65.22%.
# 		Make Workclass =  Local-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.48%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 34.78%.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 56.52%.
# 		Make Workclass =  State-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.48%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 34.78%.
# 		Aggregate cost of the above recourses = 12.00
# 	Protected Subgroup ' White', 2.08% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 48.66%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.92%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.52%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.52%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 56.68%.
# 		Make Workclass =  Self-emp-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.41%.
# 		Make Workclass =  Self-emp-not-inc, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 26.20%.
# 		Make Workclass =  Self-emp-not-inc, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 32.09%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 48.66%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.57%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 64.17%.
# 		Make Workclass =  Local-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.25%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.67%.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.43%.
# 		Make Workclass =  State-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.85%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 32.62%.
# 		Aggregate cost of the above recourses = 22.00
# 	Bias against  White. Unfairness score = 10.
# If age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.63%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.37%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.37%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.37%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.63%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.37%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.63%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.37%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.63%.
# 		Make age = (41.0, 50.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 36.84%.
# 		Make age = (50.0, 90.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 31.58%.
# 		Aggregate cost of the above recourses = 22.00
# 	Protected Subgroup ' White', 1.39% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.00%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 48.80%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.40%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.20%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.20%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.00%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.80%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.40%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.20%.
# 		Make age = (41.0, 50.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 35.20%.
# 		Make age = (50.0, 90.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 24.00%.
# 		Aggregate cost of the above recourses = 12.00
# 	Bias against  Non-White. Unfairness score = 10.
# If age = (34.0, 41.0], capital-loss = 0, hours-per-week = FullTime, marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make age = (41.0, 50.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 33.33%.
# 		Make age = (50.0, 90.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 27.78%.
# 		Aggregate cost of the above recourses = 22.00
# 	Protected Subgroup ' White', 1.33% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.98%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.22%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.10%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.54%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.94%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.18%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.82%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.10%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.94%.
# 		Make age = (41.0, 50.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 31.93%.
# 		Make age = (50.0, 90.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 20.17%.
# 		Aggregate cost of the above recourses = 12.00
# 	Bias against  Non-White. Unfairness score = 10.0.
# If age = (34.0, 41.0], capital-gain = 0, hours-per-week = FullTime, marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make age = (41.0, 50.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 33.33%.
# 		Aggregate cost of the above recourses = 22.00
# 	Protected Subgroup ' White', 1.37% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 59.35%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.97%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.66%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.34%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.09%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.47%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.16%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.66%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.47%.
# 		Make age = (41.0, 50.0], hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 34.15%.
# 		Aggregate cost of the above recourses = 12.00
# 	Bias against  Non-White. Unfairness score = 10.0.
# If age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 72.22%.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 61.11%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make occupation =  Prof-specialty with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 55.56%.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 50.00%.
# 		Make occupation =  Sales with effectiveness 22.22%.
# 		Make age = (41.0, 50.0] with effectiveness 22.22%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 22.22%.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 22.22%.
# 		Make age = (50.0, 90.0] with effectiveness 5.56%.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 22.22%.
# 		Make occupation =  Adm-clerical with effectiveness 5.56%.
# 		Make occupation =  Tech-support with effectiveness 44.44%.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 61.11%.
# 		Make age = (41.0, 50.0], occupation =  Transport-moving with effectiveness 5.56%.
# 		Make age = (41.0, 50.0], occupation =  Protective-serv with effectiveness 55.56%.
# 		Aggregate cost of the above recourses = 4.00
# 	Protected Subgroup ' White', 1.93% covered
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 68.21%.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 45.09%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 48.55%.
# 		Make occupation =  Exec-managerial with effectiveness 46.24%.
# 		Make occupation =  Prof-specialty with effectiveness 30.06%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 30.06%.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 30.06%.
# 		Make occupation =  Sales with effectiveness 11.56%.
# 		Make age = (41.0, 50.0] with effectiveness 9.83%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 16.18%.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 15.03%.
# 		Make age = (50.0, 90.0] with effectiveness 0.58%.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 2.31%.
# 		Make occupation =  Adm-clerical with effectiveness 0.58%.
# 		Make occupation =  Tech-support with effectiveness 30.06%.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 47.98%.
# 		Make age = (41.0, 50.0], occupation =  Transport-moving with effectiveness 0.58%.
# 		Make age = (41.0, 50.0], occupation =  Protective-serv with effectiveness 39.88%.
# 		Aggregate cost of the above recourses = 14.00
# 	Bias against  White. Unfairness score = 10.
# If age = (34.0, 41.0], capital-loss = 0, marital-status =  Married-civ-spouse, occupation =  Craft-repair:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 72.22%.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 61.11%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make occupation =  Prof-specialty with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 55.56%.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 50.00%.
# 		Make occupation =  Sales with effectiveness 22.22%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 22.22%.
# 		Make age = (41.0, 50.0] with effectiveness 22.22%.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 22.22%.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 22.22%.
# 		Make occupation =  Adm-clerical with effectiveness 5.56%.
# 		Make age = (50.0, 90.0] with effectiveness 5.56%.
# 		Make occupation =  Tech-support with effectiveness 44.44%.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 61.11%.
# 		Aggregate cost of the above recourses = 4.00
# 	Protected Subgroup ' White', 1.89% covered
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 68.24%.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 44.71%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 48.24%.
# 		Make occupation =  Exec-managerial with effectiveness 45.88%.
# 		Make occupation =  Prof-specialty with effectiveness 29.41%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 29.41%.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 29.41%.
# 		Make occupation =  Sales with effectiveness 11.76%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 15.88%.
# 		Make age = (41.0, 50.0] with effectiveness 10.00%.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 15.29%.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 2.35%.
# 		Make occupation =  Adm-clerical with effectiveness 0.59%.
# 		Make age = (50.0, 90.0] with effectiveness 0.59%.
# 		Make occupation =  Tech-support with effectiveness 29.41%.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 47.65%.
# 		Aggregate cost of the above recourses = 14.00
# 	Bias against  White. Unfairness score = 10.0.
# If age = (34.0, 41.0], capital-gain = 0, marital-status =  Married-civ-spouse, occupation =  Craft-repair:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 72.22%.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 61.11%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make occupation =  Prof-specialty with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 55.56%.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 50.00%.
# 		Make occupation =  Sales with effectiveness 22.22%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 22.22%.
# 		Make age = (41.0, 50.0] with effectiveness 22.22%.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 22.22%.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 61.11%.
# 		Make occupation =  Tech-support with effectiveness 44.44%.
# 		Aggregate cost of the above recourses = 4.00
# 	Protected Subgroup ' White', 1.92% covered
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 68.60%.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 45.35%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 48.84%.
# 		Make occupation =  Exec-managerial with effectiveness 46.51%.
# 		Make occupation =  Prof-specialty with effectiveness 30.23%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 30.23%.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 30.23%.
# 		Make occupation =  Sales with effectiveness 11.63%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 16.28%.
# 		Make age = (41.0, 50.0] with effectiveness 9.88%.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 15.12%.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 48.26%.
# 		Make occupation =  Tech-support with effectiveness 30.23%.
# 		Aggregate cost of the above recourses = 14.00
# 	Bias against  White. Unfairness score = 10.0.
# If age = (34.0, 41.0], capital-gain = 0, capital-loss = 0, marital-status =  Married-civ-spouse, occupation =  Craft-repair:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 72.22%.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 61.11%.
# 		Make occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make occupation =  Prof-specialty with effectiveness 44.44%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 55.56%.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 50.00%.
# 		Make occupation =  Sales with effectiveness 22.22%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 22.22%.
# 		Make age = (41.0, 50.0] with effectiveness 22.22%.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 22.22%.
# 		Aggregate cost of the above recourses = 4.00
# 	Protected Subgroup ' White', 1.88% covered
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 68.64%.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 44.97%.
# 		Make occupation =  Exec-managerial with effectiveness 46.15%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 48.52%.
# 		Make occupation =  Prof-specialty with effectiveness 29.59%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 29.59%.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 29.59%.
# 		Make occupation =  Sales with effectiveness 11.83%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 15.98%.
# 		Make age = (41.0, 50.0] with effectiveness 10.06%.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 15.38%.
# 		Aggregate cost of the above recourses = 14.00
# 	Bias against  White. Unfairness score = 10.0.

# %% [markdown]
# ## Number of Rules Above Threshold -- Equal Choice for Recourse

# %%
top_rules, subgroup_costs = facts.select_rules_subset(
    rules_with_atomic_correctness,
    metric="num-above-thr",
    sort_strategy="generic-sorting-ignore-forall-subgroups-empty",
    top_count=top_count,
    cor_threshold=cor_thres,
    filter_sequence = [
        # "remove-contained",
        # "remove-below-thr",
        # "remove-fair-rules"
    ],
    params=params
)

print_recourse_report(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True
)
# Out:
# If Workclass =  Private, hours-per-week = OverTime, marital-status =  Never-married, relationship =  Not-in-family, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 61.11%.
# 		Make hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 61.11%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 61.11%.
# 		Make Workclass =  Local-gov, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Federal-gov, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 61.11%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Self-emp-inc, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 61.11%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make Workclass =  Self-emp-inc, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make Workclass =  Self-emp-not-inc, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Self-emp-not-inc, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 27.78%.
# 		Make Workclass =  State-gov, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.44%.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 27.78%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Aggregate cost of the above recourses = -12.00
# 	Protected Subgroup ' White', 2.27% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 35.78%.
# 		Make hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 27.45%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 35.78%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.71%.
# 		Make Workclass =  Local-gov, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 22.55%.
# 		Make Workclass =  Federal-gov, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 36.27%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 22.55%.
# 		Make Workclass =  Self-emp-inc, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.71%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 31.37%.
# 		Make Workclass =  Self-emp-inc, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 31.37%.
# 		Make Workclass =  Self-emp-not-inc, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 23.04%.
# 		Make Workclass =  Self-emp-not-inc, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 11.27%.
# 		Make Workclass =  State-gov, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 16.67%.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 12.75%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 29.90%.
# 		Aggregate cost of the above recourses = 0.00
# 	Bias against  White. Unfairness score = 12.
# If Workclass =  Private, marital-status =  Never-married, occupation =  Sales, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 50.00%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 50.00%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.83%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 41.67%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 54.17%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 50.00%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 41.67%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 41.67%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 41.67%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 41.67%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving, relationship =  Married with effectiveness 29.17%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 29.17%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Protective-serv, relationship =  Married with effectiveness 41.67%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 58.33%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 54.17%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 50.00%.
# 		Aggregate cost of the above recourses = -12.00
# 	Protected Subgroup ' White', 1.98% covered
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 38.20%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 30.90%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 26.97%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 16.85%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 46.07%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 30.34%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 19.10%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 16.85%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 30.90%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 23.60%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.90%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 22.47%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving, relationship =  Married with effectiveness 14.61%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 38.20%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 33.15%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 8.99%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 30.90%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Protective-serv, relationship =  Married with effectiveness 23.60%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 53.93%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 46.07%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 30.90%.
# 		Aggregate cost of the above recourses = -1.00
# 	Bias against  White. Unfairness score = 11.
# If Workclass =  Private, marital-status =  Never-married, native-country =  United-States, occupation =  Sales, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 52.63%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.63%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.37%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 42.11%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 52.63%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.63%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 42.11%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 42.11%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 52.63%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 42.11%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.63%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 42.11%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving, relationship =  Married with effectiveness 31.58%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 52.63%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.63%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 31.58%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 52.63%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 57.89%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Protective-serv, relationship =  Married with effectiveness 42.11%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.63%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 52.63%.
# 		Aggregate cost of the above recourses = -12.00
# 	Protected Subgroup ' White', 1.94% covered
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 37.93%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 30.46%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 26.44%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 17.24%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 45.40%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 29.89%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 18.97%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 17.24%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 30.46%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 23.56%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.46%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 22.41%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving, relationship =  Married with effectiveness 14.94%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 32.76%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 37.93%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 9.20%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 30.46%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 52.87%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Protective-serv, relationship =  Married with effectiveness 23.56%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 45.40%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 30.46%.
# 		Aggregate cost of the above recourses = -1.00
# 	Bias against  White. Unfairness score = 11.
# If Workclass =  Private, occupation =  Other-service, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 2.18% covered
# 		Make occupation =  Exec-managerial with effectiveness 52.78%.
# 		Make occupation =  Prof-specialty with effectiveness 50.00%.
# 		Make occupation =  Sales with effectiveness 22.22%.
# 		Make occupation =  Craft-repair with effectiveness 13.89%.
# 		Make Workclass =  Self-emp-inc, occupation =  Exec-managerial with effectiveness 58.33%.
# 		Make Workclass =  Local-gov, occupation =  Prof-specialty with effectiveness 33.33%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Prof-specialty with effectiveness 13.89%.
# 		Make occupation =  Tech-support with effectiveness 50.00%.
# 		Make occupation =  Adm-clerical with effectiveness 13.89%.
# 		Make Workclass =  State-gov, occupation =  Prof-specialty with effectiveness 19.44%.
# 		Make Workclass =  Self-emp-inc, occupation =  Sales with effectiveness 50.00%.
# 		Make occupation =  Transport-moving with effectiveness 8.33%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Exec-managerial with effectiveness 13.89%.
# 		Make Workclass =  Local-gov, occupation =  Exec-managerial with effectiveness 52.78%.
# 		Make Workclass =  Self-emp-inc, occupation =  Prof-specialty with effectiveness 52.78%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Sales with effectiveness 8.33%.
# 		Make Workclass =  Local-gov, occupation =  Protective-serv with effectiveness 19.44%.
# 		Make Workclass =  Federal-gov, occupation =  Adm-clerical with effectiveness 52.78%.
# 		Make Workclass =  Federal-gov, occupation =  Exec-managerial with effectiveness 63.89%.
# 		Make Workclass =  Federal-gov, occupation =  Prof-specialty with effectiveness 58.33%.
# 		Aggregate cost of the above recourses = -10.00
# 	Protected Subgroup ' White', 1.30% covered
# 		Make occupation =  Exec-managerial with effectiveness 28.21%.
# 		Make occupation =  Prof-specialty with effectiveness 15.38%.
# 		Make occupation =  Sales with effectiveness 12.82%.
# 		Make occupation =  Craft-repair with effectiveness 8.55%.
# 		Make Workclass =  Self-emp-inc, occupation =  Exec-managerial with effectiveness 40.17%.
# 		Make Workclass =  Local-gov, occupation =  Prof-specialty with effectiveness 12.82%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Prof-specialty with effectiveness 8.55%.
# 		Make occupation =  Tech-support with effectiveness 15.38%.
# 		Make occupation =  Adm-clerical with effectiveness 8.55%.
# 		Make Workclass =  State-gov, occupation =  Prof-specialty with effectiveness 10.26%.
# 		Make Workclass =  Self-emp-inc, occupation =  Sales with effectiveness 17.95%.
# 		Make occupation =  Transport-moving with effectiveness 6.84%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Exec-managerial with effectiveness 9.40%.
# 		Make Workclass =  Local-gov, occupation =  Exec-managerial with effectiveness 20.51%.
# 		Make Workclass =  Self-emp-inc, occupation =  Prof-specialty with effectiveness 28.21%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Sales with effectiveness 6.84%.
# 		Make Workclass =  Local-gov, occupation =  Protective-serv with effectiveness 11.97%.
# 		Make Workclass =  Federal-gov, occupation =  Adm-clerical with effectiveness 17.95%.
# 		Make Workclass =  Federal-gov, occupation =  Exec-managerial with effectiveness 45.30%.
# 		Make Workclass =  Federal-gov, occupation =  Prof-specialty with effectiveness 40.17%.
# 		Aggregate cost of the above recourses = 0.00
# 	Bias against  White. Unfairness score = 10.
# If Workclass =  Private, marital-status =  Married-civ-spouse, occupation =  Other-service, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 2.18% covered
# 		Make occupation =  Exec-managerial with effectiveness 52.78%.
# 		Make occupation =  Prof-specialty with effectiveness 50.00%.
# 		Make occupation =  Sales with effectiveness 22.22%.
# 		Make occupation =  Craft-repair with effectiveness 13.89%.
# 		Make Workclass =  Self-emp-inc, occupation =  Exec-managerial with effectiveness 58.33%.
# 		Make Workclass =  Local-gov, occupation =  Prof-specialty with effectiveness 33.33%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Prof-specialty with effectiveness 13.89%.
# 		Make occupation =  Tech-support with effectiveness 50.00%.
# 		Make occupation =  Adm-clerical with effectiveness 13.89%.
# 		Make Workclass =  State-gov, occupation =  Prof-specialty with effectiveness 19.44%.
# 		Make Workclass =  Self-emp-inc, occupation =  Sales with effectiveness 50.00%.
# 		Make occupation =  Transport-moving with effectiveness 8.33%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Exec-managerial with effectiveness 13.89%.
# 		Make Workclass =  Local-gov, occupation =  Exec-managerial with effectiveness 52.78%.
# 		Make Workclass =  Self-emp-inc, occupation =  Prof-specialty with effectiveness 52.78%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Sales with effectiveness 8.33%.
# 		Make Workclass =  Local-gov, occupation =  Protective-serv with effectiveness 19.44%.
# 		Make Workclass =  Federal-gov, occupation =  Adm-clerical with effectiveness 52.78%.
# 		Make Workclass =  Federal-gov, occupation =  Exec-managerial with effectiveness 63.89%.
# 		Make Workclass =  Federal-gov, occupation =  Prof-specialty with effectiveness 58.33%.
# 		Aggregate cost of the above recourses = -10.00
# 	Protected Subgroup ' White', 1.30% covered
# 		Make occupation =  Exec-managerial with effectiveness 28.21%.
# 		Make occupation =  Prof-specialty with effectiveness 15.38%.
# 		Make occupation =  Sales with effectiveness 12.82%.
# 		Make occupation =  Craft-repair with effectiveness 8.55%.
# 		Make Workclass =  Self-emp-inc, occupation =  Exec-managerial with effectiveness 40.17%.
# 		Make Workclass =  Local-gov, occupation =  Prof-specialty with effectiveness 12.82%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Prof-specialty with effectiveness 8.55%.
# 		Make occupation =  Tech-support with effectiveness 15.38%.
# 		Make occupation =  Adm-clerical with effectiveness 8.55%.
# 		Make Workclass =  State-gov, occupation =  Prof-specialty with effectiveness 10.26%.
# 		Make Workclass =  Self-emp-inc, occupation =  Sales with effectiveness 17.95%.
# 		Make occupation =  Transport-moving with effectiveness 6.84%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Exec-managerial with effectiveness 9.40%.
# 		Make Workclass =  Local-gov, occupation =  Exec-managerial with effectiveness 20.51%.
# 		Make Workclass =  Self-emp-inc, occupation =  Prof-specialty with effectiveness 28.21%.
# 		Make Workclass =  Self-emp-not-inc, occupation =  Sales with effectiveness 6.84%.
# 		Make Workclass =  Local-gov, occupation =  Protective-serv with effectiveness 11.97%.
# 		Make Workclass =  Federal-gov, occupation =  Adm-clerical with effectiveness 17.95%.
# 		Make Workclass =  Federal-gov, occupation =  Exec-managerial with effectiveness 45.30%.
# 		Make Workclass =  Federal-gov, occupation =  Prof-specialty with effectiveness 40.17%.
# 		Aggregate cost of the above recourses = 0.00
# 	Bias against  White. Unfairness score = 10.
# If Workclass =  Private, marital-status =  Never-married, occupation =  Adm-clerical, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.69% covered
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 50.00%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 50.00%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 46.43%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 32.14%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 53.57%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 46.43%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.29%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 28.57%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 42.86%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 39.29%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving, relationship =  Married with effectiveness 28.57%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 25.00%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Protective-serv, relationship =  Married with effectiveness 42.86%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 64.29%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 53.57%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 46.43%.
# 		Aggregate cost of the above recourses = -10.00
# 	Protected Subgroup ' White', 2.32% covered
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 30.29%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 24.04%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 15.38%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 11.06%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 39.42%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 21.63%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 12.02%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 11.06%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 24.04%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 13.46%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 24.52%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 13.46%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving, relationship =  Married with effectiveness 9.13%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 30.29%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 25.96%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 5.77%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.96%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Protective-serv, relationship =  Married with effectiveness 13.94%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 49.04%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 39.42%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 23.56%.
# 		Aggregate cost of the above recourses = 0.00
# 	Bias against  White. Unfairness score = 10.
# If capital-loss = 0, hours-per-week = FullTime, marital-status =  Married-civ-spouse, occupation =  Other-service, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.51% covered
# 		Make hours-per-week = OverTime, occupation =  Exec-managerial with effectiveness 64.00%.
# 		Make hours-per-week = OverTime, occupation =  Prof-specialty with effectiveness 56.00%.
# 		Make occupation =  Exec-managerial with effectiveness 56.00%.
# 		Make occupation =  Prof-specialty with effectiveness 52.00%.
# 		Make hours-per-week = OverTime, occupation =  Sales with effectiveness 56.00%.
# 		Make hours-per-week = BrainDrain, occupation =  Exec-managerial with effectiveness 68.00%.
# 		Make occupation =  Sales with effectiveness 8.00%.
# 		Make hours-per-week = BrainDrain, occupation =  Prof-specialty with effectiveness 56.00%.
# 		Make hours-per-week = OverTime, occupation =  Craft-repair with effectiveness 28.00%.
# 		Make occupation =  Craft-repair with effectiveness 0.00%.
# 		Make hours-per-week = BrainDrain, occupation =  Sales with effectiveness 56.00%.
# 		Make occupation =  Adm-clerical with effectiveness 0.00%.
# 		Make occupation =  Tech-support with effectiveness 52.00%.
# 		Make hours-per-week = MidTime, occupation =  Prof-specialty with effectiveness 0.00%.
# 		Make hours-per-week = OverTime, occupation =  Adm-clerical with effectiveness 52.00%.
# 		Aggregate cost of the above recourses = -10.00
# 	Protected Subgroup ' White', 1.08% covered
# 		Make hours-per-week = OverTime, occupation =  Exec-managerial with effectiveness 49.48%.
# 		Make hours-per-week = OverTime, occupation =  Prof-specialty with effectiveness 37.11%.
# 		Make occupation =  Exec-managerial with effectiveness 26.80%.
# 		Make occupation =  Prof-specialty with effectiveness 16.49%.
# 		Make hours-per-week = OverTime, occupation =  Sales with effectiveness 26.80%.
# 		Make hours-per-week = BrainDrain, occupation =  Exec-managerial with effectiveness 49.48%.
# 		Make occupation =  Sales with effectiveness 13.40%.
# 		Make hours-per-week = BrainDrain, occupation =  Prof-specialty with effectiveness 37.11%.
# 		Make hours-per-week = OverTime, occupation =  Craft-repair with effectiveness 15.46%.
# 		Make occupation =  Craft-repair with effectiveness 8.25%.
# 		Make hours-per-week = BrainDrain, occupation =  Sales with effectiveness 26.80%.
# 		Make occupation =  Adm-clerical with effectiveness 9.28%.
# 		Make occupation =  Tech-support with effectiveness 17.53%.
# 		Make hours-per-week = MidTime, occupation =  Prof-specialty with effectiveness 8.25%.
# 		Make hours-per-week = OverTime, occupation =  Adm-clerical with effectiveness 16.49%.
# 		Aggregate cost of the above recourses = 0.00
# 	Bias against  White. Unfairness score = 10.
# If capital-loss = 0, hours-per-week = FullTime, marital-status =  Never-married, occupation =  Adm-clerical, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.27% covered
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 66.67%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.38%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 52.38%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 66.67%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 47.62%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.38%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.86%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 47.62%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 28.57%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 38.10%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.38%.
# 		Aggregate cost of the above recourses = -10.00
# 	Protected Subgroup ' White', 1.58% covered
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 44.37%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 38.73%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 32.39%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 25.35%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 31.69%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 44.37%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 16.20%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 38.73%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 11.97%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 24.65%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 10.56%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 32.39%.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 10.56%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 25.35%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.35%.
# 		Aggregate cost of the above recourses = 0.00
# 	Bias against  White. Unfairness score = 10.
# If hours-per-week = FullTime, marital-status =  Never-married, occupation =  Adm-clerical, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.27% covered
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 66.67%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.38%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 52.38%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 66.67%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 47.62%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 28.57%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.38%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.86%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 47.62%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 38.10%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.38%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Protective-serv, relationship =  Married with effectiveness 47.62%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving, relationship =  Married with effectiveness 23.81%.
# 		Aggregate cost of the above recourses = -10.00
# 	Protected Subgroup ' White', 1.60% covered
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 45.14%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 39.58%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 31.94%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 25.00%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 31.25%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 45.14%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 15.97%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 10.42%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 39.58%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 11.81%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 24.31%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 31.94%.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 10.42%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 25.00%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.00%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Protective-serv, relationship =  Married with effectiveness 24.31%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving, relationship =  Married with effectiveness 9.03%.
# 		Aggregate cost of the above recourses = 0.00
# 	Bias against  White. Unfairness score = 10.
# If Workclass =  Private, age = (34.0, 41.0], capital-loss = 0, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 61.11%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 50.00%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.56%.
# 		Aggregate cost of the above recourses = -14.00
# 	Protected Subgroup ' White', 1.07% covered
# 		Make age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 52.08%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.58%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.88%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 34.38%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.92%.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.50%.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.12%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.88%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.54%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.50%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.12%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.92%.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.92%.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.92%.
# 		Aggregate cost of the above recourses = -4.00
# 	Bias against  White. Unfairness score = 10.
# If Workclass =  Private, marital-status =  Never-married, native-country =  United-States, occupation =  Adm-clerical, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.03% covered
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 52.94%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.94%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 47.06%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 41.18%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 58.82%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 47.06%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.06%.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 35.29%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 52.94%.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 47.06%.
# ...
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 52.38%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 66.67%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 47.62%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.38%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.86%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 52.38%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 47.62%.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 38.10%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 52.38%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 28.57%.
# 		Aggregate cost of the above recourses = -9.00
# 	Protected Subgroup ' White', 1.51% covered
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 42.65%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 36.76%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 28.68%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 23.53%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 27.94%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 42.65%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 14.71%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 36.76%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 10.29%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 28.68%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 22.79%.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 8.82%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 23.53%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 8.82%.
# 		Aggregate cost of the above recourses = 0.00
# 	Bias against  White. Unfairness score = 9.
# If age = (41.0, 50.0], capital-loss = 0, hours-per-week = FullTime, occupation =  Craft-repair:
# 	Protected Subgroup ' Non-White', 1.21% covered
# 		Make hours-per-week = OverTime, occupation =  Exec-managerial with effectiveness 45.00%.
# 		Make hours-per-week = OverTime, occupation =  Prof-specialty with effectiveness 40.00%.
# 		Make occupation =  Exec-managerial with effectiveness 40.00%.
# 		Make occupation =  Prof-specialty with effectiveness 35.00%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 35.00%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Exec-managerial with effectiveness 40.00%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Prof-specialty with effectiveness 40.00%.
# 		Make hours-per-week = OverTime, occupation =  Sales with effectiveness 40.00%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 30.00%.
# 		Make hours-per-week = BrainDrain, occupation =  Exec-managerial with effectiveness 50.00%.
# 		Make hours-per-week = OverTime with effectiveness 35.00%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Sales with effectiveness 35.00%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, occupation =  Exec-managerial with effectiveness 40.00%.
# 		Make occupation =  Adm-clerical with effectiveness 5.00%.
# 		Make hours-per-week = BrainDrain, occupation =  Prof-specialty with effectiveness 40.00%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 10.00%.
# 		Make hours-per-week = BrainDrain, occupation =  Sales with effectiveness 40.00%.
# 		Aggregate cost of the above recourses = -1.00
# 	Protected Subgroup ' White', 1.95% covered
# 		Make hours-per-week = OverTime, occupation =  Exec-managerial with effectiveness 60.00%.
# 		Make hours-per-week = OverTime, occupation =  Prof-specialty with effectiveness 56.00%.
# 		Make occupation =  Exec-managerial with effectiveness 52.00%.
# 		Make occupation =  Prof-specialty with effectiveness 19.43%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 20.57%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Exec-managerial with effectiveness 58.86%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Prof-specialty with effectiveness 52.00%.
# 		Make hours-per-week = OverTime, occupation =  Sales with effectiveness 51.43%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 6.86%.
# 		Make hours-per-week = BrainDrain, occupation =  Exec-managerial with effectiveness 60.00%.
# 		Make hours-per-week = OverTime with effectiveness 18.86%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Sales with effectiveness 20.57%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, occupation =  Exec-managerial with effectiveness 59.43%.
# 		Make occupation =  Adm-clerical with effectiveness 5.71%.
# 		Make hours-per-week = BrainDrain, occupation =  Prof-specialty with effectiveness 58.86%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 5.71%.
# 		Make hours-per-week = BrainDrain, occupation =  Sales with effectiveness 52.00%.
# 		Aggregate cost of the above recourses = -10.00
# 	Bias against  Non-White. Unfairness score = 9.
# If age = (41.0, 50.0], hours-per-week = FullTime, occupation =  Craft-repair:
# 	Protected Subgroup ' Non-White', 1.21% covered
# 		Make hours-per-week = OverTime, occupation =  Exec-managerial with effectiveness 45.00%.
# 		Make hours-per-week = OverTime, occupation =  Prof-specialty with effectiveness 40.00%.
# 		Make occupation =  Exec-managerial with effectiveness 40.00%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 35.00%.
# 		Make occupation =  Prof-specialty with effectiveness 35.00%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Exec-managerial with effectiveness 40.00%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Prof-specialty with effectiveness 40.00%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 30.00%.
# 		Make hours-per-week = OverTime, occupation =  Sales with effectiveness 40.00%.
# 		Make hours-per-week = BrainDrain, occupation =  Exec-managerial with effectiveness 50.00%.
# 		Make hours-per-week = OverTime with effectiveness 35.00%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, occupation =  Exec-managerial with effectiveness 40.00%.
# 		Make occupation =  Adm-clerical with effectiveness 5.00%.
# 		Make hours-per-week = BrainDrain, occupation =  Prof-specialty with effectiveness 40.00%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Sales with effectiveness 35.00%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 10.00%.
# 		Make hours-per-week = BrainDrain, occupation =  Sales with effectiveness 40.00%.
# 		Make occupation =  Sales with effectiveness 30.00%.
# 		Make age = (50.0, 90.0] with effectiveness 0.00%.
# 		Aggregate cost of the above recourses = -1.00
# 	Protected Subgroup ' White', 1.97% covered
# 		Make hours-per-week = OverTime, occupation =  Exec-managerial with effectiveness 59.32%.
# 		Make hours-per-week = OverTime, occupation =  Prof-specialty with effectiveness 55.37%.
# 		Make occupation =  Exec-managerial with effectiveness 51.41%.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 20.34%.
# 		Make occupation =  Prof-specialty with effectiveness 19.21%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Exec-managerial with effectiveness 58.19%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Prof-specialty with effectiveness 51.41%.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 6.78%.
# 		Make hours-per-week = OverTime, occupation =  Sales with effectiveness 50.85%.
# 		Make hours-per-week = BrainDrain, occupation =  Exec-managerial with effectiveness 59.32%.
# 		Make hours-per-week = OverTime with effectiveness 18.64%.
# 		Make age = (50.0, 90.0], hours-per-week = BrainDrain, occupation =  Exec-managerial with effectiveness 58.76%.
# 		Make occupation =  Adm-clerical with effectiveness 5.65%.
# 		Make hours-per-week = BrainDrain, occupation =  Prof-specialty with effectiveness 58.19%.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime, occupation =  Sales with effectiveness 20.34%.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 5.65%.
# 		Make hours-per-week = BrainDrain, occupation =  Sales with effectiveness 51.41%.
# 		Make occupation =  Sales with effectiveness 6.78%.
# 		Make age = (50.0, 90.0] with effectiveness 0.00%.
# 		Aggregate cost of the above recourses = -10.00
# 	Bias against  Non-White. Unfairness score = 9.
# If Workclass =  Private, hours-per-week = FullTime, marital-status =  Never-married, occupation =  Prof-specialty:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 55.56%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 38.89%.
# 		Make marital-status =  Married-civ-spouse with effectiveness 38.89%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 38.89%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 27.78%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 16.67%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 33.33%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 38.89%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 16.67%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse with effectiveness 33.33%.
# 		Make Workclass =  Self-emp-inc, hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 66.67%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support with effectiveness 38.89%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 61.11%.
# 		Make Workclass =  Self-emp-inc, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 66.67%.
# 		Make Workclass =  Local-gov, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 44.44%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 61.11%.
# 		Make Workclass =  Self-emp-inc, hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 61.11%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 66.67%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 38.89%.
# 		Make Workclass =  Self-emp-not-inc, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 33.33%.
# 		Aggregate cost of the above recourses = -9.00
# 	Protected Subgroup ' White', 1.45% covered
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 30.00%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 26.92%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 23.85%.
# 		Make marital-status =  Married-civ-spouse with effectiveness 16.15%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 23.85%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 10.77%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 5.38%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 30.00%.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 11.54%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 23.85%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 6.15%.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse with effectiveness 11.54%.
# 		Make Workclass =  Self-emp-inc, hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 44.62%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support with effectiveness 16.15%.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 26.92%.
# 		Make Workclass =  Self-emp-inc, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 44.62%.
# 		Make Workclass =  Local-gov, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 25.38%.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 27.69%.
# 		Make Workclass =  Self-emp-inc, hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 26.92%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 36.92%.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 20.00%.
# 		Make Workclass =  Self-emp-not-inc, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 11.54%.
# 		Aggregate cost of the above recourses = 0.00
# 	Bias against  White. Unfairness score = 9.

# %% [markdown]
# # New Metrics

# %% [markdown]
# ## Fairness of Mean Recourse Cost ($c_\infty$ implementation) -- Equal Mean Recourse

# %%
top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
    rules_with_cumulative_correctness,
    metric="fairness-of-mean-recourse-cinf",
    c_inf=c_inf,
    sort_strategy="generic-sorting",
    top_count=top_count,
    filter_sequence = [
        # "remove-contained",
        # "remove-fair-rules"
    ],
    params=params
)

print_recourse_report_cumulative(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    show_then_costs=True
)
# Out:
# If capital-gain = 0, capital-loss = 0, education-num = 10, marital-status =  Divorced, native-country =  United-States, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 1.81% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.33% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 66.67% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 76.67% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 17.10
# 	Protected Subgroup ' White', 1.31% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 14.41% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 22.88% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.37% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 101.60
# 	Bias against  White. Unfairness score = 84.502.
# If capital-gain = 0, capital-loss = 0, education-num = 13, marital-status =  Never-married, occupation =  Prof-specialty, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.27% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 85.71% and counterfactual cost = 11.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 85.71% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 85.71% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 85.71% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 85.71% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 95.24% and counterfactual cost = 12.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 95.24% and counterfactual cost = 31.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 100.00% and counterfactual cost = 32.0.
# 		Make education-num = 15, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 12.10
# 	Protected Subgroup ' White', 1.46% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 56.49% and counterfactual cost = 11.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 56.49% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 56.49% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 56.49% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 56.49% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 59.54% and counterfactual cost = 12.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 59.54% and counterfactual cost = 31.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 66.41% and counterfactual cost = 32.0.
# 		Make education-num = 15, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 67.18% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 92.87
# 	Bias against  White. Unfairness score = 80.775.
# If capital-gain = 0, education-num = 10, marital-status =  Divorced, native-country =  United-States, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 1.81% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.33% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 66.67% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 76.67% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 17.10
# 	Protected Subgroup ' White', 1.37% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 16.26% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.20% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.90% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 97.65
# 	Bias against  White. Unfairness score = 80.546.
# If capital-gain = 0, capital-loss = 0, education-num = 10, marital-status =  Divorced, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 1.94% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.75% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 65.62% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 75.00% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 16.38
# 	Protected Subgroup ' White', 1.37% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 14.63% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 23.58% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.09% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 95.71
# 	Bias against  White. Unfairness score = 79.33.
# If capital-gain = 0, education-num = 13, marital-status =  Never-married, occupation =  Prof-specialty, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.27% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 85.71% and counterfactual cost = 11.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 85.71% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 85.71% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 85.71% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 85.71% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 95.24% and counterfactual cost = 12.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 95.24% and counterfactual cost = 31.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 95.24% and counterfactual cost = 32.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 100.00% and counterfactual cost = 32.0.
# 		Make education-num = 15, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 12.10
# 	Protected Subgroup ' White', 1.49% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.46% and counterfactual cost = 11.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 57.46% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 57.46% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 57.46% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 57.46% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 60.45% and counterfactual cost = 12.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.45% and counterfactual cost = 31.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 60.45% and counterfactual cost = 32.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 67.16% and counterfactual cost = 32.0.
# 		Make education-num = 15, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 67.91% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 91.04
# 	Bias against  White. Unfairness score = 78.942.
# If capital-loss = 0, education-num = 13, marital-status =  Never-married, occupation =  Prof-specialty, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.33% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 86.36% and counterfactual cost = 11.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 86.36% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 86.36% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 86.36% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 86.36% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 95.45% and counterfactual cost = 12.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 95.45% and counterfactual cost = 31.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 95.45% and counterfactual cost = 32.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 100.00% and counterfactual cost = 32.0.
# 		Make education-num = 15, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 12.05
# 	Protected Subgroup ' White', 1.50% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.04% and counterfactual cost = 11.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 57.04% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 57.04% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 57.04% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 57.04% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 60.74% and counterfactual cost = 12.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.74% and counterfactual cost = 31.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 60.74% and counterfactual cost = 32.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 67.41% and counterfactual cost = 32.0.
# 		Make education-num = 15, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 68.15% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 90.45
# 	Bias against  White. Unfairness score = 78.406.
# If capital-gain = 0, education-num = 10, marital-status =  Divorced, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 2.00% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.45% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 66.67% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 75.76% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 16.21
# 	Protected Subgroup ' White', 1.43% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 16.41% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.78% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.53% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 93.90
# 	Bias against  White. Unfairness score = 77.688.
# If capital-loss = 0, education-num = 10, marital-status =  Divorced, native-country =  United-States, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 1.88% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.16% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 67.74% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 77.42% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 16.90
# 	Protected Subgroup ' White', 1.40% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 19.84% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 27.78% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.03% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 93.99
# 	Bias against  White. Unfairness score = 77.088.
# If capital-loss = 0, education-num = 13, hours-per-week = FullTime, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.69% covered
# 		Make relationship =  Married with effectiveness 7.14% and counterfactual cost = 10.0.
# 		Make hours-per-week = MidTime, relationship =  Married with effectiveness 7.14% and counterfactual cost = 11.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 32.14% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 35.71% and counterfactual cost = 12.0.
# 		Make education-num = 14, relationship =  Married with effectiveness 35.71% and counterfactual cost = 30.0.
# 		Make education-num = 14, hours-per-week = OverTime, relationship =  Married with effectiveness 42.86% and counterfactual cost = 31.0.
# 		Make education-num = 14, hours-per-week = BrainDrain, relationship =  Married with effectiveness 46.43% and counterfactual cost = 32.0.
# 		Make education-num = 15, relationship =  Married with effectiveness 46.43% and counterfactual cost = 50.0.
# 		Make education-num = 15, hours-per-week = OverTime, relationship =  Married with effectiveness 57.14% and counterfactual cost = 51.0.
# 		Make education-num = 15, hours-per-week = BrainDrain, relationship =  Married with effectiveness 57.14% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 12.71
# 	Protected Subgroup ' White', 2.73% covered
# 		Make relationship =  Married with effectiveness 2.04% and counterfactual cost = 10.0.
# 		Make hours-per-week = MidTime, relationship =  Married with effectiveness 2.04% and counterfactual cost = 11.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 8.16% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 8.98% and counterfactual cost = 12.0.
# 		Make education-num = 14, relationship =  Married with effectiveness 8.98% and counterfactual cost = 30.0.
# 		Make education-num = 14, hours-per-week = OverTime, relationship =  Married with effectiveness 16.73% and counterfactual cost = 31.0.
# 		Make education-num = 14, hours-per-week = BrainDrain, relationship =  Married with effectiveness 16.73% and counterfactual cost = 32.0.
# 		Make education-num = 15, relationship =  Married with effectiveness 16.73% and counterfactual cost = 50.0.
# 		Make education-num = 15, hours-per-week = OverTime, relationship =  Married with effectiveness 25.31% and counterfactual cost = 51.0.
# 		Make education-num = 15, hours-per-week = BrainDrain, relationship =  Married with effectiveness 25.71% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 89.68
# 	Bias against  White. Unfairness score = 76.963.
# If education-num = 13, marital-status =  Never-married, occupation =  Prof-specialty, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.33% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 86.36% and counterfactual cost = 11.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 86.36% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 86.36% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 86.36% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 86.36% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 95.45% and counterfactual cost = 12.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 95.45% and counterfactual cost = 31.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 95.45% and counterfactual cost = 32.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 100.00% and counterfactual cost = 32.0.
# 		Make education-num = 15, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 12.05
# 	Protected Subgroup ' White', 1.54% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.97% and counterfactual cost = 11.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 57.97% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 57.97% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 57.97% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 57.97% and counterfactual cost = 12.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 61.59% and counterfactual cost = 12.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 61.59% and counterfactual cost = 31.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 61.59% and counterfactual cost = 32.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 68.12% and counterfactual cost = 32.0.
# 		Make education-num = 15, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 68.84% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 88.72
# 	Bias against  White. Unfairness score = 76.679.
# If education-num = 13, hours-per-week = FullTime, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.75% covered
# 		Make relationship =  Married with effectiveness 6.90% and counterfactual cost = 10.0.
# 		Make hours-per-week = MidTime, relationship =  Married with effectiveness 6.90% and counterfactual cost = 11.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 34.48% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 37.93% and counterfactual cost = 12.0.
# 		Make education-num = 14, relationship =  Married with effectiveness 37.93% and counterfactual cost = 30.0.
# 		Make education-num = 14, hours-per-week = OverTime, relationship =  Married with effectiveness 44.83% and counterfactual cost = 31.0.
# 		Make education-num = 14, hours-per-week = BrainDrain, relationship =  Married with effectiveness 48.28% and counterfactual cost = 32.0.
# 		Make education-num = 15, relationship =  Married with effectiveness 48.28% and counterfactual cost = 50.0.
# 		Make education-num = 15, hours-per-week = OverTime, relationship =  Married with effectiveness 58.62% and counterfactual cost = 51.0.
# 		Make education-num = 15, hours-per-week = BrainDrain, relationship =  Married with effectiveness 58.62% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 12.66
# 	Protected Subgroup ' White', 2.85% covered
# 		Make relationship =  Married with effectiveness 4.30% and counterfactual cost = 10.0.
# 		Make hours-per-week = MidTime, relationship =  Married with effectiveness 4.30% and counterfactual cost = 11.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 10.94% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 11.72% and counterfactual cost = 12.0.
# 		Make education-num = 14, relationship =  Married with effectiveness 11.72% and counterfactual cost = 30.0.
# 		Make education-num = 14, hours-per-week = OverTime, relationship =  Married with effectiveness 19.53% and counterfactual cost = 31.0.
# 		Make education-num = 14, hours-per-week = BrainDrain, relationship =  Married with effectiveness 19.53% and counterfactual cost = 32.0.
# 		Make education-num = 15, relationship =  Married with effectiveness 19.53% and counterfactual cost = 50.0.
# 		Make education-num = 15, hours-per-week = OverTime, relationship =  Married with effectiveness 27.73% and counterfactual cost = 51.0.
# 		Make education-num = 15, hours-per-week = BrainDrain, relationship =  Married with effectiveness 28.12% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 87.35
# 	Bias against  White. Unfairness score = 74.696.
# If capital-loss = 0, education-num = 10, marital-status =  Divorced, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 2.06% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.06% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 67.65% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 76.47% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 16.06
# 	Protected Subgroup ' White', 1.46% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 19.85% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 28.24% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 46.56% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 90.39
# 	Bias against  White. Unfairness score = 74.33.
# If capital-loss = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, native-country =  United-States, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.18% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 8.33% and counterfactual cost = 11.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.56% and counterfactual cost = 12.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.56% and counterfactual cost = 13.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.56% and counterfactual cost = 31.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 38.89% and counterfactual cost = 32.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 38.89% and counterfactual cost = 51.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.67% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 7.69
# 	Protected Subgroup ' White', 1.65% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 4.73% and counterfactual cost = 12.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 4.73% and counterfactual cost = 13.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 4.73% and counterfactual cost = 31.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 8.11% and counterfactual cost = 32.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 8.11% and counterfactual cost = 51.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 11.49% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 81.87
# 	Bias against  White. Unfairness score = 74.179.
# If capital-gain = 0, capital-loss = 0, education-num = 13, native-country =  United-States, occupation =  Prof-specialty, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.21% covered
# 		Make relationship =  Married with effectiveness 10.00% and counterfactual cost = 10.0.
# 		Make occupation =  Craft-repair, relationship =  Married with effectiveness 10.00% and counterfactual cost = 11.0.
# 		Make occupation =  Sales, relationship =  Married with effectiveness 10.00% and counterfactual cost = 11.0.
# 		Make occupation =  Adm-clerical, relationship =  Married with effectiveness 10.00% and counterfactual cost = 11.0.
# 		Make occupation =  Exec-managerial, relationship =  Married with effectiveness 25.00% and counterfactual cost = 11.0.
# 		Make education-num = 14, relationship =  Married with effectiveness 30.00% and counterfactual cost = 30.0.
# 		Make education-num = 14, occupation =  Exec-managerial, relationship =  Married with effectiveness 45.00% and counterfactual cost = 31.0.
# 		Make education-num = 15, relationship =  Married with effectiveness 50.00% and counterfactual cost = 50.0.
# 		Aggregate cost of the above recourses = 11.30
# 	Protected Subgroup ' White', 1.76% covered
# 		Make relationship =  Married with effectiveness 3.16% and counterfactual cost = 10.0.
# 		Make occupation =  Craft-repair, relationship =  Married with effectiveness 3.16% and counterfactual cost = 11.0.
# 		Make occupation =  Sales, relationship =  Married with effectiveness 3.16% and counterfactual cost = 11.0.
# 		Make occupation =  Adm-clerical, relationship =  Married with effectiveness 3.16% and counterfactual cost = 11.0.
# 		Make occupation =  Exec-managerial, relationship =  Married with effectiveness 5.70% and counterfactual cost = 11.0.
# 		Make education-num = 14, relationship =  Married with effectiveness 6.96% and counterfactual cost = 30.0.
# 		Make education-num = 14, occupation =  Exec-managerial, relationship =  Married with effectiveness 15.82% and counterfactual cost = 31.0.
# 		Make education-num = 15, relationship =  Married with effectiveness 17.72% and counterfactual cost = 50.0.
# 		Aggregate cost of the above recourses = 85.37
# 	Bias against  White. Unfairness score = 74.067.
# If education-num = 10, marital-status =  Divorced, native-country =  United-States, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 1.88% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.16% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 67.74% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 77.42% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 16.90
# 	Protected Subgroup ' White', 1.46% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 21.37% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 29.77% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.33% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 90.64
# 	Bias against  White. Unfairness score = 73.738.
# If education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, native-country =  United-States, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.18% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 8.33% and counterfactual cost = 11.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.56% and counterfactual cost = 12.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.56% and counterfactual cost = 13.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.56% and counterfactual cost = 31.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 38.89% and counterfactual cost = 32.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 38.89% and counterfactual cost = 51.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.67% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 7.69
# 	Protected Subgroup ' White', 1.68% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 0.66% and counterfactual cost = 11.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.30% and counterfactual cost = 12.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.30% and counterfactual cost = 13.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.30% and counterfactual cost = 31.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 8.61% and counterfactual cost = 32.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 8.61% and counterfactual cost = 51.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 11.92% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 80.75
# 	Bias against  White. Unfairness score = 73.056.
# If education-num = 10, marital-status =  Divorced, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 2.12% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 48.57% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 68.57% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 77.14% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 15.91
# 	Protected Subgroup ' White', 1.51% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 21.32% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.15% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.79% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 88.92
# 	Bias against  White. Unfairness score = 73.006.
# If capital-gain = 0, education-num = 13, native-country =  United-States, occupation =  Prof-specialty, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.21% covered
# 		Make relationship =  Married with effectiveness 10.00% and counterfactual cost = 10.0.
# 		Make occupation =  Craft-repair, relationship =  Married with effectiveness 10.00% and counterfactual cost = 11.0.
# 		Make occupation =  Sales, relationship =  Married with effectiveness 10.00% and counterfactual cost = 11.0.
# 		Make occupation =  Adm-clerical, relationship =  Married with effectiveness 10.00% and counterfactual cost = 11.0.
# 		Make occupation =  Tech-support, relationship =  Married with effectiveness 10.00% and counterfactual cost = 11.0.
# 		Make occupation =  Exec-managerial, relationship =  Married with effectiveness 25.00% and counterfactual cost = 11.0.
# 		Make education-num = 14, relationship =  Married with effectiveness 30.00% and counterfactual cost = 30.0.
# 		Make education-num = 14, occupation =  Exec-managerial, relationship =  Married with effectiveness 45.00% and counterfactual cost = 31.0.
# 		Make education-num = 15, relationship =  Married with effectiveness 50.00% and counterfactual cost = 50.0.
# 		Aggregate cost of the above recourses = 11.30
# 	Protected Subgroup ' White', 1.79% covered
# 		Make relationship =  Married with effectiveness 3.73% and counterfactual cost = 10.0.
# 		Make occupation =  Craft-repair, relationship =  Married with effectiveness 3.73% and counterfactual cost = 11.0.
# 		Make occupation =  Adm-clerical, relationship =  Married with effectiveness 3.73% and counterfactual cost = 11.0.
# 		Make occupation =  Sales, relationship =  Married with effectiveness 3.73% and counterfactual cost = 11.0.
# 		Make occupation =  Tech-support, relationship =  Married with effectiveness 3.73% and counterfactual cost = 11.0.
# 		Make occupation =  Exec-managerial, relationship =  Married with effectiveness 6.21% and counterfactual cost = 11.0.
# 		Make education-num = 14, relationship =  Married with effectiveness 7.45% and counterfactual cost = 30.0.
# 		Make education-num = 14, occupation =  Exec-managerial, relationship =  Married with effectiveness 16.77% and counterfactual cost = 31.0.
# 		Make education-num = 15, relationship =  Married with effectiveness 18.63% and counterfactual cost = 50.0.
# 		Aggregate cost of the above recourses = 83.25
# 	Bias against  White. Unfairness score = 71.955.
# If age = (26.0, 34.0], education-num = 9, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 8.33% and counterfactual cost = 12.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 20.83% and counterfactual cost = 12.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 20.83% and counterfactual cost = 31.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 20.83% and counterfactual cost = 32.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.67% and counterfactual cost = 32.0.
# 		Make age = (34.0, 41.0], education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.67% and counterfactual cost = 52.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.33% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 17.83
# 	Protected Subgroup ' White', 1.00% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 3.33% and counterfactual cost = 12.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.33% and counterfactual cost = 12.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.33% and counterfactual cost = 31.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.33% and counterfactual cost = 32.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 18.89% and counterfactual cost = 32.0.
# 		Make age = (34.0, 41.0], education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 18.89% and counterfactual cost = 52.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 26.67% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 89.76
# 	Bias against  White. Unfairness score = 71.922.
# If age = (16.999, 26.0], capital-loss = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.48% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.02% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.02% and counterfactual cost = 32.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.41% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 13.12
# 	Protected Subgroup ' White', 1.77% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.66% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.66% and counterfactual cost = 32.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 14.47% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 84.41
# 	Bias against  White. Unfairness score = 71.286.

# %% [markdown]
# ## Fairness of Mean Recourse Cost (conditional expectation implementation) -- Equal Conditional Mean Recourse

# %%
top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
    rules_with_cumulative_correctness,
    metric="fairness-of-mean-recourse-conditional",
    sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
    top_count=top_count,
    filter_sequence = [
        # "remove-contained",
        # "remove-fair-rules"
    ],
    params=params
)

print_recourse_report_cumulative(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    show_then_costs=True
)
# Out:
# If age = (34.0, 41.0], capital-gain = 0, education-num = 9, marital-status =  Never-married:
# 	Protected Subgroup ' Non-White', 2.48% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.34% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 1.67% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 41.0.
# If age = (34.0, 41.0], capital-gain = 0, education-num = 9, marital-status =  Never-married, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 2.18% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 2.78% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 2.78% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 2.78% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 2.78% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 2.78% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 2.78% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 2.78% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.30% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 1.71% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 41.0.
# If Workclass =  Private, age = (34.0, 41.0], education-num = 9, marital-status =  Never-married:
# 	Protected Subgroup ' Non-White', 1.81% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.16% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 1.92% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 41.0.
# If Workclass =  Private, age = (34.0, 41.0], education-num = 9, marital-status =  Never-married, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 1.63% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 3.70% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 3.70% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 3.70% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 3.70% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 3.70% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 3.70% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 3.70% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.11% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 2.00% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 41.0.
# If Workclass =  Private, education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, sex =  Male:
# 	Protected Subgroup ' Non-White', 2.48% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 4.88% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 4.88% and counterfactual cost = 3.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse with effectiveness 4.88% and counterfactual cost = 21.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 4.88% and counterfactual cost = 22.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 4.88% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 1.50
# 	Protected Subgroup ' White', 1.88% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 3.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 2.96% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 40.5.
# If Workclass =  Private, capital-loss = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, sex =  Male:
# 	Protected Subgroup ' Non-White', 2.48% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 4.88% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 4.88% and counterfactual cost = 3.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse with effectiveness 4.88% and counterfactual cost = 21.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 4.88% and counterfactual cost = 22.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 4.88% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 1.50
# 	Protected Subgroup ' White', 1.85% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 3.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.01% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 40.5.
# If Workclass =  Private, capital-loss = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.75% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 3.45% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 6.90% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 6.90% and counterfactual cost = 3.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse with effectiveness 6.90% and counterfactual cost = 21.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 6.90% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 1.50
# 	Protected Subgroup ' White', 1.76% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 3.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.16% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 40.5.
# If Workclass =  Private, education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.75% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 3.45% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 6.90% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 6.90% and counterfactual cost = 3.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse with effectiveness 6.90% and counterfactual cost = 21.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 6.90% and counterfactual cost = 22.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 6.90% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 1.50
# 	Protected Subgroup ' White', 1.79% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 3.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.11% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 40.5.
# If age = (16.999, 26.0], capital-loss = 0, education-num = 9, marital-status =  Never-married:
# 	Protected Subgroup ' Non-White', 7.32% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (26.0, 34.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (34.0, 41.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 0.83% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Protected Subgroup ' White', 6.52% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse with effectiveness 0.17% and counterfactual cost = 2.0.
# 		Make age = (26.0, 34.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.17% and counterfactual cost = 22.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.17% and counterfactual cost = 22.0.
# 		Make age = (34.0, 41.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 0.17% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 2.00
# 	Bias against  Non-White. Unfairness score = 40.0.
# If Workclass =  Private, capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, sex =  Male:
# 	Protected Subgroup ' Non-White', 2.42% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 2.50% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 2.50% and counterfactual cost = 3.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 2.50% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 2.00
# 	Protected Subgroup ' White', 1.82% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 3.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.07% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 40.0.
# If Workclass =  Private, capital-gain = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, sex =  Male:
# 	Protected Subgroup ' Non-White', 2.42% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 2.50% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 2.50% and counterfactual cost = 3.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 2.50% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 2.00
# 	Protected Subgroup ' White', 1.85% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 3.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.01% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 40.0.
# If Workclass =  Private, age = (34.0, 41.0], capital-gain = 0, education-num = 9, marital-status =  Never-married:
# 	Protected Subgroup ' Non-White', 1.81% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 3.33% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 2.00
# 	Protected Subgroup ' White', 1.13% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 1.98% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 40.0.
# If Workclass =  Private, capital-gain = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.69% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.57% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 3.57% and counterfactual cost = 3.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.57% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 2.00
# 	Protected Subgroup ' White', 1.76% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 3.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.16% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 40.0.
# If Workclass =  Private, capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.69% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.57% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 3.57% and counterfactual cost = 3.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.57% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 2.00
# 	Protected Subgroup ' White', 1.73% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 3.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 3.23% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White. Unfairness score = 40.0.
# If age = (16.999, 26.0], capital-loss = 0, education-num = 9, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.63% covered
# 		Make age = (34.0, 41.0], relationship =  Married with effectiveness 3.70% and counterfactual cost = 11.0.
# 		Make age = (26.0, 34.0], education-num = 10, relationship =  Married with effectiveness 3.70% and counterfactual cost = 31.0.
# 		Make age = (34.0, 41.0], education-num = 10, relationship =  Married with effectiveness 3.70% and counterfactual cost = 31.0.
# 		Make age = (34.0, 41.0], education-num = 11, relationship =  Married with effectiveness 3.70% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 11.00
# 	Protected Subgroup ' White', 2.36% covered
# 		Make age = (34.0, 41.0], relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make age = (34.0, 41.0], education-num = 10, relationship =  Married with effectiveness 0.00% and counterfactual cost = 31.0.
# 		Make age = (26.0, 34.0], education-num = 10, relationship =  Married with effectiveness 0.00% and counterfactual cost = 31.0.
# 		Make age = (34.0, 41.0], education-num = 11, relationship =  Married with effectiveness 0.94% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 51.00
# 	Bias against  White. Unfairness score = 40.0.
# If age = (16.999, 26.0], capital-loss = 0, education-num = 9, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make age = (34.0, 41.0], relationship =  Married with effectiveness 4.17% and counterfactual cost = 11.0.
# 		Make age = (26.0, 34.0], education-num = 10, relationship =  Married with effectiveness 4.17% and counterfactual cost = 31.0.
# 		Make age = (34.0, 41.0], education-num = 10, relationship =  Married with effectiveness 4.17% and counterfactual cost = 31.0.
# 		Make age = (34.0, 41.0], education-num = 11, relationship =  Married with effectiveness 4.17% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 11.00
# 	Protected Subgroup ' White', 2.23% covered
# 		Make age = (34.0, 41.0], relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make age = (34.0, 41.0], education-num = 10, relationship =  Married with effectiveness 0.00% and counterfactual cost = 31.0.
# 		Make age = (26.0, 34.0], education-num = 10, relationship =  Married with effectiveness 0.00% and counterfactual cost = 31.0.
# 		Make age = (34.0, 41.0], education-num = 11, relationship =  Married with effectiveness 0.50% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 51.00
# 	Bias against  White. Unfairness score = 40.0.
# If Workclass =  Private, capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = PartTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 1.27% covered
# 		Make hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 4.76% and counterfactual cost = 14.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 4.76% and counterfactual cost = 15.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 4.76% and counterfactual cost = 54.0.
# 		Aggregate cost of the above recourses = 14.00
# 	Protected Subgroup ' White', 1.89% covered
# 		Make hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 0.00% and counterfactual cost = 14.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 0.00% and counterfactual cost = 15.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 0.59% and counterfactual cost = 54.0.
# 		Aggregate cost of the above recourses = 54.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = FullTime, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 3.02% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 2.00% and counterfactual cost = 12.0.
# 		Make education-num = 11, relationship =  Married with effectiveness 2.00% and counterfactual cost = 30.0.
# 		Make education-num = 12, relationship =  Married with effectiveness 2.00% and counterfactual cost = 50.0.
# 		Make education-num = 12, hours-per-week = OverTime, relationship =  Married with effectiveness 2.00% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 12.00
# 	Protected Subgroup ' White', 2.04% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 0.00% and counterfactual cost = 12.0.
# 		Make education-num = 11, relationship =  Married with effectiveness 0.00% and counterfactual cost = 30.0.
# 		Make education-num = 12, relationship =  Married with effectiveness 0.55% and counterfactual cost = 50.0.
# 		Make education-num = 12, hours-per-week = OverTime, relationship =  Married with effectiveness 0.55% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 50.00
# 	Bias against  White. Unfairness score = 38.0.
# If capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = FullTime, native-country =  United-States, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.36% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 2.56% and counterfactual cost = 12.0.
# 		Make education-num = 12, relationship =  Married with effectiveness 2.56% and counterfactual cost = 50.0.
# 		Make education-num = 12, hours-per-week = OverTime, relationship =  Married with effectiveness 2.56% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 12.00
# 	Protected Subgroup ' White', 1.84% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 0.00% and counterfactual cost = 12.0.
# 		Make education-num = 12, relationship =  Married with effectiveness 0.61% and counterfactual cost = 50.0.
# 		Make education-num = 12, hours-per-week = OverTime, relationship =  Married with effectiveness 0.61% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 50.00
# 	Bias against  White. Unfairness score = 38.0.
# If capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = FullTime, relationship =  Own-child, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 4.17% and counterfactual cost = 12.0.
# 		Make education-num = 12, relationship =  Married with effectiveness 4.17% and counterfactual cost = 50.0.
# 		Make education-num = 12, hours-per-week = OverTime, relationship =  Married with effectiveness 4.17% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 12.00
# 	Protected Subgroup ' White', 1.28% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 0.00% and counterfactual cost = 12.0.
# 		Make education-num = 12, relationship =  Married with effectiveness 0.87% and counterfactual cost = 50.0.
# 		Make education-num = 12, hours-per-week = OverTime, relationship =  Married with effectiveness 0.87% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 50.00
# 	Bias against  White. Unfairness score = 38.0.

# %% [markdown]
# ## Fairness of Recourse at Effectiveness Level -- Equal Cost of Effectiveness (Micro)

# %%
top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
    rules_with_cumulative_correctness,
    metric="min-above-corr",
    sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
    top_count=top_count,
    cor_threshold = cor_thres,
    filter_sequence = [
        # "remove-contained",
        # "remove-fair-rules",
        # "keep-cheap-rules-above-thr-cor",
        # "keep-only-min-change",
        
    ],
    params=params
)

print_recourse_report_cumulative(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    show_then_costs=True
)
# Out:
# If education-num = 9, marital-status =  Married-civ-spouse, occupation =  Other-service:
# 	Protected Subgroup ' Non-White', 2.12% covered
# 		Make occupation =  Craft-repair with effectiveness 14.29% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 17.14% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 20.00% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 60.00% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 60.00% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 60.00% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 60.00% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 62.86% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 68.57% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 77.14% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.15% covered
# 		Make occupation =  Craft-repair with effectiveness 7.77% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 10.68% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 13.59% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 27.18% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 27.18% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 27.18% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 27.18% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 27.18% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 44.66% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 56.31% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If education-num = 9, occupation =  Other-service, relationship =  Married:
# 	Protected Subgroup ' Non-White', 2.06% covered
# 		Make occupation =  Craft-repair with effectiveness 14.71% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 17.65% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 20.59% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 61.76% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 61.76% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 61.76% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 61.76% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 64.71% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 70.59% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 79.41% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.08% covered
# 		Make occupation =  Craft-repair with effectiveness 8.25% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 11.34% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 14.43% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 27.84% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 27.84% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 27.84% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 27.84% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 27.84% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 46.39% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 58.76% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If education-num = 9, marital-status =  Married-civ-spouse, occupation =  Other-service, relationship =  Married:
# 	Protected Subgroup ' Non-White', 2.06% covered
# 		Make occupation =  Craft-repair with effectiveness 14.71% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 17.65% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 20.59% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 61.76% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 61.76% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 61.76% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 61.76% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 64.71% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 70.59% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 79.41% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.08% covered
# 		Make occupation =  Craft-repair with effectiveness 8.25% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 11.34% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 14.43% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 27.84% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 27.84% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 27.84% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 27.84% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 27.84% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 46.39% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 58.76% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-loss = 0, education-num = 9, marital-status =  Married-civ-spouse, occupation =  Other-service:
# 	Protected Subgroup ' Non-White', 2.06% covered
# 		Make occupation =  Craft-repair with effectiveness 11.76% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 17.65% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 58.82% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 58.82% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 58.82% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 58.82% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 61.76% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 67.65% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 76.47% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.07% covered
# 		Make occupation =  Craft-repair with effectiveness 3.12% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 8.33% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 21.88% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 21.88% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 21.88% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 21.88% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 21.88% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 40.62% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 53.12% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-loss = 0, education-num = 9, occupation =  Other-service, relationship =  Married:
# 	Protected Subgroup ' Non-White', 2.00% covered
# 		Make occupation =  Craft-repair with effectiveness 12.12% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 18.18% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 60.61% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 63.64% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 69.70% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 78.79% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.00% covered
# 		Make occupation =  Craft-repair with effectiveness 3.33% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 8.89% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 22.22% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 42.22% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 55.56% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-loss = 0, education-num = 9, marital-status =  Married-civ-spouse, occupation =  Other-service, relationship =  Married:
# 	Protected Subgroup ' Non-White', 2.00% covered
# 		Make occupation =  Craft-repair with effectiveness 12.12% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 18.18% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 60.61% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 63.64% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 69.70% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 78.79% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.00% covered
# 		Make occupation =  Craft-repair with effectiveness 3.33% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 8.89% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 22.22% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 42.22% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 55.56% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.94% covered
# 		Make hours-per-week = OverTime with effectiveness 50.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 50.00% and counterfactual cost = 2.0.
# 		Make education-num = 12 with effectiveness 50.00% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 65.62% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 3.28% covered
# 		Make hours-per-week = OverTime with effectiveness 32.31% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 34.01% and counterfactual cost = 2.0.
# 		Make education-num = 12 with effectiveness 45.24% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 66.67% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = FullTime, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.94% covered
# 		Make hours-per-week = OverTime with effectiveness 50.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 50.00% and counterfactual cost = 2.0.
# 		Make education-num = 12 with effectiveness 50.00% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 65.62% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 3.28% covered
# 		Make hours-per-week = OverTime with effectiveness 32.31% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 34.01% and counterfactual cost = 2.0.
# 		Make education-num = 12 with effectiveness 45.24% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 66.67% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.57% covered
# 		Make hours-per-week = OverTime with effectiveness 50.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 50.00% and counterfactual cost = 2.0.
# 		Make education-num = 12 with effectiveness 50.00% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 61.54% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 3.12% covered
# 		Make hours-per-week = OverTime with effectiveness 33.57% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 35.36% and counterfactual cost = 2.0.
# 		Make education-num = 12 with effectiveness 46.79% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 67.14% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.57% covered
# 		Make hours-per-week = OverTime with effectiveness 50.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 50.00% and counterfactual cost = 2.0.
# 		Make education-num = 11 with effectiveness 50.00% and counterfactual cost = 20.0.
# 		Make education-num = 12 with effectiveness 50.00% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 61.54% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 3.15% covered
# 		Make hours-per-week = OverTime with effectiveness 33.57% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 35.34% and counterfactual cost = 2.0.
# 		Make education-num = 11 with effectiveness 35.34% and counterfactual cost = 20.0.
# 		Make education-num = 12 with effectiveness 46.64% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 67.14% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If education-num = 10, marital-status =  Divorced, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.51% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 56.00% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.00% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 76.00% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 11.00
# 	Protected Subgroup ' White', 2.35% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 32.23% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.55% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 57.35% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 51.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, education-num = 10, marital-status =  Divorced, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.51% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 56.00% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.00% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 76.00% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 11.00
# 	Protected Subgroup ' White', 2.23% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 29.50% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.00% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.50% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 51.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, education-num = 10, hours-per-week = FullTime, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make hours-per-week = OverTime with effectiveness 54.17% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 54.17% and counterfactual cost = 2.0.
# 		Make education-num = 11 with effectiveness 54.17% and counterfactual cost = 20.0.
# 		Make education-num = 12 with effectiveness 54.17% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 66.67% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 3.13% covered
# 		Make hours-per-week = OverTime with effectiveness 33.81% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 35.59% and counterfactual cost = 2.0.
# 		Make education-num = 11 with effectiveness 35.59% and counterfactual cost = 20.0.
# 		Make education-num = 12 with effectiveness 46.98% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 67.62% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make hours-per-week = OverTime with effectiveness 54.17% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 54.17% and counterfactual cost = 2.0.
# 		Make education-num = 12 with effectiveness 54.17% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 66.67% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 3.10% covered
# 		Make hours-per-week = OverTime with effectiveness 33.81% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 35.61% and counterfactual cost = 2.0.
# 		Make education-num = 12 with effectiveness 47.12% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 67.63% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, capital-loss = 0, education-num = 10, hours-per-week = FullTime, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make hours-per-week = OverTime with effectiveness 54.17% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 54.17% and counterfactual cost = 2.0.
# 		Make education-num = 12 with effectiveness 54.17% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 66.67% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 3.10% covered
# 		Make hours-per-week = OverTime with effectiveness 33.81% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 35.61% and counterfactual cost = 2.0.
# 		Make education-num = 12 with effectiveness 47.12% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 67.63% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make hours-per-week = OverTime with effectiveness 54.17% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 54.17% and counterfactual cost = 2.0.
# 		Make education-num = 11 with effectiveness 54.17% and counterfactual cost = 20.0.
# 		Make education-num = 12 with effectiveness 54.17% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 66.67% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 3.13% covered
# 		Make hours-per-week = OverTime with effectiveness 33.81% and counterfactual cost = 1.0.
# 		Make hours-per-week = BrainDrain with effectiveness 35.59% and counterfactual cost = 2.0.
# 		Make education-num = 11 with effectiveness 35.59% and counterfactual cost = 20.0.
# 		Make education-num = 12 with effectiveness 46.98% and counterfactual cost = 40.0.
# 		Make education-num = 12, hours-per-week = OverTime with effectiveness 67.62% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-loss = 0, education-num = 10, marital-status =  Divorced, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.17% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.33% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 75.00% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 11.00
# 	Protected Subgroup ' White', 2.24% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 28.86% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.79% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 55.22% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 51.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, capital-loss = 0, education-num = 10, marital-status =  Divorced, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.17% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.33% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 75.00% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 11.00
# 	Protected Subgroup ' White', 2.12% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.79% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 38.95% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 53.16% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 51.00
# 	Bias against  White. Unfairness score = 40.0.
# If education-num = 10, marital-status =  Divorced, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.39% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.87% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 65.22% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 78.26% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 11.00
# 	Protected Subgroup ' White', 2.27% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 32.84% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.59% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 58.33% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 51.00
# 	Bias against  White. Unfairness score = 40.0.
# If capital-gain = 0, education-num = 10, marital-status =  Divorced, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.39% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.87% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 65.22% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 78.26% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 11.00
# 	Protected Subgroup ' White', 2.15% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 30.05% and counterfactual cost = 11.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.01% and counterfactual cost = 31.0.
# 		Make education-num = 12, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 56.48% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 51.00
# 	Bias against  White. Unfairness score = 40.0.

# %% [markdown]
# ## Fairness of Effectiveness -- Equal Effectiveness

# %%
top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
    rules_with_cumulative_correctness,
    metric="total-correctness",
    sort_strategy="generic-sorting-ignore-forall-subgroups-empty",
    top_count=top_count,
    filter_sequence = [
        # "remove-contained",
        # "remove-fair-rules",
        # "keep-only-min-change"
    ],
    params=params
)

print_recourse_report_cumulative(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    show_then_costs=True,
    correctness_metric=True
)
# Out:
# If age = (16.999, 26.0], capital-gain = 0, capital-loss = 0, marital-status =  Never-married, occupation =  Handlers-cleaners, relationship =  Own-child, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.03% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 11.76% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 35.29% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 58.82% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 76.47% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.76
# 	Protected Subgroup ' White', 1.24% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 1.80% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 1.80% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 5.41% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 5.41% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 9.01% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 20.72% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.21
# 	Bias against  White. Unfairness score = 0.557.
# If age = (16.999, 26.0], capital-gain = 0, marital-status =  Never-married, occupation =  Handlers-cleaners, relationship =  Own-child, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.03% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 11.76% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 35.29% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 58.82% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 58.82% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 76.47% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.76
# 	Protected Subgroup ' White', 1.26% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 1.77% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 1.77% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 1.77% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 5.31% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 5.31% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 9.73% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 9.73% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 21.24% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.21
# 	Bias against  White. Unfairness score = 0.552.
# If age = (16.999, 26.0], capital-loss = 0, marital-status =  Never-married, occupation =  Handlers-cleaners, relationship =  Own-child, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.03% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 11.76% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 35.29% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 58.82% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 58.82% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 76.47% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.76
# 	Protected Subgroup ' White', 1.25% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 1.79% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 1.79% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 1.79% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 6.25% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 6.25% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 9.82% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 9.82% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 21.43% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.21
# 	Bias against  White. Unfairness score = 0.55.
# If age = (16.999, 26.0], marital-status =  Never-married, occupation =  Handlers-cleaners, relationship =  Own-child, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.03% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 11.76% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 35.29% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 58.82% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 58.82% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 76.47% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.76
# 	Protected Subgroup ' White', 1.27% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 1.75% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 1.75% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 1.75% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 6.14% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 6.14% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 10.53% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 10.53% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 21.93% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.22
# 	Bias against  White. Unfairness score = 0.545.
# If age = (16.999, 26.0], capital-gain = 0, capital-loss = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.48% covered
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.41% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.63
# 	Protected Subgroup ' White', 1.73% covered
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 12.90% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.13
# 	Bias against  White. Unfairness score = 0.505.
# If age = (16.999, 26.0], capital-gain = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.48% covered
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.41% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.63
# 	Protected Subgroup ' White', 1.74% covered
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.46% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.13
# 	Bias against  White. Unfairness score = 0.5.
# If Workclass =  Private, age = (16.999, 26.0], capital-gain = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.24% covered
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 62.16% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.62
# 	Protected Subgroup ' White', 1.54% covered
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.04% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.13
# 	Bias against  White. Unfairness score = 0.491.
# If age = (16.999, 26.0], capital-loss = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.48% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.02% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.02% and counterfactual cost = 32.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.41% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.63
# 	Protected Subgroup ' White', 1.77% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.66% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.66% and counterfactual cost = 32.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 14.47% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.14
# 	Bias against  White. Unfairness score = 0.489.
# If age = (16.999, 26.0], education-num = 9, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.48% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.02% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.02% and counterfactual cost = 32.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.41% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.63
# 	Protected Subgroup ' White', 1.78% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 6.25% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 6.25% and counterfactual cost = 32.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 15.00% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.15
# 	Bias against  White. Unfairness score = 0.484.
# If age = (16.999, 26.0], capital-gain = 0, capital-loss = 0, marital-status =  Never-married, occupation =  Handlers-cleaners, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 10.53% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 31.58% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.63% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 68.42% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.68
# 	Protected Subgroup ' White', 1.36% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 1.64% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 1.64% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 4.92% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 4.92% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 8.20% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 20.49% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.20
# 	Bias against  White. Unfairness score = 0.479.
# If age = (16.999, 26.0], capital-gain = 0, marital-status =  Never-married, occupation =  Handlers-cleaners, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 10.53% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 31.58% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.63% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 52.63% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 68.42% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.68
# 	Protected Subgroup ' White', 1.39% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 1.60% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 1.60% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 1.60% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 4.80% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 4.80% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 8.80% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 8.80% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 20.80% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.21
# 	Bias against  White. Unfairness score = 0.476.
# If Workclass =  Private, age = (16.999, 26.0], education-num = 9, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.24% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.84% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.84% and counterfactual cost = 32.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 62.16% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.62
# 	Protected Subgroup ' White', 1.58% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.63% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], education-num = 10, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.63% and counterfactual cost = 32.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 14.79% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.15
# 	Bias against  White. Unfairness score = 0.474.
# If Workclass =  Private, age = (16.999, 26.0], capital-loss = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 2.24% covered
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 62.16% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.62
# 	Protected Subgroup ' White', 1.58% covered
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 14.79% and counterfactual cost = 33.0.
# 		Aggregate cost of the above recourses = 0.15
# 	Bias against  White. Unfairness score = 0.474.
# If age = (16.999, 26.0], capital-loss = 0, marital-status =  Never-married, occupation =  Handlers-cleaners, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 5.26% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 10.53% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 31.58% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.63% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 52.63% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 68.42% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.68
# 	Protected Subgroup ' White', 1.37% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 1.63% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 1.63% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 1.63% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 2.44% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 5.69% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 5.69% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 8.94% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 8.94% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 21.14% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.21
# 	Bias against  White. Unfairness score = 0.473.
# If age = (16.999, 26.0], capital-gain = 0, hours-per-week = MidTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.67% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.17% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.17% and counterfactual cost = 14.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 62.50% and counterfactual cost = 14.0.
# 		Make age = (26.0, 34.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 62.50% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 70.83% and counterfactual cost = 15.0.
# 		Aggregate cost of the above recourses = 0.71
# 	Protected Subgroup ' White', 2.31% covered
# 		Make age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.31% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.04% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.04% and counterfactual cost = 14.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 23.67% and counterfactual cost = 14.0.
# 		Make age = (26.0, 34.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 23.67% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 23.67% and counterfactual cost = 15.0.
# 		Aggregate cost of the above recourses = 0.24
# 	Bias against  White. Unfairness score = 0.472.
# If age = (16.999, 26.0], marital-status =  Never-married, occupation =  Handlers-cleaners, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 0.00% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 5.26% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 10.53% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 31.58% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 52.63% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 52.63% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 68.42% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.68
# 	Protected Subgroup ' White', 1.40% covered
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 1.59% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 1.59% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 1.59% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 2.38% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 5.56% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 5.56% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 9.52% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 9.52% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 21.43% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.21
# 	Bias against  White. Unfairness score = 0.47.
# If age = (16.999, 26.0], hours-per-week = MidTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.67% and counterfactual cost = 12.0.
# 		Make age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.67% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.17% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.17% and counterfactual cost = 14.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 62.50% and counterfactual cost = 14.0.
# 		Make age = (26.0, 34.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 62.50% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 70.83% and counterfactual cost = 15.0.
# 		Aggregate cost of the above recourses = 0.71
# 	Protected Subgroup ' White', 2.34% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.71% and counterfactual cost = 12.0.
# 		Make age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 5.71% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.81% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.81% and counterfactual cost = 14.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 24.29% and counterfactual cost = 14.0.
# 		Make age = (26.0, 34.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 24.29% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 24.29% and counterfactual cost = 15.0.
# 		Aggregate cost of the above recourses = 0.24
# 	Bias against  White. Unfairness score = 0.465.
# If age = (16.999, 26.0], marital-status =  Never-married, occupation =  Adm-clerical, relationship =  Own-child, sex =  Female:
# 	Protected Subgroup ' Non-White', 2.00% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 60.61% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.61
# 	Protected Subgroup ' White', 1.50% covered
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 14.07% and counterfactual cost = 13.0.
# 		Aggregate cost of the above recourses = 0.14
# 	Bias against  White. Unfairness score = 0.465.
# If age = (16.999, 26.0], capital-gain = 0, capital-loss = 0, hours-per-week = PartTime, marital-status =  Never-married, occupation =  Sales, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 11.11% and counterfactual cost = 15.0.
# 		Make age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 27.78% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 55.56% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 83.33% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 83.33% and counterfactual cost = 15.0.
# 		Make age = (26.0, 34.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 83.33% and counterfactual cost = 16.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 83.33% and counterfactual cost = 16.0.
# 		Make age = (26.0, 34.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 83.33% and counterfactual cost = 16.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 100.00% and counterfactual cost = 16.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.23% covered
# 		Make age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 1.82% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 3.64% and counterfactual cost = 15.0.
# 		Make age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 3.64% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 40.91% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 40.91% and counterfactual cost = 15.0.
# 		Make age = (26.0, 34.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 40.91% and counterfactual cost = 16.0.
# 		Make age = (26.0, 34.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 40.91% and counterfactual cost = 16.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Prof-specialty, relationship =  Married with effectiveness 43.64% and counterfactual cost = 16.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 53.64% and counterfactual cost = 16.0.
# 		Aggregate cost of the above recourses = 0.54
# 	Bias against  White. Unfairness score = 0.464.
# If age = (16.999, 26.0], capital-gain = 0, capital-loss = 0, hours-per-week = MidTime, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 1.33% covered
# 		Make age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 40.91% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.55% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 54.55% and counterfactual cost = 14.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 59.09% and counterfactual cost = 14.0.
# 		Make age = (26.0, 34.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 59.09% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 68.18% and counterfactual cost = 15.0.
# 		Aggregate cost of the above recourses = 0.68
# 	Protected Subgroup ' White', 2.27% covered
# 		Make age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 4.41% and counterfactual cost = 13.0.
# 		Make age = (34.0, 41.0], hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 11.76% and counterfactual cost = 13.0.
# 		Make age = (26.0, 34.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 11.76% and counterfactual cost = 14.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 22.55% and counterfactual cost = 14.0.
# 		Make age = (26.0, 34.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 22.55% and counterfactual cost = 15.0.
# 		Make age = (34.0, 41.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 22.55% and counterfactual cost = 15.0.
# 		Aggregate cost of the above recourses = 0.23
# 	Bias against  White. Unfairness score = 0.456.

# %% [markdown]
# ## Fairness of Recourse (using two-sample Kolmogorov-Smirnov test) -- Fair Effectiveness-Cost Trade-Off

# %%
# taken from the other notebooks
preds_Xtest = model.predict(Xtest)
affected_pop_sizes = {sg: ((Xtest["race"] == sg) & (preds_Xtest == 0)).sum() for sg in Xtest["race"].unique()}

top_rules,unfairness = facts.select_rules_subset_KStest(
    rules_with_cumulative_correctness,
    affected_pop_sizes,
    top_count=top_count
)

print_recourse_report_KStest_cumulative(
    top_rules,
    population_sizes=affected_pop_sizes,
    unfairness = unfairness,
    show_then_costs=True
    # show_cumulative_plots=True
)
# Out:
# If capital-gain = 0, capital-loss = 0, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 15.43% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 7.45% and counterfactual cost = 11.0.
# 		Make capital-gain = 3103, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.88% and counterfactual cost = 11.03.
# 		Make capital-gain = 4386, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 32.94% and counterfactual cost = 11.04.
# 		Make capital-gain = 5178, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.10% and counterfactual cost = 11.05.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 66.67% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 74.51% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.15.
# 		Make capital-loss = 1887, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.43.
# 		Make capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.44.
# 		Make capital-loss = 1977, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.45.
# 		Make capital-gain = 99999, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	Protected Subgroup ' White', 16.09% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 3.32% and counterfactual cost = 11.0.
# 		Make capital-gain = 3103, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 12.53% and counterfactual cost = 11.03.
# 		Make capital-gain = 4386, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 20.29% and counterfactual cost = 11.04.
# 		Make capital-gain = 5178, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 24.38% and counterfactual cost = 11.05.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.27% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 44.94% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.68% and counterfactual cost = 11.15.
# 		Make capital-loss = 1887, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.68% and counterfactual cost = 11.43.
# 		Make capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.68% and counterfactual cost = 11.44.
# 		Make capital-loss = 1977, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.68% and counterfactual cost = 11.45.
# 		Make capital-gain = 99999, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 4.35.
# If capital-gain = 0, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 15.73% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 8.08% and counterfactual cost = 11.0.
# 		Make capital-gain = 3103, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 26.54% and counterfactual cost = 11.03.
# 		Make capital-gain = 4386, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 33.46% and counterfactual cost = 11.04.
# 		Make capital-gain = 5178, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.38% and counterfactual cost = 11.05.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 66.92% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 74.62% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.15.
# 		Make capital-gain = 99999, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	Protected Subgroup ' White', 16.49% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 3.78% and counterfactual cost = 11.0.
# 		Make capital-gain = 3103, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.18% and counterfactual cost = 11.03.
# 		Make capital-gain = 4386, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 20.95% and counterfactual cost = 11.04.
# 		Make capital-gain = 5178, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.34% and counterfactual cost = 11.05.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.03% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.68% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.76% and counterfactual cost = 11.15.
# 		Make capital-gain = 99999, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 4.3.
# If capital-gain = 0, capital-loss = 0, marital-status =  Never-married, native-country =  United-States, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 13.01% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 7.44% and counterfactual cost = 11.0.
# 		Make capital-gain = 3103, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 27.44% and counterfactual cost = 11.03.
# 		Make capital-gain = 4386, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 35.35% and counterfactual cost = 11.04.
# 		Make capital-gain = 5178, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 48.37% and counterfactual cost = 11.05.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 66.51% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 75.81% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.15.
# 		Make capital-loss = 1887, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.43.
# 		Make capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.44.
# 		Make capital-loss = 1977, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.45.
# 		Make capital-gain = 99999, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	Protected Subgroup ' White', 15.35% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 3.34% and counterfactual cost = 11.0.
# 		Make capital-gain = 3103, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 12.77% and counterfactual cost = 11.03.
# 		Make capital-gain = 4386, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 20.39% and counterfactual cost = 11.04.
# 		Make capital-gain = 5178, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 24.38% and counterfactual cost = 11.05.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 41.36% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.14% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.73% and counterfactual cost = 11.15.
# 		Make capital-loss = 1887, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.73% and counterfactual cost = 11.43.
# 		Make capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.73% and counterfactual cost = 11.44.
# 		Make capital-loss = 1977, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.73% and counterfactual cost = 11.45.
# 		Make capital-gain = 99999, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 4.18.
# If capital-gain = 0, marital-status =  Never-married, native-country =  United-States, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 13.25% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 8.22% and counterfactual cost = 11.0.
# 		Make capital-gain = 3103, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 27.85% and counterfactual cost = 11.03.
# 		Make capital-gain = 4386, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 35.62% and counterfactual cost = 11.04.
# 		Make capital-gain = 5178, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 48.40% and counterfactual cost = 11.05.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 66.67% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 75.80% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.15.
# 		Make capital-gain = 99999, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	Protected Subgroup ' White', 15.75% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 3.82% and counterfactual cost = 11.0.
# 		Make capital-gain = 3103, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 13.44% and counterfactual cost = 11.03.
# 		Make capital-gain = 4386, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 21.07% and counterfactual cost = 11.04.
# 		Make capital-gain = 5178, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 25.39% and counterfactual cost = 11.05.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.15% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 45.90% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.82% and counterfactual cost = 11.15.
# 		Make capital-gain = 99999, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 4.12.
# If Workclass =  Private, capital-gain = 0, capital-loss = 0, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 13.07% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 6.94% and counterfactual cost = 11.0.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.89% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 73.15% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.15.
# 		Make capital-loss = 1887, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.43.
# 		Make capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.44.
# 		Make capital-loss = 1977, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.45.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	Protected Subgroup ' White', 13.98% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 2.79% and counterfactual cost = 11.0.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.20% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.87% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.49% and counterfactual cost = 11.15.
# 		Make capital-loss = 1887, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.49% and counterfactual cost = 11.43.
# 		Make capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.49% and counterfactual cost = 11.44.
# 		Make capital-loss = 1977, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.49% and counterfactual cost = 11.45.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.49% and counterfactual cost = 12.0.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.49% and counterfactual cost = 12.0.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.49% and counterfactual cost = 12.0.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.49% and counterfactual cost = 12.0.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.49% and counterfactual cost = 12.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 4.11.
# If Workclass =  Private, capital-gain = 0, marital-status =  Never-married, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 13.37% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 7.69% and counterfactual cost = 11.0.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 64.25% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 73.30% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.15.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	Protected Subgroup ' White', 14.34% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 3.19% and counterfactual cost = 11.0.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 40.02% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.67% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 11.15.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 12.0.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 12.0.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 12.0.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 12.0.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 12.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 4.07.
# If Workclass =  Private, capital-gain = 0, capital-loss = 0, marital-status =  Never-married, native-country =  United-States, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 10.77% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 6.74% and counterfactual cost = 11.0.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 62.92% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 74.16% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.15.
# 		Make capital-loss = 1887, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.43.
# 		Make capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.44.
# 		Make capital-loss = 1977, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.45.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	Protected Subgroup ' White', 13.37% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 2.75% and counterfactual cost = 11.0.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 39.33% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.08% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 11.15.
# 		Make capital-loss = 1887, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 11.43.
# 		Make capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 11.44.
# 		Make capital-loss = 1977, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 11.45.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 12.0.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 12.0.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 12.0.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 12.0.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.58% and counterfactual cost = 12.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.87.
# If Workclass =  Private, capital-gain = 0, marital-status =  Never-married, native-country =  United-States, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 11.01% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 7.69% and counterfactual cost = 11.0.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.19% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 74.18% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.15.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00% and counterfactual cost = 12.0.
# 	Protected Subgroup ' White', 13.72% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 3.17% and counterfactual cost = 11.0.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 40.18% and counterfactual cost = 11.07.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 43.91% and counterfactual cost = 11.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.67% and counterfactual cost = 11.15.
# 		Make Workclass =  Self-emp-not-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.67% and counterfactual cost = 12.0.
# 		Make Workclass =  State-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.67% and counterfactual cost = 12.0.
# 		Make Workclass =  Local-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.67% and counterfactual cost = 12.0.
# 		Make Workclass =  Self-emp-inc, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.67% and counterfactual cost = 12.0.
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 96.67% and counterfactual cost = 12.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.81.
# If capital-gain = 0, marital-status =  Never-married, occupation =  Other-service:
# 	Protected Subgroup ' Non-White', 8.11% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving with effectiveness 0.75% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 1.49% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 1.49% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 1.49% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Protective-serv with effectiveness 1.49% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 2.99% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support with effectiveness 2.99% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 3.73% and counterfactual cost = 2.0.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 59.70% and counterfactual cost = 2.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 100.00% and counterfactual cost = 2.15.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 100.00% and counterfactual cost = 2.15.
# 	Protected Subgroup ' White', 6.35% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 0.18% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Protective-serv with effectiveness 0.35% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 0.53% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support with effectiveness 0.53% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 1.05% and counterfactual cost = 2.0.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 26.67% and counterfactual cost = 2.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 88.77% and counterfactual cost = 2.15.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 94.56% and counterfactual cost = 2.15.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.44.
# If capital-gain = 0, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 76.71% covered out of 1653
# 		Make capital-gain = 3103 with effectiveness 11.04% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 17.74% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 22.00% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 34.23% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 36.91% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 83.36% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 89.26% covered out of 8977
# 		Make capital-gain = 3103 with effectiveness 20.14% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 27.47% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 32.24% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 43.88% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 45.95% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 80.47% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.39.
# If capital-gain = 0, capital-loss = 0, marital-status =  Never-married, occupation =  Other-service:
# 	Protected Subgroup ' Non-White', 7.86% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 0.77% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 0.77% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 0.77% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Protective-serv with effectiveness 0.77% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 2.31% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support with effectiveness 2.31% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 3.08% and counterfactual cost = 2.0.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 59.23% and counterfactual cost = 2.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 100.00% and counterfactual cost = 2.15.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 100.00% and counterfactual cost = 2.15.
# 	Protected Subgroup ' White', 6.24% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 0.18% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Protective-serv with effectiveness 0.36% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 0.54% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support with effectiveness 0.54% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 1.07% and counterfactual cost = 2.0.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 26.43% and counterfactual cost = 2.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 88.57% and counterfactual cost = 2.15.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 94.46% and counterfactual cost = 2.15.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.37.
# If capital-gain = 0, capital-loss = 0, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 74.83% covered out of 1653
# 		Make capital-gain = 3103 with effectiveness 10.43% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 17.14% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 21.42% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 33.63% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 36.14% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 83.10% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 83.10% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 83.10% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 83.10% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 86.52% covered out of 8977
# 		Make capital-gain = 3103 with effectiveness 19.74% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 26.88% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 31.53% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 43.11% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 45.18% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 80.04% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 80.04% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 80.04% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 80.04% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.3.
# If age = (16.999, 26.0], capital-gain = 0, capital-loss = 0, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 10.89% covered out of 1653
# 		Make age = (26.0, 34.0], relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make age = (34.0, 41.0], relationship =  Married with effectiveness 1.11% and counterfactual cost = 11.0.
# 		Make age = (34.0, 41.0], capital-gain = 7298, relationship =  Married with effectiveness 57.78% and counterfactual cost = 11.07.
# 		Make age = (34.0, 41.0], capital-gain = 15024, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.15.
# 	Protected Subgroup ' White', 13.24% covered out of 8977
# 		Make age = (26.0, 34.0], relationship =  Married with effectiveness 0.08% and counterfactual cost = 11.0.
# 		Make age = (34.0, 41.0], relationship =  Married with effectiveness 0.17% and counterfactual cost = 11.0.
# 		Make age = (34.0, 41.0], capital-gain = 7298, relationship =  Married with effectiveness 32.38% and counterfactual cost = 11.07.
# 		Make age = (34.0, 41.0], capital-gain = 15024, relationship =  Married with effectiveness 97.14% and counterfactual cost = 11.15.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.18.
# If age = (16.999, 26.0], capital-gain = 0, relationship =  Own-child:
# 	Protected Subgroup ' Non-White', 11.07% covered out of 1653
# 		Make age = (26.0, 34.0], relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make age = (34.0, 41.0], relationship =  Married with effectiveness 1.09% and counterfactual cost = 11.0.
# 		Make age = (34.0, 41.0], capital-gain = 7298, relationship =  Married with effectiveness 57.92% and counterfactual cost = 11.07.
# 		Make age = (34.0, 41.0], capital-gain = 15024, relationship =  Married with effectiveness 100.00% and counterfactual cost = 11.15.
# 	Protected Subgroup ' White', 13.57% covered out of 8977
# 		Make age = (26.0, 34.0], relationship =  Married with effectiveness 0.25% and counterfactual cost = 11.0.
# 		Make age = (34.0, 41.0], relationship =  Married with effectiveness 0.41% and counterfactual cost = 11.0.
# 		Make age = (34.0, 41.0], capital-gain = 7298, relationship =  Married with effectiveness 33.17% and counterfactual cost = 11.07.
# 		Make age = (34.0, 41.0], capital-gain = 15024, relationship =  Married with effectiveness 97.21% and counterfactual cost = 11.15.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.12.
# If capital-gain = 0, marital-status =  Never-married, native-country =  United-States, occupation =  Other-service:
# 	Protected Subgroup ' Non-White', 6.84% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving with effectiveness 0.88% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 1.77% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 1.77% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 1.77% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Protective-serv with effectiveness 1.77% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 3.54% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 3.54% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support with effectiveness 3.54% and counterfactual cost = 2.0.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 59.29% and counterfactual cost = 2.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 100.00% and counterfactual cost = 2.15.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 100.00% and counterfactual cost = 2.15.
# 	Protected Subgroup ' White', 5.75% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Transport-moving with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 0.19% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Protective-serv with effectiveness 0.39% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 0.58% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support with effectiveness 0.58% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 0.97% and counterfactual cost = 2.0.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 27.33% and counterfactual cost = 2.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 88.95% and counterfactual cost = 2.15.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 94.96% and counterfactual cost = 2.15.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.08.
# If capital-gain = 0:
# 	Protected Subgroup ' Non-White', 96.37% covered out of 1653
# 		Make capital-gain = 3103 with effectiveness 11.36% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 18.08% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 22.91% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 34.97% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 37.79% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 82.74% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 96.58% covered out of 8977
# 		Make capital-gain = 3103 with effectiveness 19.37% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 26.46% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 31.08% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 42.51% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 44.54% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 79.48% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.07.
# If capital-gain = 0, capital-loss = 0:
# 	Protected Subgroup ' Non-White', 94.13% covered out of 1653
# 		Make capital-gain = 3103 with effectiveness 10.80% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 17.48% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 22.30% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 34.38% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 37.08% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 82.46% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 82.46% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 82.46% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 82.46% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 93.72% covered out of 8977
# 		Make capital-gain = 3103 with effectiveness 18.97% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 25.89% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 30.39% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 41.76% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 43.79% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 79.04% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 79.04% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 79.04% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 79.04% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.05.
# If capital-loss = 0, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 77.80% covered out of 1653
# 		Make capital-loss = 1887 with effectiveness 14.31% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 14.46% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 14.93% and counterfactual cost = 0.45.
# 	Protected Subgroup ' White', 89.71% covered out of 8977
# 		Make capital-loss = 1887 with effectiveness 22.89% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 23.20% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 24.07% and counterfactual cost = 0.45.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.04.
# If capital-gain = 0, capital-loss = 0, marital-status =  Never-married, native-country =  United-States, occupation =  Other-service:
# 	Protected Subgroup ' Non-White', 6.59% covered out of 1653
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 0.92% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 0.92% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 0.92% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Protective-serv with effectiveness 0.92% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 2.75% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 2.75% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support with effectiveness 2.75% and counterfactual cost = 2.0.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 58.72% and counterfactual cost = 2.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 100.00% and counterfactual cost = 2.15.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 100.00% and counterfactual cost = 2.15.
# 	Protected Subgroup ' White', 5.64% covered out of 8977
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 0.20% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Protective-serv with effectiveness 0.40% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 0.59% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Tech-support with effectiveness 0.59% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 0.99% and counterfactual cost = 2.0.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 27.08% and counterfactual cost = 2.08.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 88.74% and counterfactual cost = 2.15.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 94.86% and counterfactual cost = 2.15.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 3.0.
# If capital-gain = 0, capital-loss = 0, occupation =  Other-service:
# 	Protected Subgroup ' Non-White', 18.21% covered out of 1653
# 		Make occupation =  Craft-repair with effectiveness 1.99% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 2.66% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 3.99% and counterfactual cost = 1.0.
# 		Make occupation =  Protective-serv with effectiveness 5.98% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 8.31% and counterfactual cost = 1.0.
# 		Make occupation =  Tech-support with effectiveness 8.64% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 10.30% and counterfactual cost = 1.0.
# 		Make capital-gain = 7688, occupation =  Prof-specialty with effectiveness 41.53% and counterfactual cost = 1.08.
# 		Make capital-gain = 15024, occupation =  Prof-specialty with effectiveness 90.03% and counterfactual cost = 1.15.
# 		Make capital-gain = 15024, occupation =  Exec-managerial with effectiveness 91.36% and counterfactual cost = 1.15.
# 	Protected Subgroup ' White', 11.98% covered out of 8977
# 		Make occupation =  Craft-repair with effectiveness 0.93% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 1.12% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 1.86% and counterfactual cost = 1.0.
# 		Make occupation =  Protective-serv with effectiveness 2.23% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 2.70% and counterfactual cost = 1.0.
# 		Make occupation =  Tech-support with effectiveness 2.79% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 4.93% and counterfactual cost = 1.0.
# 		Make capital-gain = 7688, occupation =  Prof-specialty with effectiveness 25.21% and counterfactual cost = 1.08.
# 		Make capital-gain = 15024, occupation =  Prof-specialty with effectiveness 70.70% and counterfactual cost = 1.15.
# 		Make capital-gain = 15024, occupation =  Exec-managerial with effectiveness 75.16% and counterfactual cost = 1.15.
# 	 Unfairness based on the Kolmogorov-Smirnov test = 2.97.

# %% [markdown]
# ## Fairness of Effectiveness at Recourse Budget -- Equal Effectiveness within Budget (Micro)

# %%
top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
    rules_with_cumulative_correctness,
    metric="max-upto-cost",
    sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
    top_count=top_count,
    cost_threshold = cost_budget,
    filter_sequence = [
        # "remove-contained",
        # "remove-fair-rules",
        # "remove-above-thr-cost"
        #"remove-below-thr",
        #"keep-only-min-change",
        
    ],
    params=params
)

print_recourse_report_cumulative(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    show_then_costs=True,
    correctness_metric = True
)
# Out:
# If capital-gain = 0, capital-loss = 0, education-num = 9, marital-status =  Married-civ-spouse, occupation =  Other-service:
# 	Protected Subgroup ' Non-White', 2.00% covered
# 		Make occupation =  Exec-managerial with effectiveness 57.58% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 57.58% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 66.67% and counterfactual cost = 21.0.
# 		Aggregate cost of the above recourses = 0.58
# 	Protected Subgroup ' White', 1.00% covered
# 		Make occupation =  Exec-managerial with effectiveness 17.78% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 17.78% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 37.78% and counterfactual cost = 21.0.
# 		Aggregate cost of the above recourses = 0.18
# 	Bias against  White. Unfairness score = 0.398.
# If Workclass =  Self-emp-not-inc, age = (34.0, 41.0]:
# 	Protected Subgroup ' Non-White', 1.03% covered
# 		Make Workclass =  Private with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make Workclass =  Local-gov with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make Workclass =  Private, age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Private, age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Self-emp-inc, age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Local-gov, age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  State-gov, age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  State-gov, age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.00
# 	Protected Subgroup ' White', 1.56% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.71% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 4.29% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 5.71% and counterfactual cost = 1.0.
# 		Make Workclass =  Local-gov with effectiveness 10.00% and counterfactual cost = 1.0.
# 		Make Workclass =  Private with effectiveness 14.29% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 26.43% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 30.00% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov, age = (50.0, 90.0] with effectiveness 30.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Local-gov, age = (50.0, 90.0] with effectiveness 30.00% and counterfactual cost = 2.0.
# 		Make Workclass =  State-gov, age = (41.0, 50.0] with effectiveness 30.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Private, age = (50.0, 90.0] with effectiveness 30.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0] with effectiveness 30.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Private, age = (41.0, 50.0] with effectiveness 30.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Self-emp-inc, age = (50.0, 90.0] with effectiveness 30.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0] with effectiveness 30.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0] with effectiveness 33.57% and counterfactual cost = 2.0.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0] with effectiveness 39.29% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.39
# 	Bias against  Non-White. Unfairness score = 0.393.
# If age = (26.0, 34.0], capital-loss = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 20.83% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 62.50% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 70.83% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.62
# 	Protected Subgroup ' White', 1.67% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 14.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 22.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 23.33% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 23.33% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 23.33% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 24.67% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 54.00% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.23
# 	Bias against  White. Unfairness score = 0.392.
# If age = (26.0, 34.0], capital-loss = 0, education-num = 9, hours-per-week = FullTime, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 20.83% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 62.50% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 70.83% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.62
# 	Protected Subgroup ' White', 1.66% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 14.09% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 22.15% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 23.49% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 23.49% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 23.49% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 24.83% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 54.36% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.23
# 	Bias against  White. Unfairness score = 0.39.
# If age = (26.0, 34.0], capital-loss = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 20.83% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 62.50% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 70.83% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.62
# 	Protected Subgroup ' White', 1.66% covered
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 14.09% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 22.15% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 23.49% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 23.49% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 23.49% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 24.83% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 54.36% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.23
# 	Bias against  White. Unfairness score = 0.39.
# If Workclass =  Self-emp-not-inc, age = (34.0, 41.0], capital-loss = 0:
# 	Protected Subgroup ' Non-White', 1.03% covered
# 		Make Workclass =  Private with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make Workclass =  Local-gov with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make Workclass =  Private, age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Private, age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Self-emp-inc, age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Local-gov, age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  State-gov, age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make Workclass =  State-gov, age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.00
# 	Protected Subgroup ' White', 1.47% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.76% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 3.79% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 5.30% and counterfactual cost = 1.0.
# 		Make Workclass =  Local-gov with effectiveness 9.09% and counterfactual cost = 1.0.
# 		Make Workclass =  Private with effectiveness 12.88% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 25.76% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov, age = (50.0, 90.0] with effectiveness 25.76% and counterfactual cost = 2.0.
# 		Make Workclass =  Local-gov, age = (50.0, 90.0] with effectiveness 25.76% and counterfactual cost = 2.0.
# 		Make Workclass =  State-gov, age = (41.0, 50.0] with effectiveness 25.76% and counterfactual cost = 2.0.
# 		Make Workclass =  Private, age = (50.0, 90.0] with effectiveness 25.76% and counterfactual cost = 2.0.
# 		Make Workclass =  Local-gov, age = (41.0, 50.0] with effectiveness 25.76% and counterfactual cost = 2.0.
# 		Make Workclass =  Private, age = (41.0, 50.0] with effectiveness 25.76% and counterfactual cost = 2.0.
# 		Make Workclass =  Self-emp-inc, age = (50.0, 90.0] with effectiveness 26.52% and counterfactual cost = 2.0.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0] with effectiveness 28.79% and counterfactual cost = 2.0.
# 		Make Workclass =  Federal-gov, age = (50.0, 90.0] with effectiveness 32.58% and counterfactual cost = 2.0.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0] with effectiveness 38.64% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.39
# 	Bias against  Non-White. Unfairness score = 0.386.
# If capital-loss = 0, education-num = 9, occupation =  Other-service, relationship =  Married:
# 	Protected Subgroup ' Non-White', 2.00% covered
# 		Make occupation =  Craft-repair with effectiveness 12.12% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 18.18% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 60.61% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 63.64% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 69.70% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 78.79% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 0.61
# 	Protected Subgroup ' White', 1.00% covered
# 		Make occupation =  Craft-repair with effectiveness 3.33% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 8.89% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 22.22% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 42.22% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 55.56% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 0.22
# 	Bias against  White. Unfairness score = 0.384.
# If capital-loss = 0, education-num = 9, marital-status =  Married-civ-spouse, occupation =  Other-service, relationship =  Married:
# 	Protected Subgroup ' Non-White', 2.00% covered
# 		Make occupation =  Craft-repair with effectiveness 12.12% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 18.18% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 60.61% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 60.61% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 63.64% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 69.70% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 78.79% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 0.61
# 	Protected Subgroup ' White', 1.00% covered
# 		Make occupation =  Craft-repair with effectiveness 3.33% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 8.89% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 22.22% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 22.22% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 42.22% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 55.56% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 0.22
# 	Bias against  White. Unfairness score = 0.384.
# If age = (26.0, 34.0], capital-gain = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.39% covered
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 60.87% and counterfactual cost = 3.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 60.87% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 60.87% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 69.57% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.61
# 	Protected Subgroup ' White', 1.63% covered
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 22.60% and counterfactual cost = 3.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 22.60% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 23.97% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 53.42% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.23
# 	Bias against  White. Unfairness score = 0.383.
# If age = (26.0, 34.0], capital-gain = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.39% covered
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 60.87% and counterfactual cost = 3.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 60.87% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 60.87% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 69.57% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.61
# 	Protected Subgroup ' White', 1.62% covered
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 22.76% and counterfactual cost = 3.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 22.76% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 24.14% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 53.79% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.23
# 	Bias against  White. Unfairness score = 0.381.
# If age = (26.0, 34.0], capital-gain = 0, education-num = 9, hours-per-week = FullTime, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.39% covered
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 60.87% and counterfactual cost = 3.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 60.87% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 60.87% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 69.57% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.61
# 	Protected Subgroup ' White', 1.62% covered
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 22.76% and counterfactual cost = 3.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 22.76% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 24.14% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 53.79% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.23
# 	Bias against  White. Unfairness score = 0.381.
# If capital-loss = 0, education-num = 9, marital-status =  Married-civ-spouse, occupation =  Other-service:
# 	Protected Subgroup ' Non-White', 2.06% covered
# 		Make occupation =  Craft-repair with effectiveness 11.76% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 17.65% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 58.82% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 58.82% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 58.82% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 58.82% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 61.76% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 67.65% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 76.47% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 0.59
# 	Protected Subgroup ' White', 1.07% covered
# 		Make occupation =  Craft-repair with effectiveness 3.12% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 8.33% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 21.88% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 21.88% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 21.88% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 21.88% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 21.88% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 40.62% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 53.12% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 0.22
# 	Bias against  White. Unfairness score = 0.369.
# If age = (41.0, 50.0], capital-loss = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, relationship =  Married:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 52.63% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime with effectiveness 52.63% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain with effectiveness 52.63% and counterfactual cost = 2.0.
# 		Make education-num = 10 with effectiveness 52.63% and counterfactual cost = 20.0.
# 		Make age = (50.0, 90.0], education-num = 10 with effectiveness 52.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, hours-per-week = OverTime with effectiveness 63.16% and counterfactual cost = 21.0.
# 		Make age = (50.0, 90.0], education-num = 10, hours-per-week = OverTime with effectiveness 63.16% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.53
# 	Protected Subgroup ' White', 1.77% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 12.58% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime with effectiveness 12.58% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain with effectiveness 15.72% and counterfactual cost = 2.0.
# 		Make education-num = 10 with effectiveness 15.72% and counterfactual cost = 20.0.
# 		Make age = (50.0, 90.0], education-num = 10 with effectiveness 15.72% and counterfactual cost = 21.0.
# 		Make education-num = 10, hours-per-week = OverTime with effectiveness 59.12% and counterfactual cost = 21.0.
# 		Make age = (50.0, 90.0], education-num = 10, hours-per-week = OverTime with effectiveness 59.12% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.16
# 	Bias against  White. Unfairness score = 0.369.
# If age = (41.0, 50.0], capital-loss = 0, education-num = 9, hours-per-week = FullTime, native-country =  United-States, relationship =  Married:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 52.63% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime with effectiveness 52.63% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain with effectiveness 52.63% and counterfactual cost = 2.0.
# 		Make education-num = 10 with effectiveness 52.63% and counterfactual cost = 20.0.
# 		Make age = (50.0, 90.0], education-num = 10 with effectiveness 52.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, hours-per-week = OverTime with effectiveness 63.16% and counterfactual cost = 21.0.
# 		Make age = (50.0, 90.0], education-num = 10, hours-per-week = OverTime with effectiveness 63.16% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.53
# 	Protected Subgroup ' White', 1.77% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 12.58% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime with effectiveness 12.58% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain with effectiveness 15.72% and counterfactual cost = 2.0.
# 		Make education-num = 10 with effectiveness 15.72% and counterfactual cost = 20.0.
# 		Make age = (50.0, 90.0], education-num = 10 with effectiveness 15.72% and counterfactual cost = 21.0.
# 		Make education-num = 10, hours-per-week = OverTime with effectiveness 59.12% and counterfactual cost = 21.0.
# 		Make age = (50.0, 90.0], education-num = 10, hours-per-week = OverTime with effectiveness 59.12% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.16
# 	Bias against  White. Unfairness score = 0.369.
# If age = (41.0, 50.0], capital-loss = 0, education-num = 9, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 52.63% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime with effectiveness 52.63% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain with effectiveness 52.63% and counterfactual cost = 2.0.
# 		Make education-num = 10 with effectiveness 52.63% and counterfactual cost = 20.0.
# 		Make age = (50.0, 90.0], education-num = 10 with effectiveness 52.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, hours-per-week = OverTime with effectiveness 63.16% and counterfactual cost = 21.0.
# 		Make age = (50.0, 90.0], education-num = 10, hours-per-week = OverTime with effectiveness 63.16% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.53
# 	Protected Subgroup ' White', 1.79% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 13.04% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime with effectiveness 13.04% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain with effectiveness 16.15% and counterfactual cost = 2.0.
# 		Make education-num = 10 with effectiveness 16.15% and counterfactual cost = 20.0.
# 		Make age = (50.0, 90.0], education-num = 10 with effectiveness 16.15% and counterfactual cost = 21.0.
# 		Make education-num = 10, hours-per-week = OverTime with effectiveness 59.01% and counterfactual cost = 21.0.
# 		Make age = (50.0, 90.0], education-num = 10, hours-per-week = OverTime with effectiveness 59.01% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.16
# 	Bias against  White. Unfairness score = 0.365.
# If age = (26.0, 34.0], education-num = 9, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make age = (41.0, 50.0] with effectiveness 4.17% and counterfactual cost = 1.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 20.83% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 62.50% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 70.83% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.62
# 	Protected Subgroup ' White', 1.74% covered
# 		Make age = (41.0, 50.0] with effectiveness 14.10% and counterfactual cost = 1.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 17.31% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 25.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 26.28% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 26.28% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 26.28% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 27.56% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 55.77% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.26
# 	Bias against  White. Unfairness score = 0.362.
# If age = (26.0, 34.0], education-num = 9, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make age = (41.0, 50.0] with effectiveness 4.17% and counterfactual cost = 1.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 20.83% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 62.50% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 70.83% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.62
# 	Protected Subgroup ' White', 1.73% covered
# 		Make age = (41.0, 50.0] with effectiveness 14.19% and counterfactual cost = 1.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 17.42% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 25.16% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 26.45% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 26.45% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 26.45% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 27.74% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 56.13% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.26
# 	Bias against  White. Unfairness score = 0.36.
# If age = (26.0, 34.0], education-num = 9, hours-per-week = FullTime, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.45% covered
# 		Make age = (41.0, 50.0] with effectiveness 4.17% and counterfactual cost = 1.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 20.83% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 62.50% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 62.50% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 62.50% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 70.83% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.62
# 	Protected Subgroup ' White', 1.73% covered
# 		Make age = (41.0, 50.0] with effectiveness 14.19% and counterfactual cost = 1.0.
# 		Make age = (34.0, 41.0], hours-per-week = OverTime with effectiveness 17.42% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = OverTime with effectiveness 25.16% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain with effectiveness 26.45% and counterfactual cost = 3.0.
# 		Make age = (34.0, 41.0], education-num = 10 with effectiveness 26.45% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10 with effectiveness 26.45% and counterfactual cost = 21.0.
# 		Make age = (34.0, 41.0], education-num = 10, hours-per-week = OverTime with effectiveness 27.74% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 10, hours-per-week = OverTime with effectiveness 56.13% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.26
# 	Bias against  White. Unfairness score = 0.36.
# If age = (41.0, 50.0], education-num = 9, hours-per-week = FullTime, marital-status =  Married-civ-spouse, native-country =  United-States, relationship =  Married:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 52.63% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime with effectiveness 52.63% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain with effectiveness 52.63% and counterfactual cost = 2.0.
# 		Make education-num = 10 with effectiveness 52.63% and counterfactual cost = 20.0.
# 		Make age = (50.0, 90.0], education-num = 10 with effectiveness 52.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, hours-per-week = OverTime with effectiveness 63.16% and counterfactual cost = 21.0.
# 		Make age = (50.0, 90.0], education-num = 10, hours-per-week = OverTime with effectiveness 63.16% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.53
# 	Protected Subgroup ' White', 1.79% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 13.66% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime with effectiveness 13.66% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain with effectiveness 16.77% and counterfactual cost = 2.0.
# 		Make education-num = 10 with effectiveness 16.77% and counterfactual cost = 20.0.
# 		Make age = (50.0, 90.0], education-num = 10 with effectiveness 16.77% and counterfactual cost = 21.0.
# 		Make education-num = 10, hours-per-week = OverTime with effectiveness 59.63% and counterfactual cost = 21.0.
# 		Make age = (50.0, 90.0], education-num = 10, hours-per-week = OverTime with effectiveness 59.63% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.17
# 	Bias against  White. Unfairness score = 0.359.
# If age = (41.0, 50.0], education-num = 9, hours-per-week = FullTime, native-country =  United-States, relationship =  Married:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 52.63% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime with effectiveness 52.63% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain with effectiveness 52.63% and counterfactual cost = 2.0.
# 		Make education-num = 10 with effectiveness 52.63% and counterfactual cost = 20.0.
# 		Make age = (50.0, 90.0], education-num = 10 with effectiveness 52.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, hours-per-week = OverTime with effectiveness 63.16% and counterfactual cost = 21.0.
# 		Make age = (50.0, 90.0], education-num = 10, hours-per-week = OverTime with effectiveness 63.16% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.53
# 	Protected Subgroup ' White', 1.79% covered
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 13.66% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], hours-per-week = OverTime with effectiveness 13.66% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain with effectiveness 16.77% and counterfactual cost = 2.0.
# 		Make education-num = 10 with effectiveness 16.77% and counterfactual cost = 20.0.
# 		Make age = (50.0, 90.0], education-num = 10 with effectiveness 16.77% and counterfactual cost = 21.0.
# 		Make education-num = 10, hours-per-week = OverTime with effectiveness 59.63% and counterfactual cost = 21.0.
# 		Make age = (50.0, 90.0], education-num = 10, hours-per-week = OverTime with effectiveness 59.63% and counterfactual cost = 22.0.
# 		Aggregate cost of the above recourses = 0.17
# 	Bias against  White. Unfairness score = 0.359.

# %% [markdown]
# # Gather all metrics in a table (under construction)

# %%
from facts.fairness_metrics_aggr import make_table, auto_budget_calculation

# %%
rules_with_atomic_correctness.keys() == rules_with_cumulative_correctness.keys()
# Out:
# True

# %%
thens1 = {ifc: {sg: (cov, sorted([t for t, _ in thens])) for sg, (cov, thens) in thencs.items()} for ifc, thencs in rules_with_atomic_correctness.items()}
thens2 = {ifc: {sg: (cov, sorted([t for t, _, _ in thens])) for sg, (cov, thens) in thencs.items()} for ifc, thencs in rules_with_cumulative_correctness.items()}

thens1 == thens2
# Out:
# True

# %%
rules_with_both = {}
for ifc, all_thens in rules_with_cumulative_correctness.items():
    new_all_thens = {}
    for sg, (cov, thens_cum) in all_thens.items():
        thens_atom = rules_with_atomic_correctness[ifc][sg][1]
        thens_atom_dict = {then: atom_cor for then, atom_cor in thens_atom}
        new_all_thens[sg] = (cov, [(then, thens_atom_dict[then], cumcor) for then, cumcor, _cost in thens_cum])
    rules_with_both[ifc] = new_all_thens

# %%
budgets = auto_budget_calculation(rules_with_cumulative_correctness, cor_thres=0.5, percentiles=[0.3, 0.6, 0.9])
budgets
# Out:
# [1.150241502415024, 10.150241502415025, 21.0]

# %%
df = make_table(
    rules_with_both,
    sensitive_attribute_vals=[" Non-White", " White"],
    effectiveness_thresholds=[0.3, 0.7],
    cost_budgets=budgets,
    params=params
)

# %%
# dropping 'weighted-average' and 'mean-cost-cinf'
df.drop(['weighted-average', 'mean-cost-cinf'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_71462/1608859965.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df.drop(['weighted-average', 'mean-cost-cinf'], axis=1, inplace=True)

# %% [markdown]
# ## 2-level index: Examples of usage

# %%
df["subgroup"]
# Out:
#                                                 subgroup
# 0                                       capital-loss = 0
# 1                                       capital-gain = 0
# 2                     capital-gain = 0, capital-loss = 0
# 3                        native-country =  United-States
# 4      capital-loss = 0, native-country =  United-States
# ...                                                  ...
# 16636  Workclass =  Private, age = (16.999, 26.0], ca...
# 16637  hours-per-week = PartTime, marital-status =  N...
# 16638  Workclass =  Private, hours-per-week = PartTim...
# 16639  Workclass =  Private, capital-gain = 0, capita...
# 16640  capital-gain = 0, hours-per-week = FullTime, n...
#
# [16641 rows x 1 columns]

# %%
df[('Equal Cost of Effectiveness(Macro)', 0.3), " Non-White"]
# Out:
# 0             inf
# 1        0.072981
# 2        0.072981
# 3             inf
# 4             inf
#            ...
# 16636         inf
# 16637         inf
# 16638         inf
# 16639         inf
# 16640         inf
# Name: ((Equal Cost of Effectiveness(Macro), 0.3),  Non-White), Length: 16641, dtype: float64

# %%
(df[('Equal Cost of Effectiveness(Macro)', 0.3), " White"] - df[('Equal Cost of Effectiveness(Macro)', 0.3), " Non-White"]).dropna().value_counts()
# Out:
#  0.000000     4555
#  inf           877
#  2.000000      650
# -inf           491
#  3.000000      243
#  0.150242      124
#  10.000000     110
#  4.000000       56
#  6.000000       39
#  8.000000       39
#  0.072981       33
#  0.077261       27
#  0.076881       26
# -2.000000       25
#  0.073361       20
# -0.072981       18
#  0.073361       15
#  0.031030       14
# -3.000000       14
#  0.007920       12
#  0.433196       11
# -0.433196       11
#  0.076881       10
#  1.000000        9
#  7.000000        9
# -0.077261        7
# -1.000000        7
#  0.029120        6
#  5.000000        6
# -6.000000        6
# -0.150242        6
#  0.021200        6
# -0.021200        5
# -8.000000        4
#  4.076881        4
#  0.076881        4
# -0.072981        4
#  0.433196        3
# -0.003900        3
#  0.020750        3
# -10.000000       3
#  0.003900        3
# -0.073361        3
#  4.150242        2
#  0.076881        2
#  0.072981        2
#  0.007920        2
#  0.029120        2
# -0.003900        2
# -4.000000        2
# -2.150242        1
# -0.031030        1
# -0.003900        1
#  2.150242        1
#  0.003444        1
#  0.012830        1
# -0.003900        1
# -0.076881        1
# dtype: int64

# %% [markdown]
# ## 3- Get ranking of subgroups based on metrics

# %%
#table of differences between Male and Female for each metric
diff = get_diff_table(df, sensitive_attribute_vals=[" White", " Non-White"], with_abs = True)
diff = diff.set_index('subgroup')
ranked = diff.drop(columns=[('Fair Effectiveness-Cost Trade-Off','bias')]).mask(diff == 0).rank(ascending = False,axis=0,method='dense')
ranked = ranked.replace(np.nan,"Fair")
# Out:
# /home/dimitrios/Desktop/Athena/FACTS/facts/facts/fairness_metrics_aggr.py:214: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   z = z.drop(columns=["Fair Effectiveness-Cost Trade-Off"])

# %%
ranked
# Out:
#                                                    (Equal Cost of Effectiveness(Macro), 0.3)  \
# subgroup
# capital-loss = 0                                                                        Fair
# capital-gain = 0                                                                        30.0
# capital-gain = 0, capital-loss = 0                                                      30.0
# native-country =  United-States                                                         Fair
# capital-loss = 0, native-country =  United-States                                       Fair
# ...                                                                                      ...
# Workclass =  Private, age = (16.999, 26.0], cap...                                      Fair
# hours-per-week = PartTime, marital-status =  Ne...                                      Fair
# Workclass =  Private, hours-per-week = PartTime...                                      Fair
# Workclass =  Private, capital-gain = 0, capital...                                      Fair
# capital-gain = 0, hours-per-week = FullTime, na...                                       1.0
#
#                                                    (Equal Cost of Effectiveness(Macro), 0.7)  \
# subgroup
# capital-loss = 0                                                                        Fair
# capital-gain = 0                                                                        Fair
# capital-gain = 0, capital-loss = 0                                                      Fair
# native-country =  United-States                                                         Fair
# capital-loss = 0, native-country =  United-States                                       Fair
# ...                                                                                      ...
# Workclass =  Private, age = (16.999, 26.0], cap...                                      Fair
# hours-per-week = PartTime, marital-status =  Ne...                                      Fair
# Workclass =  Private, hours-per-week = PartTime...                                      Fair
# Workclass =  Private, capital-gain = 0, capital...                                      Fair
# capital-gain = 0, hours-per-week = FullTime, na...                                      Fair
#
#                                                    (Equal Choice for Recourse, 0.3)  \
# subgroup
# capital-loss = 0                                                               Fair
# capital-gain = 0                                                               14.0
# capital-gain = 0, capital-loss = 0                                             14.0
# native-country =  United-States                                                Fair
# capital-loss = 0, native-country =  United-States                              Fair
# ...                                                                             ...
# Workclass =  Private, age = (16.999, 26.0], cap...                             Fair
# hours-per-week = PartTime, marital-status =  Ne...                             Fair
# Workclass =  Private, hours-per-week = PartTime...                             Fair
# Workclass =  Private, capital-gain = 0, capital...                             Fair
# capital-gain = 0, hours-per-week = FullTime, na...                             12.0
#
#                                                    (Equal Choice for Recourse, 0.7)  \
# subgroup
# capital-loss = 0                                                               Fair
# capital-gain = 0                                                               Fair
# capital-gain = 0, capital-loss = 0                                             Fair
# native-country =  United-States                                                Fair
# capital-loss = 0, native-country =  United-States                              Fair
# ...                                                                             ...
# Workclass =  Private, age = (16.999, 26.0], cap...                             Fair
# hours-per-week = PartTime, marital-status =  Ne...                             Fair
# Workclass =  Private, hours-per-week = PartTime...                             Fair
# Workclass =  Private, capital-gain = 0, capital...                             Fair
# capital-gain = 0, hours-per-week = FullTime, na...                             Fair
#
#                                                    Equal Effectiveness  \
# subgroup
# capital-loss = 0                                                4443.0
# capital-gain = 0                                                  Fair
# capital-gain = 0, capital-loss = 0                                Fair
# native-country =  United-States                                   Fair
# capital-loss = 0, native-country =  United-States               3827.0
# ...                                                                ...
# Workclass =  Private, age = (16.999, 26.0], cap...              7591.0
# hours-per-week = PartTime, marital-status =  Ne...              3188.0
# Workclass =  Private, hours-per-week = PartTime...              2238.0
# Workclass =  Private, capital-gain = 0, capital...              4550.0
# capital-gain = 0, hours-per-week = FullTime, na...               367.0
#
#                                                    (Equal Effectiveness within Budget, 1.150241502415024)  \
# subgroup
# capital-loss = 0                                                                                 12.0
# capital-gain = 0                                                                                 Fair
# capital-gain = 0, capital-loss = 0                                                               Fair
# native-country =  United-States                                                                  Fair
# capital-loss = 0, native-country =  United-States                                                10.0
# ...                                                                                               ...
# Workclass =  Private, age = (16.999, 26.0], cap...                                               Fair
# hours-per-week = PartTime, marital-status =  Ne...                                               Fair
# Workclass =  Private, hours-per-week = PartTime...                                               Fair
# Workclass =  Private, capital-gain = 0, capital...                                               Fair
# capital-gain = 0, hours-per-week = FullTime, na...                                               Fair
#
#                                                    (Equal Effectiveness within Budget, 10.150241502415025)  \
# subgroup
# capital-loss = 0                                                                               3009.0
# capital-gain = 0                                                                                 Fair
# capital-gain = 0, capital-loss = 0                                                               Fair
# native-country =  United-States                                                                  Fair
# capital-loss = 0, native-country =  United-States                                              2495.0
# ...                                                                                               ...
# Workclass =  Private, age = (16.999, 26.0], cap...                                               Fair
# hours-per-week = PartTime, marital-status =  Ne...                                               Fair
# Workclass =  Private, hours-per-week = PartTime...                                             1177.0
# Workclass =  Private, capital-gain = 0, capital...                                             2662.0
# capital-gain = 0, hours-per-week = FullTime, na...                                              154.0
#
#                                                    (Equal Effectiveness within Budget, 21.0)  \
# subgroup
# capital-loss = 0                                                                      4221.0
# capital-gain = 0                                                                        Fair
# capital-gain = 0, capital-loss = 0                                                      Fair
# native-country =  United-States                                                         Fair
# capital-loss = 0, native-country =  United-States                                     3604.0
# ...                                                                                      ...
# Workclass =  Private, age = (16.999, 26.0], cap...                                      Fair
# hours-per-week = PartTime, marital-status =  Ne...                                    2959.0
# Workclass =  Private, hours-per-week = PartTime...                                    1980.0
# Workclass =  Private, capital-gain = 0, capital...                                    4330.0
# capital-gain = 0, hours-per-week = FullTime, na...                                     209.0
#
#                                                    (Equal Cost of Effectiveness(Micro), 0.3)  \
# subgroup
# capital-loss = 0                                                                        Fair
# capital-gain = 0                                                                        31.0
# capital-gain = 0, capital-loss = 0                                                      31.0
# native-country =  United-States                                                         Fair
# capital-loss = 0, native-country =  United-States                                       Fair
# ...                                                                                      ...
# Workclass =  Private, age = (16.999, 26.0], cap...                                      Fair
# hours-per-week = PartTime, marital-status =  Ne...                                      Fair
# Workclass =  Private, hours-per-week = PartTime...                                      Fair
# Workclass =  Private, capital-gain = 0, capital...                                      Fair
# capital-gain = 0, hours-per-week = FullTime, na...                                       1.0
#
#                                                    (Equal Cost of Effectiveness(Micro), 0.7)  \
# subgroup
# capital-loss = 0                                                                        Fair
# capital-gain = 0                                                                        Fair
# capital-gain = 0, capital-loss = 0                                                      Fair
# native-country =  United-States                                                         Fair
# capital-loss = 0, native-country =  United-States                                       Fair
# ...                                                                                      ...
# Workclass =  Private, age = (16.999, 26.0], cap...                                      Fair
# hours-per-week = PartTime, marital-status =  Ne...                                      Fair
# Workclass =  Private, hours-per-week = PartTime...                                      Fair
# Workclass =  Private, capital-gain = 0, capital...                                      Fair
# capital-gain = 0, hours-per-week = FullTime, na...                                      Fair
#
#                                                    Equal(Conditional Mean Recourse)  \
# subgroup
# capital-loss = 0                                                             7890.0
# capital-gain = 0                                                             6430.0
# capital-gain = 0, capital-loss = 0                                           6370.0
# native-country =  United-States                                                Fair
# capital-loss = 0, native-country =  United-States                            7921.0
# ...                                                                             ...
# Workclass =  Private, age = (16.999, 26.0], cap...                           3169.0
# hours-per-week = PartTime, marital-status =  Ne...                             Fair
# Workclass =  Private, hours-per-week = PartTime...                           4750.0
# Workclass =  Private, capital-gain = 0, capital...                           3165.0
# capital-gain = 0, hours-per-week = FullTime, na...                           1558.0
#
#                                                    (Fair Effectiveness-Cost Trade-Off, value)
# subgroup
# capital-loss = 0                                                                       6536.0
# capital-gain = 0                                                                       6216.0
# capital-gain = 0, capital-loss = 0                                                     6200.0
# native-country =  United-States                                                          Fair
# capital-loss = 0, native-country =  United-States                                      5693.0
# ...                                                                                       ...
# Workclass =  Private, age = (16.999, 26.0], cap...                                    10155.0
# hours-per-week = PartTime, marital-status =  Ne...                                     4852.0
# Workclass =  Private, hours-per-week = PartTime...                                     3290.0
# Workclass =  Private, capital-gain = 0, capital...                                     5981.0
# capital-gain = 0, hours-per-week = FullTime, na...                                      755.0
#
# [16641 rows x 12 columns]

# %%
rev_bias_metrics = ['Equal Effectiveness', 'Equal Effectiveness within Budget']
comb_df = get_comb_df(df, ranked, diff, rev_bias_metrics, sensitive_attribute_vals=[" White", " Non-White"])
analysis_df, rank_analysis_df = get_analysis_dfs(comb_df, ranked, sensitive_attribute_vals=["White", "Non-White"])
# Out:
# /home/dimitrios/Desktop/Athena/FACTS/facts/facts/fairness_metrics_aggr.py:214: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   z = z.drop(columns=["Fair Effectiveness-Cost Trade-Off"])
# /home/dimitrios/Desktop/Athena/FACTS/facts/facts/fairness_metrics_aggr.py:416: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(total_row)

# %%
comb_df.head()
# Out:
#                                                   (Equal Cost of Effectiveness(Macro), 0.3)  \
#                                                                                        rank
# subgroup
# capital-loss = 0                                                                       Fair
# capital-gain = 0                                                                       30.0
# capital-gain = 0, capital-loss = 0                                                     30.0
# native-country =  United-States                                                        Fair
# capital-loss = 0, native-country =  United-States                                      Fair
#
#                                                                         \
#                                                     score bias against
# subgroup
# capital-loss = 0                                   0.0000         Fair
# capital-gain = 0                                   0.0212    Non-White
# capital-gain = 0, capital-loss = 0                 0.0212    Non-White
# native-country =  United-States                    0.0000         Fair
# capital-loss = 0, native-country =  United-States  0.0000         Fair
#
#                                                   (Equal Cost of Effectiveness(Macro), 0.7)  \
#                                                                                        rank
# subgroup
# capital-loss = 0                                                                       Fair
# capital-gain = 0                                                                       Fair
# capital-gain = 0, capital-loss = 0                                                     Fair
# native-country =  United-States                                                        Fair
# capital-loss = 0, native-country =  United-States                                      Fair
#
#                                                                       \
#                                                   score bias against
# subgroup
# capital-loss = 0                                    0.0         Fair
# capital-gain = 0                                    0.0         Fair
# capital-gain = 0, capital-loss = 0                  0.0         Fair
# native-country =  United-States                     0.0         Fair
# capital-loss = 0, native-country =  United-States   0.0         Fair
#
#                                                   (Equal Choice for Recourse, 0.3)  \
#                                                                               rank
# subgroup
# capital-loss = 0                                                              Fair
# capital-gain = 0                                                              14.0
# capital-gain = 0, capital-loss = 0                                            14.0
# native-country =  United-States                                               Fair
# capital-loss = 0, native-country =  United-States                             Fair
#
#                                                                       \
#                                                   score bias against
# subgroup
# capital-loss = 0                                    0.0         Fair
# capital-gain = 0                                    1.0    Non-White
# capital-gain = 0, capital-loss = 0                  1.0    Non-White
# native-country =  United-States                     0.0         Fair
# capital-loss = 0, native-country =  United-States   0.0         Fair
#
#                                                   (Equal Choice for Recourse, 0.7)  \
#                                                                               rank
# subgroup
# capital-loss = 0                                                              Fair
# capital-gain = 0                                                              Fair
# capital-gain = 0, capital-loss = 0                                            Fair
# native-country =  United-States                                               Fair
# capital-loss = 0, native-country =  United-States                             Fair
#
#                                                    ...  \
#                                                    ...
# subgroup                                           ...
# capital-loss = 0                                   ...
# capital-gain = 0                                   ...
# capital-gain = 0, capital-loss = 0                 ...
# native-country =  United-States                    ...
# capital-loss = 0, native-country =  United-States  ...
#
#                                                   (Equal Cost of Effectiveness(Micro), 0.3)  \
#                                                                                bias against
# subgroup
# capital-loss = 0                                                                       Fair
# capital-gain = 0                                                                  Non-White
# capital-gain = 0, capital-loss = 0                                                Non-White
# native-country =  United-States                                                        Fair
# capital-loss = 0, native-country =  United-States                                      Fair
#
#                                                   (Equal Cost of Effectiveness(Micro), 0.7)  \
#                                                                                        rank
# subgroup
# capital-loss = 0                                                                       Fair
# capital-gain = 0                                                                       Fair
# capital-gain = 0, capital-loss = 0                                                     Fair
# native-country =  United-States                                                        Fair
# capital-loss = 0, native-country =  United-States                                      Fair
#
#                                                                       \
#                                                   score bias against
# subgroup
# capital-loss = 0                                    0.0         Fair
# capital-gain = 0                                    0.0         Fair
# capital-gain = 0, capital-loss = 0                  0.0         Fair
# native-country =  United-States                     0.0         Fair
# capital-loss = 0, native-country =  United-States   0.0         Fair
#
#                                                   Equal(Conditional Mean Recourse)  \
#                                                                               rank
# subgroup
# capital-loss = 0                                                            7890.0
# capital-gain = 0                                                            6430.0
# capital-gain = 0, capital-loss = 0                                          6370.0
# native-country =  United-States                                               Fair
# capital-loss = 0, native-country =  United-States                           7921.0
#
#                                                                           \
#                                                       score bias against
# subgroup
# capital-loss = 0                                   0.000280        White
# capital-gain = 0                                   0.018996        White
# capital-gain = 0, capital-loss = 0                 0.020344        White
# native-country =  United-States                    0.000000         Fair
# capital-loss = 0, native-country =  United-States  0.000109        White
#
#                                                   Fair Effectiveness-Cost Trade-Off  \
#                                                                                rank
# subgroup
# capital-loss = 0                                                             6536.0
# capital-gain = 0                                                             6216.0
# capital-gain = 0, capital-loss = 0                                           6200.0
# native-country =  United-States                                                Fair
# capital-loss = 0, native-country =  United-States                            5693.0
#
#
#                                                       score bias against
# subgroup
# capital-loss = 0                                   0.078920    Non-White
# capital-gain = 0                                   0.083800    Non-White
# capital-gain = 0, capital-loss = 0                 0.084078    Non-White
# native-country =  United-States                    0.000000    Non-White
# capital-loss = 0, native-country =  United-States  0.091356    Non-White
#
# [5 rows x 36 columns]

# %%
analysis_df
# Out:
#                                                     Rank = 1 Count  \
# (Equal Cost of Effectiveness(Macro), 0.3)                     1368
# (Equal Cost of Effectiveness(Micro), 0.3)                     1368
# (Equal Cost of Effectiveness(Macro), 0.7)                      546
# (Equal Cost of Effectiveness(Micro), 0.7)                      546
# Equal(Conditional Mean Recourse)                              1274
# (Equal Effectiveness within Budget, 1.150241502...               1
# (Equal Effectiveness within Budget, 10.15024150...               1
# (Equal Effectiveness within Budget, 21.0)                        1
# (Equal Choice for Recourse, 0.7)                                 1
# (Equal Choice for Recourse, 0.3)                                 1
# Equal Effectiveness                                              1
# Fair Effectiveness-Cost Trade-Off                                1
# Total Count                                                   5109
#
#                                                     White bias against Count  \
# (Equal Cost of Effectiveness(Macro), 0.3)                               2372
# (Equal Cost of Effectiveness(Micro), 0.3)                               2377
# (Equal Cost of Effectiveness(Macro), 0.7)                               1001
# (Equal Cost of Effectiveness(Micro), 0.7)                               1001
# Equal(Conditional Mean Recourse)                                        8248
# (Equal Effectiveness within Budget, 1.150241502...                       142
# (Equal Effectiveness within Budget, 10.15024150...                      7229
# (Equal Effectiveness within Budget, 21.0)                               8724
# (Equal Choice for Recourse, 0.7)                                        1117
# (Equal Choice for Recourse, 0.3)                                        3554
# Equal Effectiveness                                                     5730
# Fair Effectiveness-Cost Trade-Off                                      10376
# Total Count                                                            51871
#
#                                                     Non-White bias against Count
# (Equal Cost of Effectiveness(Macro), 0.3)                                    616
# (Equal Cost of Effectiveness(Micro), 0.3)                                    616
# (Equal Cost of Effectiveness(Macro), 0.7)                                     51
# (Equal Cost of Effectiveness(Micro), 0.7)                                     51
# Equal(Conditional Mean Recourse)                                            5231
# (Equal Effectiveness within Budget, 1.150241502...                            59
# (Equal Effectiveness within Budget, 10.15024150...                          5189
# (Equal Effectiveness within Budget, 21.0)                                   5757
# (Equal Choice for Recourse, 0.7)                                              81
# (Equal Choice for Recourse, 0.3)                                             773
# Equal Effectiveness                                                         8931
# Fair Effectiveness-Cost Trade-Off                                           6265
# Total Count                                                                33620

# %%
rank_analysis_df
# Out:
#                                                     Fair Effectiveness-Cost Trade-Off  \
# Fair Effectiveness-Cost Trade-Off                                                 1.0
# (Equal Effectiveness within Budget, 21.0)                                        40.0
# (Equal Choice for Recourse, 0.7)                                                808.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                      1768.8
# (Equal Cost of Effectiveness(Macro), 0.7)                                      1768.8
# (Equal Effectiveness within Budget, 1.150241502...                             3464.0
# (Equal Effectiveness within Budget, 10.15024150...                               40.0
# (Equal Choice for Recourse, 0.3)                                                227.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                      2964.2
# (Equal Cost of Effectiveness(Macro), 0.3)                                      2964.2
# Equal(Conditional Mean Recourse)                                              10357.6
# Equal Effectiveness                                                               1.0
#
#                                                     (Equal Effectiveness within Budget, 21.0)  \
# Fair Effectiveness-Cost Trade-Off                                                     12311.0
# (Equal Effectiveness within Budget, 21.0)                                                 1.0
# (Equal Choice for Recourse, 0.7)                                                        237.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                              2400.4
# (Equal Cost of Effectiveness(Macro), 0.7)                                              2400.4
# (Equal Effectiveness within Budget, 1.150241502...                                     1841.0
# (Equal Effectiveness within Budget, 10.15024150...                                        1.0
# (Equal Choice for Recourse, 0.3)                                                        621.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                              3237.7
# (Equal Cost of Effectiveness(Macro), 0.3)                                              3237.7
# Equal(Conditional Mean Recourse)                                                       8191.8
# Equal Effectiveness                                                                   12311.0
#
#                                                     (Equal Choice for Recourse, 0.7)  \
# Fair Effectiveness-Cost Trade-Off                                               10.0
# (Equal Effectiveness within Budget, 21.0)                                       11.0
# (Equal Choice for Recourse, 0.7)                                                 1.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                        9.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                        9.0
# (Equal Effectiveness within Budget, 1.150241502...                              10.0
# (Equal Effectiveness within Budget, 10.15024150...                              11.0
# (Equal Choice for Recourse, 0.3)                                                10.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                       11.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                       11.0
# Equal(Conditional Mean Recourse)                                                11.0
# Equal Effectiveness                                                             10.0
#
#                                                     (Equal Cost of Effectiveness(Micro), 0.7)  \
# Fair Effectiveness-Cost Trade-Off                                                         1.0
# (Equal Effectiveness within Budget, 21.0)                                                24.0
# (Equal Choice for Recourse, 0.7)                                                          3.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                 1.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                                 1.0
# (Equal Effectiveness within Budget, 1.150241502...                                        1.0
# (Equal Effectiveness within Budget, 10.15024150...                                       24.0
# (Equal Choice for Recourse, 0.3)                                                          1.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                                23.9
# (Equal Cost of Effectiveness(Macro), 0.3)                                                23.9
# Equal(Conditional Mean Recourse)                                                         24.0
# Equal Effectiveness                                                                       1.0
#
#                                                     (Equal Cost of Effectiveness(Macro), 0.7)  \
# Fair Effectiveness-Cost Trade-Off                                                         1.0
# (Equal Effectiveness within Budget, 21.0)                                                24.0
# (Equal Choice for Recourse, 0.7)                                                          3.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                 1.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                                 1.0
# (Equal Effectiveness within Budget, 1.150241502...                                        1.0
# (Equal Effectiveness within Budget, 10.15024150...                                       24.0
# (Equal Choice for Recourse, 0.3)                                                          1.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                                23.9
# (Equal Cost of Effectiveness(Macro), 0.3)                                                23.9
# Equal(Conditional Mean Recourse)                                                         24.0
# Equal Effectiveness                                                                       1.0
#
#                                                     (Equal Effectiveness within Budget, 1.150241502415024)  \
# Fair Effectiveness-Cost Trade-Off                                                               182.0
# (Equal Effectiveness within Budget, 21.0)                                                       182.0
# (Equal Choice for Recourse, 0.7)                                                                182.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                       180.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                                       180.0
# (Equal Effectiveness within Budget, 1.150241502...                                                1.0
# (Equal Effectiveness within Budget, 10.15024150...                                              182.0
# (Equal Choice for Recourse, 0.3)                                                                182.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                                       181.2
# (Equal Cost of Effectiveness(Macro), 0.3)                                                       181.2
# Equal(Conditional Mean Recourse)                                                                182.0
# Equal Effectiveness                                                                             182.0
#
#                                                     (Equal Effectiveness within Budget, 10.150241502415025)  \
# Fair Effectiveness-Cost Trade-Off                                                             10535.0
# (Equal Effectiveness within Budget, 21.0)                                                         1.0
# (Equal Choice for Recourse, 0.7)                                                                924.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                      2586.2
# (Equal Cost of Effectiveness(Macro), 0.7)                                                      2586.2
# (Equal Effectiveness within Budget, 1.150241502...                                             1273.0
# (Equal Effectiveness within Budget, 10.15024150...                                                1.0
# (Equal Choice for Recourse, 0.3)                                                                 15.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                                      4421.6
# (Equal Cost of Effectiveness(Macro), 0.3)                                                      4421.6
# Equal(Conditional Mean Recourse)                                                               8340.9
# Equal Effectiveness                                                                           10535.0
#
#                                                     (Equal Choice for Recourse, 0.3)  \
# Fair Effectiveness-Cost Trade-Off                                               12.0
# (Equal Effectiveness within Budget, 21.0)                                       14.0
# (Equal Choice for Recourse, 0.7)                                                15.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                       12.5
# (Equal Cost of Effectiveness(Macro), 0.7)                                       12.5
# (Equal Effectiveness within Budget, 1.150241502...                              15.0
# (Equal Effectiveness within Budget, 10.15024150...                              14.0
# (Equal Choice for Recourse, 0.3)                                                 1.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                       13.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                       13.0
# Equal(Conditional Mean Recourse)                                                15.0
# Equal Effectiveness                                                             12.0
#
#                                                     (Equal Cost of Effectiveness(Micro), 0.3)  \
# Fair Effectiveness-Cost Trade-Off                                                         1.0
# (Equal Effectiveness within Budget, 21.0)                                                 1.0
# (Equal Choice for Recourse, 0.7)                                                         41.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                27.7
# (Equal Cost of Effectiveness(Macro), 0.7)                                                27.7
# (Equal Effectiveness within Budget, 1.150241502...                                       41.0
# (Equal Effectiveness within Budget, 10.15024150...                                        1.0
# (Equal Choice for Recourse, 0.3)                                                         10.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                                 1.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                                 1.0
# Equal(Conditional Mean Recourse)                                                         40.5
# Equal Effectiveness                                                                       1.0
#
#                                                     (Equal Cost of Effectiveness(Macro), 0.3)  \
# Fair Effectiveness-Cost Trade-Off                                                         1.0
# (Equal Effectiveness within Budget, 21.0)                                                 1.0
# (Equal Choice for Recourse, 0.7)                                                         40.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                26.7
# (Equal Cost of Effectiveness(Macro), 0.7)                                                26.7
# (Equal Effectiveness within Budget, 1.150241502...                                       40.0
# (Equal Effectiveness within Budget, 10.15024150...                                        1.0
# (Equal Choice for Recourse, 0.3)                                                          9.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                                 1.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                                 1.0
# Equal(Conditional Mean Recourse)                                                         39.5
# Equal Effectiveness                                                                       1.0
#
#                                                     Equal(Conditional Mean Recourse)  \
# Fair Effectiveness-Cost Trade-Off                                             7972.0
# (Equal Effectiveness within Budget, 21.0)                                        1.0
# (Equal Choice for Recourse, 0.7)                                              5238.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                     4056.1
# (Equal Cost of Effectiveness(Macro), 0.7)                                     4056.1
# (Equal Effectiveness within Budget, 1.150241502...                            7972.0
# (Equal Effectiveness within Budget, 10.15024150...                               1.0
# (Equal Choice for Recourse, 0.3)                                               733.0
# (Equal Cost of Effectiveness(Micro), 0.3)                                     4129.4
# (Equal Cost of Effectiveness(Macro), 0.3)                                     4129.4
# Equal(Conditional Mean Recourse)                                                 1.0
# Equal Effectiveness                                                           7972.0
#
#                                                     Equal Effectiveness
# Fair Effectiveness-Cost Trade-Off                                   1.0
# (Equal Effectiveness within Budget, 21.0)                          27.0
# (Equal Choice for Recourse, 0.7)                                  399.0
# (Equal Cost of Effectiveness(Micro), 0.7)                        2161.4
# (Equal Cost of Effectiveness(Macro), 0.7)                        2161.4
# (Equal Effectiveness within Budget, 1.150241502...               2100.0
# (Equal Effectiveness within Budget, 10.15024150...                 27.0
# (Equal Choice for Recourse, 0.3)                                  861.0
# (Equal Cost of Effectiveness(Micro), 0.3)                        2214.3
# (Equal Cost of Effectiveness(Macro), 0.3)                        2214.3
# Equal(Conditional Mean Recourse)                                 8347.7
# Equal Effectiveness                                                 1.0

# %%
#top_rank = ranked[(ranked[('mincost-above-th', 0.7)]==1) | (ranked[('number-above-th', 0.7)]==1) |  (ranked['total-effectiveness']==1) | (ranked['total-effectiveness']==1) | (ranked[('eff-within-budget', 10.0)]==1) | (ranked[('eff-within-budget', 18.0)]==1) | (ranked[('eff-within-budget', 5.076880768807688)]==1) | (ranked[('cost-of-effectiveness', 0.7)]==1) | (ranked[('cost-of-effectiveness', 0.3)]==1) | (ranked[('KStest', 'value')]==1)]

# %%
# ranked_indexed = top_rank.set_index([top_rank.index, "subgroup"])
# ranked_fair = ranked_indexed == 'Fair'
# ranked_more_than_2000 = ranked_indexed.mask(ranked_indexed=='Fair') >= 1000
# new_rank = ranked_indexed[ranked_fair.apply(lambda row: row.sum() >=4 , axis=1) | ranked_more_than_2000.apply(lambda row : row.sum() >= 6,axis=1)]
# new_rank.head()

# %%
# sgs = [
#     ranked.iloc[9841].subgroup,
# ]

# rules_sgs_atomic = {ifc: rules_with_atomic_correctness[ifc] for ifc in sgs}
# rules_sgs_cumulative = {ifc: rules_with_cumulative_correctness[ifc] for ifc in sgs}

# %%
# df.iloc[4228].to_frame().T

# %%
# top_rules, subgroup_costs = facts.select_rules_subset(
#     rules_sgs_atomic,
#     metric="min-above-thr",
#     sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
#     cor_threshold=0.7,
#     filter_sequence = [
#         # "remove-contained",
#         "remove-below-thr",        
#         #"remove-fair-rules", 
#         "keep-only-min-change"
#     ],
#     params=params
# )

# print_recourse_report(
#     top_rules,
#     subgroup_costs=subgroup_costs,
#     show_subgroup_costs=True
# )

# %%
# top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
#     rules_sgs_cumulative,
#     metric="max-upto-cost",
#     sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
#     top_count=top_count,
#     cost_threshold = 10,
#     filter_sequence = [
#         # "remove-contained",
#         # "remove-fair-rules",
#         "keep-cheap-rules-above-thr-cor",
#         # "keep-only-min-change",
        
#     ],
#     params=params
# )

# print_recourse_report_cumulative(
#     top_rules,
#     subgroup_costs=subgroup_costs,
#     show_subgroup_costs=True,
#     show_then_costs=True,
#     correctness_metric=True
# )
