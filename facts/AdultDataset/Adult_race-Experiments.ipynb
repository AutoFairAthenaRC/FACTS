# %% [markdown]
# Datasets used:
# - `adult (Adult)` :<br>The UCI Adult dataset contains 14 features, which can be divided into two categories: demographic and income-related.<br> The demographic features include:
#
#     age: continuous.<br>
#     fnlwgt : continuous, represents final weight, which is the number of units in the target population that the responding unit represents.<br>
#     workclass: categorical, with values 'Private', 'Local-gov', 'Self-emp-not-inc', 'Federal-gov', 'State-gov', 'Self-emp-inc', 'Without-pay'.<br>
#     education: categorical, with values '11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th', ..., '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'.<br>
#     education-num: continuous with values 1 to 16, one number assigned to each label of education feature.<br>
#     marital-status: categorical, with values 'Never-married', 'Married-civ-spouse', 'Widowed', 'Separated', 'Divorced', 'Married-spouse-absent', 'Married-AF-spouse'.<br>
#     occupation: categorical, with values such as 'Machine-op-inspct', 'Farming-fishing', 'Protective-serv'.<br>
#     relationship: categorical, with values 'Own-child', 'Husband', 'Not-in-family', 'Unmarried', 'Wife', 'Other-relative'.<br>
#     race: categorical, with values such as white, black, and Asian.<br>
#     sex: categorical, with values male and female.<br>
#
#     The income-related features include:<br>
#
#     hours-per-week: continuous.<br>
#     native-country: categorical, with values such as United-States, Mexico, and Germany.<br>
#     capital-gain: continuous, represent the amount of money an individual has gained from the sale of investments such as stocks, bonds, or real estate.<br>
#     capital-loss: continuous, represent the amount of money an individual has lost from the sale of investments such as stocks, bonds, or real estate..<br>
#     The target feature is the income, which is binary:<br>
#     income: categorical, with values less than or equal to 50K and greater than 50K.<br>
#
# Reference Links: https://archive.ics.uci.edu/ml/datasets/adult

# %%
import pandas as pd
import numpy as np

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')
import facts
from facts.clean import clean_dataset
from facts import valid_ifthens_with_coverage_correctness, rules2rulesbyif
from facts.models import customLogisticRegression
from facts.parameters import ParameterProxy
from facts.formatting import recourse_report_reverse, print_recourse_report, print_recourse_report_cumulative, print_recourse_report_KStest_cumulative
from facts.utils import load_rules_by_if
from facts.fairness_metrics_aggr import get_diff_table, get_comb_df, get_analysis_dfs

# %%
cost_budget = 10
top_count = 20
c_inf = 5

# %% [markdown]
# # Dataset

# %%
urlfile= "https://raw.githubusercontent.com/columbia/fairtest/master/data/adult/adult.csv"

X = pd.read_csv(urlfile)
df = clean_dataset(X, "adult")

age = [val.left for val in df.age.unique()]
age.sort()

df.head()
# Out:
#             age          Workclass  education-num       marital-status  \
# 0  (34.0, 41.0]          State-gov             13        Never-married
# 1  (41.0, 50.0]   Self-emp-not-inc             13   Married-civ-spouse
# 2  (34.0, 41.0]            Private              9             Divorced
# 3  (50.0, 90.0]            Private              7   Married-civ-spouse
# 4  (26.0, 34.0]            Private             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Married   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Married   Black     Male             0
# 4      Prof-specialty         Married   Black   Female             0
#
#    capital-loss hours-per-week  native-country  income
# 0             0       FullTime   United-States       0
# 1             0       PartTime   United-States       0
# 2             0       FullTime   United-States       0
# 3             0       FullTime   United-States       0
# 4             0       FullTime            Cuba       0

# %%
y = df['income']
X = df.drop('income', axis=1)

num_features = X._get_numeric_data().columns.to_list()
cate_features = X.select_dtypes(include=['object','category']).columns.to_list()
ord_features = ['hours-per-week']

# %% [markdown]
# # Rules

# %%
rules_with_atomic_correctness, Xtest, model = load_rules_by_if("rules-Xtest-model-2_race (seed 131313).data")
rules_with_cumulative_correctness = load_rules_by_if("rulesAdultFairTest_race_cumulative (seed 131313).data")

# %%
feature_weights = {"race" : 100 , "sex": 100, "marital-status": 5, "relationship":5, "age": 10, "occupation": 4, "Workclass": 2, "native-country": 4,
                    "hours-per-week":2, "capital-gain": 1, "capital-loss":1, "education-num": 3}
features_with_binary_cost = cate_features
features_with_proportional_cost = num_features


comparators = facts.feature_change_builder(
    X,
    num_cols=features_with_proportional_cost,
    cate_cols=features_with_binary_cost,
    ord_cols=ord_features,
    feature_weights=feature_weights,
    num_normalization=True,
    feats_to_normalize = ["capital-gain","capital-loss"]
)
params = ParameterProxy(featureChanges=comparators)

# %% [markdown]
# # Macro Viewpoint

# %% [markdown]
# ## Equal Cost of Effectiveness (Macro)

# %%
top_rules, subgroup_costs = facts.select_rules_subset(
    rules_with_atomic_correctness,
    metric="min-above-thr",
    sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
    top_count=top_count,
    cor_threshold=0.7,
    filter_sequence = [
        "remove-contained",
        "remove-below-thr",        
        "remove-fair-rules",
        "keep-only-min-change"
    ],
    params=params
)

print_recourse_report(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    metric_name = 'Equal Cost of Effectiveness (Macro) (threshold = 0.7)'
)
# Out:
# If age = (26.0, 34.0], marital-status =  Never-married, occupation =  Prof-specialty, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 80.00%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 80.00%.
# 		Aggregate cost of the above recourses = 20.00
# 	Protected Subgroup ' White', 1.18% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 75.47%.
# 		Aggregate cost of the above recourses = 10.00
# 	Bias against  Non-White due to Equal Cost of Effectiveness (Macro) (threshold = 0.7). Unfairness score = 10.
# If age = (26.0, 34.0], education-num = 13, marital-status =  Never-married, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.78% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 87.10%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 80.65%.
# 		Aggregate cost of the above recourses = 20.00
# 	Protected Subgroup ' White', 1.66% covered
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 84.67%.
# 		Aggregate cost of the above recourses = 13.00
# 	Bias against  Non-White due to Equal Cost of Effectiveness (Macro) (threshold = 0.7). Unfairness score = 7.
# If Workclass =  Private, marital-status =  Never-married, occupation =  Prof-specialty, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.43% covered
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 72.00%.
# 		Aggregate cost of the above recourses = 12.00
# 	Protected Subgroup ' White', 2.17% covered
# 		Make Workclass =  Federal-gov, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 72.45%.
# 		Aggregate cost of the above recourses = 16.00
# 	Bias against  White due to Equal Cost of Effectiveness (Macro) (threshold = 0.7). Unfairness score = 4.
# If education-num = 9, marital-status =  Married-civ-spouse, occupation =  Transport-moving, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.78% covered
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 70.97%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 2.00% covered
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 70.56%.
# 		Aggregate cost of the above recourses = 7.00
# 	Bias against  Non-White due to Equal Cost of Effectiveness (Macro) (threshold = 0.7). Unfairness score = 3.
# If education-num = 9, occupation =  Transport-moving, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.78% covered
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 70.97%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 1.97% covered
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 71.35%.
# 		Aggregate cost of the above recourses = 7.00
# 	Bias against  Non-White due to Equal Cost of Effectiveness (Macro) (threshold = 0.7). Unfairness score = 3.
# If education-num = 13, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.66% covered
# 		Make education-num = 14, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 72.41%.
# 		Aggregate cost of the above recourses = 15.00
# 	Protected Subgroup ' White', 2.32% covered
# 		Make education-num = 15, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 80.38%.
# 		Aggregate cost of the above recourses = 18.00
# 	Bias against  White due to Equal Cost of Effectiveness (Macro) (threshold = 0.7). Unfairness score = 3.
# If education-num = 9, marital-status =  Married-civ-spouse, native-country =  United-States, occupation =  Transport-moving, relationship =  Married:
# 	Protected Subgroup ' Non-White', 1.55% covered
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 70.37%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 1.93% covered
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 71.84%.
# 		Aggregate cost of the above recourses = 7.00
# 	Bias against  Non-White due to Equal Cost of Effectiveness (Macro) (threshold = 0.7). Unfairness score = 3.
# If capital-loss = 0, education-num = 9, native-country =  United-States, occupation =  Transport-moving, relationship =  Married:
# 	Protected Subgroup ' Non-White', 1.55% covered
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 70.37%.
# 		Aggregate cost of the above recourses = 10.00
# 	Protected Subgroup ' White', 1.89% covered
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 71.18%.
# 		Aggregate cost of the above recourses = 7.00
# 	Bias against  Non-White due to Equal Cost of Effectiveness (Macro) (threshold = 0.7). Unfairness score = 3.0.

# %% [markdown]
# ## Equal Choice for Recourse

# %%
top_rules, subgroup_costs = facts.select_rules_subset(
    rules_with_atomic_correctness,
    metric="num-above-thr",
    sort_strategy="generic-sorting-ignore-forall-subgroups-empty",
    top_count=top_count,
    cor_threshold=0.7,
    filter_sequence = [
        "remove-contained",
        "remove-below-thr",
        "remove-fair-rules"
    ],
    params=params
)

print_recourse_report(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    metric_name = 'Equal Choice for Recourse(Macro) (threshold = 0.7)'
)
# Out:
# If age = (26.0, 34.0], marital-status =  Never-married, occupation =  Prof-specialty, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.15% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 90.00%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 80.00%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 80.00%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 80.00%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 80.00%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 80.00%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 70.00%.
# 		Aggregate cost of the above recourses = -7.00
# 	Protected Subgroup ' White', 1.18% covered
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 93.40%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 89.62%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 88.68%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 85.85%.
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 75.47%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 85.85%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Sales, relationship =  Married with effectiveness 83.02%.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 83.02%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 82.08%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 83.02%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Craft-repair, relationship =  Married with effectiveness 75.47%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Adm-clerical, relationship =  Married with effectiveness 80.19%.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 88.68%.
# 		Make age = (34.0, 41.0], marital-status =  Married-civ-spouse, occupation =  Tech-support, relationship =  Married with effectiveness 84.91%.
# 		Aggregate cost of the above recourses = -14.00
# 	Bias against  Non-White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 7.
# If capital-gain = 0, capital-loss = 0, marital-status =  Divorced, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 5.39% covered
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 81.91%.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 81.91%.
# 		Make capital-gain = 99999, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -4.00
# 	Protected Subgroup ' White', 8.81% covered
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 94.21%.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 93.83%.
# 		Make capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 71.03%.
# 		Make capital-loss = 1977, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 71.91%.
# 		Make capital-loss = 1887, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 71.03%.
# 		Make capital-gain = 99999, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 5178, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 83.63%.
# 		Make capital-gain = 4386, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 77.46%.
# 		Aggregate cost of the above recourses = -9.00
# 	Bias against  Non-White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 5.
# If capital-gain = 0, capital-loss = 0, hours-per-week = FullTime, marital-status =  Widowed:
# 	Protected Subgroup ' Non-White', 2.24% covered
# 		Make capital-gain = 15024, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse with effectiveness 97.44%.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -3.00
# 	Protected Subgroup ' White', 1.19% covered
# 		Make capital-gain = 15024, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Make capital-gain = 7688, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 82.24%.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse with effectiveness 73.83%.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse with effectiveness 71.03%.
# 		Make capital-gain = 7298, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 80.37%.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -7.00
# 	Bias against  Non-White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 4.
# If capital-gain = 0, hours-per-week = FullTime, marital-status =  Widowed, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 2.07% covered
# 		Make capital-gain = 15024, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse with effectiveness 97.22%.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -3.00
# 	Protected Subgroup ' White', 1.08% covered
# 		Make capital-gain = 15024, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Make capital-gain = 7688, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 83.51%.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Make capital-gain = 7688, marital-status =  Married-civ-spouse with effectiveness 76.29%.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse with effectiveness 74.23%.
# 		Make capital-gain = 7298, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 81.44%.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -7.00
# 	Bias against  Non-White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 4.
# If Workclass =  Private, age = (26.0, 34.0], hours-per-week = FullTime, marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.89% covered
# 		No recourses for this subgroup!
# 		Aggregate cost of the above recourses = 0.00
# 	Protected Subgroup ' White', 2.22% covered
# 		Make age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 70.00%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 76.00%.
# 		Make Workclass =  Federal-gov, age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 74.50%.
# 		Make Workclass =  Self-emp-inc, age = (41.0, 50.0], hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 79.50%.
# 		Aggregate cost of the above recourses = -4.00
# 	Bias against  Non-White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 4.
# If education-num = 13, marital-status =  Never-married, occupation =  Prof-specialty, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.26% covered
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 72.73%.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 72.73%.
# 		Make education-num = 15, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 86.36%.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, occupation =  Exec-managerial, relationship =  Married with effectiveness 81.82%.
# 		Aggregate cost of the above recourses = -4.00
# 	Protected Subgroup ' White', 1.53% covered
# 		No recourses for this subgroup!
# 		Aggregate cost of the above recourses = 0.00
# 	Bias against  White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 4.
# If capital-gain = 0, hours-per-week = PartTime, marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make capital-gain = 15024, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 15024, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -3.00
# 	Protected Subgroup ' White', 1.44% covered
# 		Make capital-gain = 15024, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 7688, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 86.15%.
# 		Make capital-gain = 15024, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 7688, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 79.23%.
# 		Make capital-gain = 7298, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 76.15%.
# 		Make capital-gain = 7298, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 83.85%.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -7.00
# 	Bias against  Non-White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 4.
# If capital-gain = 0, capital-loss = 0, hours-per-week = PartTime, marital-status =  Never-married, native-country =  United-States, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make capital-gain = 15024, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 15024, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -3.00
# 	Protected Subgroup ' White', 1.36% covered
# 		Make capital-gain = 15024, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 7688, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 85.37%.
# 		Make capital-gain = 15024, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Make capital-gain = 7688, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 78.05%.
# 		Make capital-gain = 7298, hours-per-week = FullTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 74.80%.
# 		Make capital-gain = 7298, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 82.93%.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -7.00
# 	Bias against  Non-White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 4.
# If capital-gain = 0, hours-per-week = FullTime, native-country =  United-States, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 11.65% covered
# 		Make capital-gain = 15024, hours-per-week = OverTime, relationship =  Married with effectiveness 99.51%.
# 		Make capital-gain = 15024, relationship =  Married with effectiveness 98.52%.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain, relationship =  Married with effectiveness 99.51%.
# 		Aggregate cost of the above recourses = -3.00
# 	Protected Subgroup ' White', 4.74% covered
# 		Make capital-gain = 15024, hours-per-week = OverTime, relationship =  Married with effectiveness 99.77%.
# 		Make capital-gain = 7688, hours-per-week = OverTime, relationship =  Married with effectiveness 79.63%.
# 		Make capital-gain = 15024, relationship =  Married with effectiveness 99.77%.
# 		Make capital-gain = 7688, relationship =  Married with effectiveness 70.49%.
# 		Make capital-gain = 7298, hours-per-week = OverTime, relationship =  Married with effectiveness 76.35%.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain, relationship =  Married with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -6.00
# 	Bias against  Non-White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 3.
# If capital-loss = 0, marital-status =  Divorced, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 5.57% covered
# 		No recourses for this subgroup!
# 		Aggregate cost of the above recourses = 0.00
# 	Protected Subgroup ' White', 9.21% covered
# 		Make capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 72.05%.
# 		Make capital-loss = 1977, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 73.01%.
# 		Make capital-loss = 1887, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 72.05%.
# 		Aggregate cost of the above recourses = -3.00
# 	Bias against  Non-White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 3.
# If age = (34.0, 41.0], capital-gain = 0, capital-loss = 0, marital-status =  Never-married:
# 	Protected Subgroup ' Non-White', 5.39% covered
# 		Make age = (41.0, 50.0], capital-gain = 15024, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Make age = (50.0, 90.0], capital-gain = 15024, marital-status =  Married-civ-spouse with effectiveness 100.00%.
# 		Aggregate cost of the above recourses = -3.00
# 	Protected Subgroup ' White', 3.67% covered
# 		Make age = (41.0, 50.0], capital-gain = 15024, marital-status =  Married-civ-spouse with effectiveness 99.70%.
# 		Make capital-gain = 15024, marital-status =  Married-civ-spouse with effectiveness 99.40%.
# 		Make age = (50.0, 90.0], capital-gain = 15024, marital-status =  Married-civ-spouse with effectiveness 99.40%.
# 		Make age = (41.0, 50.0], capital-gain = 7688, marital-status =  Married-civ-spouse with effectiveness 85.80%.
# 		Make capital-gain = 7298, marital-status =  Married-civ-spouse with effectiveness 77.34%.
# 		Make age = (50.0, 90.0], capital-gain = 7688, marital-status =  Married-civ-spouse with effectiveness 82.48%.
# 		Aggregate cost of the above recourses = -6.00
# 	Bias against  Non-White due to Equal Choice for Recourse(Macro) (threshold = 0.7). Unfairness score = 3.

# %% [markdown]
# # New Metrics

# %% [markdown]
# ## Equal Conditional Mean Recourse

# %%
top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
    rules_with_cumulative_correctness,
    metric="fairness-of-mean-recourse-conditional",
    sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
    top_count=top_count,
    filter_sequence = [
        "remove-contained",
        "remove-fair-rules"
    ],
    params=params
)

print_recourse_report_cumulative(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    show_then_costs=True,
    metric_name = 'Equal Conditional Mean Recourse'
)
# Out:
# If Workclass =  Private, capital-loss = 0, education-num = 10, hours-per-week = FullTime, marital-status =  Never-married, sex =  Male:
# 	Protected Subgroup ' Non-White', 2.35% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 3.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 21.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 22.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 1.00
# 	Protected Subgroup ' White', 1.84% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 3.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make education-num = 11, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make education-num = 12, hours-per-week = OverTime, marital-status =  Married-civ-spouse with effectiveness 2.41% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White due to Equal Conditional Mean Recourse. Unfairness score = 41.0.
# If Workclass =  Private, capital-loss = 0, education-num = 10, hours-per-week = FullTime, native-country =  United-States, relationship =  Not-in-family, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.20% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 4.76% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 4.76% and counterfactual cost = 12.0.
# 		Make education-num = 12, hours-per-week = OverTime, relationship =  Married with effectiveness 4.76% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 11.00
# 	Protected Subgroup ' White', 1.10% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 0.00% and counterfactual cost = 12.0.
# 		Make education-num = 12, hours-per-week = OverTime, relationship =  Married with effectiveness 1.01% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 51.00
# 	Bias against  White due to Equal Conditional Mean Recourse. Unfairness score = 40.0.
# If education-num = 9, hours-per-week = FullTime, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 5.28% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 1.09% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 1.09% and counterfactual cost = 12.0.
# 		Make education-num = 10, relationship =  Married with effectiveness 1.09% and counterfactual cost = 30.0.
# 		Make education-num = 10, hours-per-week = OverTime, relationship =  Married with effectiveness 1.09% and counterfactual cost = 31.0.
# 		Make education-num = 10, hours-per-week = BrainDrain, relationship =  Married with effectiveness 1.09% and counterfactual cost = 32.0.
# 		Make education-num = 11, relationship =  Married with effectiveness 1.09% and counterfactual cost = 50.0.
# 		Make education-num = 11, hours-per-week = OverTime, relationship =  Married with effectiveness 1.09% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 11.00
# 	Protected Subgroup ' White', 2.11% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make hours-per-week = OverTime, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make hours-per-week = BrainDrain, relationship =  Married with effectiveness 0.00% and counterfactual cost = 12.0.
# 		Make education-num = 10, relationship =  Married with effectiveness 0.00% and counterfactual cost = 30.0.
# 		Make education-num = 10, hours-per-week = OverTime, relationship =  Married with effectiveness 0.00% and counterfactual cost = 31.0.
# 		Make education-num = 10, hours-per-week = BrainDrain, relationship =  Married with effectiveness 0.00% and counterfactual cost = 32.0.
# 		Make education-num = 11, relationship =  Married with effectiveness 0.00% and counterfactual cost = 50.0.
# 		Make education-num = 11, hours-per-week = OverTime, relationship =  Married with effectiveness 2.63% and counterfactual cost = 51.0.
# 		Aggregate cost of the above recourses = 51.00
# 	Bias against  White due to Equal Conditional Mean Recourse. Unfairness score = 40.0.
# If capital-loss = 0, education-num = 10, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 5.22% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make education-num = 11, relationship =  Married with effectiveness 0.00% and counterfactual cost = 30.0.
# 		Make education-num = 12, relationship =  Married with effectiveness 2.20% and counterfactual cost = 50.0.
# 		Aggregate cost of the above recourses = 50.00
# 	Protected Subgroup ' White', 2.50% covered
# 		Make relationship =  Married with effectiveness 2.67% and counterfactual cost = 10.0.
# 		Make education-num = 11, relationship =  Married with effectiveness 2.67% and counterfactual cost = 30.0.
# 		Make education-num = 12, relationship =  Married with effectiveness 2.67% and counterfactual cost = 50.0.
# 		Aggregate cost of the above recourses = 10.00
# 	Bias against  Non-White due to Equal Conditional Mean Recourse. Unfairness score = 40.0.
# If Workclass =  Private, capital-loss = 0, education-num = 10, relationship =  Unmarried:
# 	Protected Subgroup ' Non-White', 3.67% covered
# 		Make relationship =  Married with effectiveness 0.00% and counterfactual cost = 10.0.
# 		Make Workclass =  Self-emp-inc, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make Workclass =  Federal-gov, relationship =  Married with effectiveness 0.00% and counterfactual cost = 11.0.
# 		Make education-num = 11, relationship =  Married with effectiveness 0.00% and counterfactual cost = 30.0.
# 		Make education-num = 12, relationship =  Married with effectiveness 3.12% and counterfactual cost = 50.0.
# 		Aggregate cost of the above recourses = 50.00
# 	Protected Subgroup ' White', 1.93% covered
# 		Make relationship =  Married with effectiveness 3.45% and counterfactual cost = 10.0.
# 		Make Workclass =  Self-emp-inc, relationship =  Married with effectiveness 3.45% and counterfactual cost = 11.0.
# 		Make Workclass =  Federal-gov, relationship =  Married with effectiveness 3.45% and counterfactual cost = 11.0.
# 		Make education-num = 11, relationship =  Married with effectiveness 3.45% and counterfactual cost = 30.0.
# 		Make education-num = 12, relationship =  Married with effectiveness 3.45% and counterfactual cost = 50.0.
# 		Aggregate cost of the above recourses = 10.00
# 	Bias against  Non-White due to Equal Conditional Mean Recourse. Unfairness score = 40.0.
# If age = (34.0, 41.0], capital-gain = 0, education-num = 9, marital-status =  Never-married:
# 	Protected Subgroup ' Non-White', 2.35% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 2.44% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 2.00
# 	Protected Subgroup ' White', 1.33% covered
# 		Make marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 21.0.
# 		Make age = (41.0, 50.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (50.0, 90.0], education-num = 10, marital-status =  Married-civ-spouse with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make age = (41.0, 50.0], education-num = 11, marital-status =  Married-civ-spouse with effectiveness 1.67% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Bias against  White due to Equal Conditional Mean Recourse. Unfairness score = 40.0.
# If capital-loss = 0, education-num = 9, marital-status =  Never-married, occupation =  Machine-op-inspct:
# 	Protected Subgroup ' Non-White', 2.01% covered
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 22.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 2.86% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 42.00
# 	Protected Subgroup ' White', 1.01% covered
# 		Make marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 1.10% and counterfactual cost = 2.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse, occupation =  Sales with effectiveness 1.10% and counterfactual cost = 22.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse, occupation =  Craft-repair with effectiveness 1.10% and counterfactual cost = 22.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 1.10% and counterfactual cost = 22.0.
# 		Make education-num = 10, marital-status =  Married-civ-spouse, occupation =  Prof-specialty with effectiveness 1.10% and counterfactual cost = 22.0.
# 		Make education-num = 11, marital-status =  Married-civ-spouse, occupation =  Exec-managerial with effectiveness 1.10% and counterfactual cost = 42.0.
# 		Aggregate cost of the above recourses = 2.00
# 	Bias against  Non-White due to Equal Conditional Mean Recourse. Unfairness score = 40.0.

# %% [markdown]
# ## Equal Cost of Effectiveness (Micro)

# %%
top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
    rules_with_cumulative_correctness,
    metric="min-above-corr",
    sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
    top_count=top_count,
    cor_threshold = 0.7,
    filter_sequence = [
        "remove-contained",
        "remove-fair-rules",
        "keep-cheap-rules-above-thr-cor",
        
    ],
    params=params
)

print_recourse_report_cumulative(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    show_then_costs=True,
    metric_name = 'Equal Cost of Effectiveness (Micro) (threshold = 0.7)'
)
# Out:
# If education-num = 9, marital-status =  Married-civ-spouse, occupation =  Transport-moving, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.78% covered
# 		Make occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 6.45% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 29.03% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 29.03% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 29.03% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 29.03% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 41.94% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 70.97% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Protected Subgroup ' White', 2.00% covered
# 		Make occupation =  Craft-repair with effectiveness 0.56% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 10.00% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 49.44% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 49.44% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 49.44% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 50.56% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 70.56% and counterfactual cost = 21.0.
# 		Aggregate cost of the above recourses = 21.00
# 	Bias against  Non-White due to Equal Cost of Effectiveness (Micro) (threshold = 0.7). Unfairness score = 20.0.
# If education-num = 9, occupation =  Transport-moving, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.78% covered
# 		Make occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 6.45% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 29.03% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 29.03% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 29.03% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 29.03% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 41.94% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 70.97% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Protected Subgroup ' White', 1.97% covered
# 		Make occupation =  Craft-repair with effectiveness 0.56% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 10.11% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 50.00% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 50.00% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 50.00% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 51.12% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 71.35% and counterfactual cost = 21.0.
# 		Aggregate cost of the above recourses = 21.00
# 	Bias against  Non-White due to Equal Cost of Effectiveness (Micro) (threshold = 0.7). Unfairness score = 20.0.
# If education-num = 13, hours-per-week = FullTime, marital-status =  Never-married, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.66% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.93% and counterfactual cost = 11.0.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 37.93% and counterfactual cost = 12.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 48.28% and counterfactual cost = 12.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.72% and counterfactual cost = 13.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.72% and counterfactual cost = 31.0.
# 		Make education-num = 14, hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 51.72% and counterfactual cost = 32.0.
# 		Make education-num = 14, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 72.41% and counterfactual cost = 32.0.
# 		Aggregate cost of the above recourses = 32.00
# 	Protected Subgroup ' White', 2.32% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.37% and counterfactual cost = 11.0.
# 		Make hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 47.37% and counterfactual cost = 12.0.
# 		Make hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 59.33% and counterfactual cost = 12.0.
# 		Make hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.29% and counterfactual cost = 13.0.
# 		Make education-num = 14, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.29% and counterfactual cost = 31.0.
# 		Make education-num = 14, hours-per-week = MidTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 60.29% and counterfactual cost = 32.0.
# 		Make education-num = 14, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 63.64% and counterfactual cost = 32.0.
# 		Make education-num = 14, hours-per-week = BrainDrain, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 67.46% and counterfactual cost = 33.0.
# 		Make education-num = 15, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 67.46% and counterfactual cost = 51.0.
# 		Make education-num = 15, hours-per-week = OverTime, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 80.38% and counterfactual cost = 52.0.
# 		Aggregate cost of the above recourses = 52.00
# 	Bias against  White due to Equal Cost of Effectiveness (Micro) (threshold = 0.7). Unfairness score = 20.0.
# If education-num = 9, marital-status =  Married-civ-spouse, native-country =  United-States, occupation =  Transport-moving:
# 	Protected Subgroup ' Non-White', 1.55% covered
# 		Make occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 3.70% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 29.63% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 29.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 29.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 29.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 29.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 44.44% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 70.37% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Protected Subgroup ' White', 1.94% covered
# 		Make occupation =  Craft-repair with effectiveness 0.57% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 10.29% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 50.29% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 50.29% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 50.29% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 50.29% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 51.43% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 71.43% and counterfactual cost = 21.0.
# 		Aggregate cost of the above recourses = 21.00
# 	Bias against  Non-White due to Equal Cost of Effectiveness (Micro) (threshold = 0.7). Unfairness score = 20.0.
# If education-num = 9, native-country =  United-States, occupation =  Transport-moving, relationship =  Married:
# 	Protected Subgroup ' Non-White', 1.55% covered
# 		Make occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 3.70% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 29.63% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 29.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 29.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 29.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 29.63% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 44.44% and counterfactual cost = 21.0.
# 		Make education-num = 11, occupation =  Exec-managerial with effectiveness 70.37% and counterfactual cost = 41.0.
# 		Aggregate cost of the above recourses = 41.00
# 	Protected Subgroup ' White', 1.93% covered
# 		Make occupation =  Craft-repair with effectiveness 0.57% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 10.34% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 50.57% and counterfactual cost = 1.0.
# 		Make education-num = 10, occupation =  Craft-repair with effectiveness 50.57% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Adm-clerical with effectiveness 50.57% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Sales with effectiveness 50.57% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Prof-specialty with effectiveness 51.72% and counterfactual cost = 21.0.
# 		Make education-num = 10, occupation =  Exec-managerial with effectiveness 71.84% and counterfactual cost = 21.0.
# 		Aggregate cost of the above recourses = 21.00
# 	Bias against  Non-White due to Equal Cost of Effectiveness (Micro) (threshold = 0.7). Unfairness score = 20.0.

# %% [markdown]
# ## Equal Effectiveness

# %%
top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
    rules_with_cumulative_correctness,
    metric="total-correctness",
    sort_strategy="generic-sorting-ignore-forall-subgroups-empty",
    top_count=top_count,
    filter_sequence = [
        "remove-contained",
        "remove-fair-rules",
    ],
    params=params
)

print_recourse_report_cumulative(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    show_then_costs=True,
    correctness_metric=True,
    metric_name = 'Equal Effectiveness'
)
# Out:
# If age = (34.0, 41.0], capital-loss = 0, native-country =  United-States, occupation =  Machine-op-inspct:
# 	Protected Subgroup ' Non-White', 1.38% covered
# 		Make occupation =  Exec-managerial with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Tech-support with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.00
# 	Protected Subgroup ' White', 1.20% covered
# 		Make occupation =  Craft-repair with effectiveness 3.70% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 6.48% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 11.11% and counterfactual cost = 1.0.
# 		Make occupation =  Tech-support with effectiveness 13.89% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 17.59% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 29.63% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], occupation =  Craft-repair with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Craft-repair with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 50.00% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.50
# 	Bias against  Non-White due to Equal Effectiveness. Unfairness score = 0.5.
# If education-num = 14, relationship =  Not-in-family:
# 	Protected Subgroup ' Non-White', 1.20% covered
# 		Make relationship =  Married with effectiveness 4.76% and counterfactual cost = 10.0.
# 		Make education-num = 15, relationship =  Married with effectiveness 9.52% and counterfactual cost = 30.0.
# 		Make education-num = 16, relationship =  Married with effectiveness 9.52% and counterfactual cost = 50.0.
# 		Aggregate cost of the above recourses = 0.10
# 	Protected Subgroup ' White', 2.02% covered
# 		Make relationship =  Married with effectiveness 21.98% and counterfactual cost = 10.0.
# 		Make education-num = 15, relationship =  Married with effectiveness 36.81% and counterfactual cost = 30.0.
# 		Make education-num = 16, relationship =  Married with effectiveness 52.75% and counterfactual cost = 50.0.
# 		Aggregate cost of the above recourses = 0.53
# 	Bias against  Non-White due to Equal Effectiveness. Unfairness score = 0.432.
# If age = (34.0, 41.0], capital-gain = 0, capital-loss = 0, marital-status =  Married-civ-spouse, occupation =  Craft-repair:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make occupation =  Sales with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 5.26% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 10.53% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 10.53% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 10.53% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 10.53% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 10.53% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 10.53% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 26.32% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 26.32% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.26
# 	Protected Subgroup ' White', 1.91% covered
# 		Make age = (41.0, 50.0] with effectiveness 3.49% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 13.95% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 19.77% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 43.60% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 47.09% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 69.19% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.69
# 	Bias against  Non-White due to Equal Effectiveness. Unfairness score = 0.429.
# If age = (34.0, 41.0], capital-loss = 0, marital-status =  Never-married, relationship =  Not-in-family, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 21.05% and counterfactual cost = 11.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 26.32% and counterfactual cost = 12.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 26.32% and counterfactual cost = 12.0.
# 		Make age = (41.0, 50.0], capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.11% and counterfactual cost = 12.44.
# 		Aggregate cost of the above recourses = 0.42
# 	Protected Subgroup ' White', 1.71% covered
# 		Make marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 38.96% and counterfactual cost = 11.0.
# 		Make age = (50.0, 90.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 40.91% and counterfactual cost = 12.0.
# 		Make age = (41.0, 50.0], marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 42.21% and counterfactual cost = 12.0.
# 		Make age = (41.0, 50.0], capital-loss = 1902, marital-status =  Married-civ-spouse, relationship =  Married with effectiveness 83.77% and counterfactual cost = 12.44.
# 		Aggregate cost of the above recourses = 0.84
# 	Bias against  Non-White due to Equal Effectiveness. Unfairness score = 0.417.
# If Workclass =  Self-emp-not-inc, capital-loss = 0, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make Workclass =  Local-gov with effectiveness 5.26% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 5.26% and counterfactual cost = 1.0.
# 		Make Workclass =  Private with effectiveness 10.53% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 26.32% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 26.32% and counterfactual cost = 1.0.
# 		Make Workclass =  Private, capital-loss = 1887 with effectiveness 31.58% and counterfactual cost = 1.43.
# 		Make Workclass =  Private, capital-loss = 1902 with effectiveness 31.58% and counterfactual cost = 1.44.
# 		Make Workclass =  Private, capital-loss = 1977 with effectiveness 31.58% and counterfactual cost = 1.45.
# 		Make Workclass =  Private, relationship =  Not-in-family with effectiveness 31.58% and counterfactual cost = 11.0.
# 		Aggregate cost of the above recourses = 0.32
# 	Protected Subgroup ' White', 4.55% covered
# 		Make Workclass =  State-gov with effectiveness 10.73% and counterfactual cost = 1.0.
# 		Make Workclass =  Local-gov with effectiveness 15.37% and counterfactual cost = 1.0.
# 		Make Workclass =  Private with effectiveness 17.80% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 31.95% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 40.24% and counterfactual cost = 1.0.
# 		Make Workclass =  Private, capital-loss = 1887 with effectiveness 70.73% and counterfactual cost = 1.43.
# 		Make Workclass =  Private, capital-loss = 1902 with effectiveness 70.73% and counterfactual cost = 1.44.
# 		Make Workclass =  Private, capital-loss = 1977 with effectiveness 73.17% and counterfactual cost = 1.45.
# 		Make Workclass =  Private, relationship =  Not-in-family with effectiveness 73.17% and counterfactual cost = 11.0.
# 		Aggregate cost of the above recourses = 0.73
# 	Bias against  Non-White due to Equal Effectiveness. Unfairness score = 0.416.
# If age = (34.0, 41.0], capital-loss = 0, occupation =  Craft-repair, relationship =  Married:
# 	Protected Subgroup ' Non-White', 1.03% covered
# 		Make occupation =  Sales with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 5.56% and counterfactual cost = 1.0.
# 		Make occupation =  Tech-support with effectiveness 5.56% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 11.11% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 27.78% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 27.78% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.28
# 	Protected Subgroup ' White', 1.91% covered
# 		Make occupation =  Adm-clerical with effectiveness 2.33% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0] with effectiveness 2.33% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 3.49% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 13.95% and counterfactual cost = 1.0.
# 		Make occupation =  Tech-support with effectiveness 18.60% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 19.77% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 43.60% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 47.09% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 69.19% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.69
# 	Bias against  Non-White due to Equal Effectiveness. Unfairness score = 0.414.

# %% [markdown]
# ## Fair Effectiveness-Cost Trade-Off

# %%
# taken from the other notebooks
preds_Xtest = model.predict(Xtest)
affected_pop_sizes = {sg: ((Xtest["race"] == sg) & (preds_Xtest == 0)).sum() for sg in Xtest["race"].unique()}

top_rules,unfairness = facts.select_rules_subset_KStest(
    rules_with_cumulative_correctness,
    affected_pop_sizes,
    top_count=top_count
)

print_recourse_report_KStest_cumulative(
    top_rules,
    population_sizes=affected_pop_sizes,
    unfairness = unfairness,
    show_then_costs=True,
    metric_name = 'Fair Effectiveness-Cost Trade-Off'
    # show_cumulative_plots=True
)
    # show_cumulative_plots=True
# Out:
# If capital-gain = 0, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 76.82% covered out of 1743
# 		Make capital-gain = 3103 with effectiveness 9.19% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 12.99% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 17.77% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 27.71% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 29.87% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 74.46% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 89.37% covered out of 9016
# 		Make capital-gain = 3103 with effectiveness 20.20% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 28.05% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 32.66% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 44.56% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 46.64% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 81.06% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 5.71.
# If capital-gain = 0, capital-loss = 0, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 74.81% covered out of 1743
# 		Make capital-gain = 3103 with effectiveness 8.82% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 12.50% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 17.02% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 26.99% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 29.14% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 73.93% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 73.93% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 73.93% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 73.93% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 86.65% covered out of 9016
# 		Make capital-gain = 3103 with effectiveness 19.76% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 27.50% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 31.98% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 43.82% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 45.84% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 80.66% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 80.66% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 80.66% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 80.66% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 5.62.
# If capital-gain = 0:
# 	Protected Subgroup ' Non-White', 96.16% covered out of 1743
# 		Make capital-gain = 3103 with effectiveness 9.37% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 13.66% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 18.38% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 28.94% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 31.09% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 74.64% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 96.61% covered out of 9016
# 		Make capital-gain = 3103 with effectiveness 19.51% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 27.08% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 31.61% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 43.27% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 45.38% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 80.23% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 5.37.
# If capital-gain = 0, capital-loss = 0:
# 	Protected Subgroup ' Non-White', 93.75% covered out of 1743
# 		Make capital-gain = 3103 with effectiveness 9.06% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 13.16% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 17.63% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 28.21% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 30.35% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 74.11% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 74.11% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 74.11% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 74.11% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 93.76% covered out of 9016
# 		Make capital-gain = 3103 with effectiveness 19.08% and counterfactual cost = 0.03.
# 		Make capital-gain = 4386 with effectiveness 26.53% and counterfactual cost = 0.04.
# 		Make capital-gain = 5178 with effectiveness 30.94% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 42.54% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 44.60% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 79.82% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 79.82% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 79.82% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 79.82% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 5.3.
# If Workclass =  Private, capital-gain = 0, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 57.43% covered out of 1743
# 		Make capital-gain = 7298 with effectiveness 24.18% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 26.17% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 70.83% and counterfactual cost = 0.15.
# 		Make Workclass =  Local-gov with effectiveness 70.83% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-not-inc with effectiveness 70.83% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 70.83% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 70.83% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 70.83% and counterfactual cost = 1.0.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 68.80% covered out of 9016
# 		Make capital-gain = 7298 with effectiveness 40.27% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 42.24% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 78.17% and counterfactual cost = 0.15.
# 		Make Workclass =  Local-gov with effectiveness 78.17% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-not-inc with effectiveness 78.17% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 78.17% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 78.17% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 78.17% and counterfactual cost = 1.0.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.73.
# If Workclass =  Private, capital-gain = 0, capital-loss = 0, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 55.77% covered out of 1743
# 		Make capital-gain = 7298 with effectiveness 23.25% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 25.21% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 70.16% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 70.16% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 70.16% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 70.16% and counterfactual cost = 0.45.
# 		Make Workclass =  Local-gov with effectiveness 70.16% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-not-inc with effectiveness 70.16% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 70.16% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 70.16% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 70.16% and counterfactual cost = 1.0.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 66.73% covered out of 9016
# 		Make capital-gain = 7298 with effectiveness 39.49% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 41.41% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 77.73% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 77.73% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 77.73% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 77.73% and counterfactual cost = 0.45.
# 		Make Workclass =  Local-gov with effectiveness 77.73% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-not-inc with effectiveness 77.73% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 77.73% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 77.73% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 77.73% and counterfactual cost = 1.0.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.7.
# If capital-loss = 0, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 78.03% covered out of 1743
# 		Make capital-loss = 1887 with effectiveness 11.40% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 11.40% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 11.69% and counterfactual cost = 0.45.
# 	Protected Subgroup ' White', 89.81% covered out of 9016
# 		Make capital-loss = 1887 with effectiveness 23.54% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 23.61% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 24.40% and counterfactual cost = 0.45.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.34.
# If capital-loss = 0:
# 	Protected Subgroup ' Non-White', 97.59% covered out of 1743
# 		Make capital-loss = 1887 with effectiveness 11.52% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 11.64% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 12.11% and counterfactual cost = 0.45.
# 	Protected Subgroup ' White', 97.15% covered out of 9016
# 		Make capital-loss = 1887 with effectiveness 22.77% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 22.83% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 23.60% and counterfactual cost = 0.45.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.34.
# If Workclass =  Private, capital-gain = 0:
# 	Protected Subgroup ' Non-White', 74.13% covered out of 1743
# 		Make capital-gain = 7298 with effectiveness 25.70% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 27.71% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 71.28% and counterfactual cost = 0.15.
# 		Make Workclass =  Local-gov with effectiveness 71.28% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-not-inc with effectiveness 71.28% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 71.28% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 71.28% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 71.28% and counterfactual cost = 1.0.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 74.83% covered out of 9016
# 		Make capital-gain = 7298 with effectiveness 38.83% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 40.77% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 77.20% and counterfactual cost = 0.15.
# 		Make Workclass =  Local-gov with effectiveness 77.20% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-not-inc with effectiveness 77.20% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 77.20% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 77.20% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 77.20% and counterfactual cost = 1.0.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.33.
# If age = (26.0, 34.0], capital-gain = 0, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 19.33% covered out of 1743
# 		Make age = (34.0, 41.0] with effectiveness 2.97% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 5.04% and counterfactual cost = 1.0.
# 		Make age = (34.0, 41.0], capital-gain = 7298 with effectiveness 33.23% and counterfactual cost = 1.07.
# 		Make age = (41.0, 50.0], capital-gain = 7688 with effectiveness 38.58% and counterfactual cost = 1.08.
# 		Make age = (34.0, 41.0], capital-gain = 15024 with effectiveness 90.21% and counterfactual cost = 1.15.
# 		Make age = (41.0, 50.0], capital-gain = 15024 with effectiveness 94.07% and counterfactual cost = 1.15.
# 	Protected Subgroup ' White', 19.76% covered out of 9016
# 		Make age = (34.0, 41.0] with effectiveness 7.24% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 9.88% and counterfactual cost = 1.0.
# 		Make age = (34.0, 41.0], capital-gain = 7298 with effectiveness 57.80% and counterfactual cost = 1.07.
# 		Make age = (41.0, 50.0], capital-gain = 7688 with effectiveness 64.20% and counterfactual cost = 1.08.
# 		Make age = (34.0, 41.0], capital-gain = 15024 with effectiveness 97.08% and counterfactual cost = 1.15.
# 		Make age = (41.0, 50.0], capital-gain = 15024 with effectiveness 98.37% and counterfactual cost = 1.15.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.31.
# If Workclass =  Private, capital-gain = 0, capital-loss = 0:
# 	Protected Subgroup ' Non-White', 72.12% covered out of 1743
# 		Make capital-gain = 7298 with effectiveness 24.82% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 26.81% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 70.64% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 70.64% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 70.64% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 70.64% and counterfactual cost = 0.45.
# 		Make Workclass =  Local-gov with effectiveness 70.64% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-not-inc with effectiveness 70.64% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 70.64% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 70.64% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 70.64% and counterfactual cost = 1.0.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 72.67% covered out of 9016
# 		Make capital-gain = 7298 with effectiveness 38.10% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 39.97% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 76.76% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 76.76% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 76.76% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 76.76% and counterfactual cost = 0.45.
# 		Make Workclass =  Local-gov with effectiveness 76.76% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-not-inc with effectiveness 76.76% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 76.76% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 76.76% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 76.76% and counterfactual cost = 1.0.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.31.
# If capital-gain = 0, hours-per-week = FullTime, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 46.30% covered out of 1743
# 		Make capital-gain = 7298 with effectiveness 30.36% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 32.96% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 81.16% and counterfactual cost = 0.15.
# 		Make hours-per-week = MidTime with effectiveness 81.16% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 81.16% and counterfactual cost = 1.0.
# 		Make capital-gain = 7298, hours-per-week = OverTime with effectiveness 81.16% and counterfactual cost = 1.07.
# 		Make capital-gain = 7688, hours-per-week = OverTime with effectiveness 81.16% and counterfactual cost = 1.08.
# 		Make capital-gain = 15024, hours-per-week = OverTime with effectiveness 85.75% and counterfactual cost = 1.15.
# 		Make hours-per-week = BrainDrain with effectiveness 85.75% and counterfactual cost = 2.0.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain with effectiveness 86.37% and counterfactual cost = 2.15.
# 	Protected Subgroup ' White', 42.40% covered out of 9016
# 		Make capital-gain = 7298 with effectiveness 46.93% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 49.25% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 87.92% and counterfactual cost = 0.15.
# 		Make hours-per-week = MidTime with effectiveness 87.92% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 87.92% and counterfactual cost = 1.0.
# 		Make capital-gain = 7298, hours-per-week = OverTime with effectiveness 87.92% and counterfactual cost = 1.07.
# 		Make capital-gain = 7688, hours-per-week = OverTime with effectiveness 87.92% and counterfactual cost = 1.08.
# 		Make capital-gain = 15024, hours-per-week = OverTime with effectiveness 91.42% and counterfactual cost = 1.15.
# 		Make hours-per-week = BrainDrain with effectiveness 91.42% and counterfactual cost = 2.0.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain with effectiveness 91.79% and counterfactual cost = 2.15.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.28.
# If capital-gain = 0, capital-loss = 0, hours-per-week = FullTime, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 45.27% covered out of 1743
# 		Make capital-gain = 7298 with effectiveness 29.66% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 32.19% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 80.74% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 80.74% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 80.74% and counterfactual cost = 0.44.
# 		Make hours-per-week = MidTime with effectiveness 80.74% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 80.74% and counterfactual cost = 1.0.
# 		Make capital-gain = 7298, hours-per-week = OverTime with effectiveness 80.74% and counterfactual cost = 1.07.
# 		Make capital-gain = 7688, hours-per-week = OverTime with effectiveness 80.74% and counterfactual cost = 1.08.
# 		Make capital-gain = 15024, hours-per-week = OverTime with effectiveness 85.42% and counterfactual cost = 1.15.
# 		Make hours-per-week = BrainDrain with effectiveness 85.42% and counterfactual cost = 2.0.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain with effectiveness 86.06% and counterfactual cost = 2.15.
# 	Protected Subgroup ' White', 41.18% covered out of 9016
# 		Make capital-gain = 7298 with effectiveness 46.19% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 48.48% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 87.61% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 87.61% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 87.61% and counterfactual cost = 0.44.
# 		Make hours-per-week = MidTime with effectiveness 87.61% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 87.61% and counterfactual cost = 1.0.
# 		Make capital-gain = 7298, hours-per-week = OverTime with effectiveness 87.61% and counterfactual cost = 1.07.
# 		Make capital-gain = 7688, hours-per-week = OverTime with effectiveness 87.61% and counterfactual cost = 1.08.
# 		Make capital-gain = 15024, hours-per-week = OverTime with effectiveness 91.19% and counterfactual cost = 1.15.
# 		Make hours-per-week = BrainDrain with effectiveness 91.19% and counterfactual cost = 2.0.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain with effectiveness 91.57% and counterfactual cost = 2.15.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.22.
# If age = (26.0, 34.0], capital-gain = 0, capital-loss = 0, native-country =  United-States:
# 	Protected Subgroup ' Non-White', 18.99% covered out of 1743
# 		Make age = (34.0, 41.0] with effectiveness 2.72% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 4.83% and counterfactual cost = 1.0.
# 		Make age = (34.0, 41.0], capital-gain = 7298 with effectiveness 32.63% and counterfactual cost = 1.07.
# 		Make age = (41.0, 50.0], capital-gain = 7688 with effectiveness 38.07% and counterfactual cost = 1.08.
# 		Make age = (34.0, 41.0], capital-gain = 15024 with effectiveness 90.03% and counterfactual cost = 1.15.
# 		Make age = (41.0, 50.0], capital-gain = 15024 with effectiveness 93.96% and counterfactual cost = 1.15.
# 		Make age = (41.0, 50.0], capital-loss = 1902 with effectiveness 93.96% and counterfactual cost = 1.44.
# 	Protected Subgroup ' White', 19.13% covered out of 9016
# 		Make age = (34.0, 41.0] with effectiveness 6.96% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 9.57% and counterfactual cost = 1.0.
# 		Make age = (34.0, 41.0], capital-gain = 7298 with effectiveness 57.04% and counterfactual cost = 1.07.
# 		Make age = (41.0, 50.0], capital-gain = 7688 with effectiveness 63.30% and counterfactual cost = 1.08.
# 		Make age = (34.0, 41.0], capital-gain = 15024 with effectiveness 96.99% and counterfactual cost = 1.15.
# 		Make age = (41.0, 50.0], capital-gain = 15024 with effectiveness 98.32% and counterfactual cost = 1.15.
# 		Make age = (41.0, 50.0], capital-loss = 1902 with effectiveness 98.32% and counterfactual cost = 1.44.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.21.
# If capital-gain = 0, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 38.15% covered out of 1743
# 		Make capital-gain = 3103 with effectiveness 15.49% and counterfactual cost = 0.03.
# 		Make capital-gain = 5178 with effectiveness 27.22% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 38.05% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 40.00% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 78.50% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 56.23% covered out of 9016
# 		Make capital-gain = 3103 with effectiveness 28.15% and counterfactual cost = 0.03.
# 		Make capital-gain = 5178 with effectiveness 43.16% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 54.99% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 56.79% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 84.85% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.11.
# If capital-gain = 0, capital-loss = 0, native-country =  United-States, sex =  Male:
# 	Protected Subgroup ' Non-White', 37.01% covered out of 1743
# 		Make capital-gain = 3103 with effectiveness 15.04% and counterfactual cost = 0.03.
# 		Make capital-gain = 5178 with effectiveness 26.51% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 37.52% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 39.53% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 78.14% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 78.14% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 78.14% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 78.14% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 54.58% covered out of 9016
# 		Make capital-gain = 3103 with effectiveness 27.74% and counterfactual cost = 0.03.
# 		Make capital-gain = 5178 with effectiveness 42.57% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 54.44% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 56.21% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 84.54% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 84.54% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 84.54% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 84.54% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 4.04.
# If capital-gain = 0, sex =  Male:
# 	Protected Subgroup ' Non-White', 49.28% covered out of 1743
# 		Make capital-gain = 3103 with effectiveness 15.37% and counterfactual cost = 0.03.
# 		Make capital-gain = 5178 with effectiveness 28.06% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 39.23% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 40.98% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 78.58% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 60.95% covered out of 9016
# 		Make capital-gain = 3103 with effectiveness 27.04% and counterfactual cost = 0.03.
# 		Make capital-gain = 5178 with effectiveness 41.57% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 53.19% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 55.05% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 83.79% and counterfactual cost = 0.15.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 3.84.
# If capital-gain = 0, capital-loss = 0, sex =  Male:
# 	Protected Subgroup ' Non-White', 47.91% covered out of 1743
# 		Make capital-gain = 3103 with effectiveness 14.97% and counterfactual cost = 0.03.
# 		Make capital-gain = 5178 with effectiveness 27.31% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 38.56% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 40.36% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 78.20% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 78.20% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 78.20% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 78.20% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	Protected Subgroup ' White', 59.25% covered out of 9016
# 		Make capital-gain = 3103 with effectiveness 26.64% and counterfactual cost = 0.03.
# 		Make capital-gain = 5178 with effectiveness 40.98% and counterfactual cost = 0.05.
# 		Make capital-gain = 7298 with effectiveness 52.64% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 54.47% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 83.47% and counterfactual cost = 0.15.
# 		Make capital-loss = 1887 with effectiveness 83.47% and counterfactual cost = 0.43.
# 		Make capital-loss = 1902 with effectiveness 83.47% and counterfactual cost = 0.44.
# 		Make capital-loss = 1977 with effectiveness 83.47% and counterfactual cost = 0.45.
# 		Make capital-gain = 99999 with effectiveness 100.00% and counterfactual cost = 1.0.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 3.79.
# If age = (50.0, 90.0], capital-gain = 0:
# 	Protected Subgroup ' Non-White', 14.97% covered out of 1743
# 		Make capital-gain = 7688 with effectiveness 39.85% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 86.59% and counterfactual cost = 0.15.
# 	Protected Subgroup ' White', 17.20% covered out of 9016
# 		Make capital-gain = 7688 with effectiveness 64.60% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 96.39% and counterfactual cost = 0.15.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 3.7.
# If capital-gain = 0, hours-per-week = FullTime:
# 	Protected Subgroup ' Non-White', 57.60% covered out of 1743
# 		Make capital-gain = 7298 with effectiveness 32.17% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 34.76% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 80.68% and counterfactual cost = 0.15.
# 		Make hours-per-week = MidTime with effectiveness 80.68% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 80.68% and counterfactual cost = 1.0.
# 		Make capital-gain = 7298, hours-per-week = OverTime with effectiveness 80.68% and counterfactual cost = 1.07.
# 		Make capital-gain = 7688, hours-per-week = OverTime with effectiveness 80.68% and counterfactual cost = 1.08.
# 		Make capital-gain = 15024, hours-per-week = OverTime with effectiveness 85.16% and counterfactual cost = 1.15.
# 		Make hours-per-week = BrainDrain with effectiveness 85.16% and counterfactual cost = 2.0.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain with effectiveness 85.96% and counterfactual cost = 2.15.
# 	Protected Subgroup ' White', 46.57% covered out of 9016
# 		Make capital-gain = 7298 with effectiveness 45.11% and counterfactual cost = 0.07.
# 		Make capital-gain = 7688 with effectiveness 47.51% and counterfactual cost = 0.08.
# 		Make capital-gain = 15024 with effectiveness 86.52% and counterfactual cost = 0.15.
# 		Make hours-per-week = MidTime with effectiveness 86.52% and counterfactual cost = 1.0.
# 		Make hours-per-week = OverTime with effectiveness 86.52% and counterfactual cost = 1.0.
# 		Make capital-gain = 7298, hours-per-week = OverTime with effectiveness 86.52% and counterfactual cost = 1.07.
# 		Make capital-gain = 7688, hours-per-week = OverTime with effectiveness 86.52% and counterfactual cost = 1.08.
# 		Make capital-gain = 15024, hours-per-week = OverTime with effectiveness 90.19% and counterfactual cost = 1.15.
# 		Make hours-per-week = BrainDrain with effectiveness 90.19% and counterfactual cost = 2.0.
# 		Make capital-gain = 15024, hours-per-week = BrainDrain with effectiveness 90.57% and counterfactual cost = 2.15.
# 	 Unfairness based on the Fair Effectiveness-Cost Trade-Off = 3.68.

# %% [markdown]
# ## Equal Effectiveness within Budget (Micro)

# %%
top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
    rules_with_cumulative_correctness,
    metric="max-upto-cost",
    sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
    top_count=top_count,
    cost_threshold = cost_budget,
    filter_sequence = [
        "remove-contained",
        "remove-fair-rules",
        
    ],
    params=params
)

print_recourse_report_cumulative(
    top_rules,
    subgroup_costs=subgroup_costs,
    show_subgroup_costs=True,
    show_then_costs=True,
    correctness_metric = True,
    metric_name = 'Equal Effectiveness within Budget (Micro)'
)
# Out:
# If age = (34.0, 41.0], capital-loss = 0, native-country =  United-States, occupation =  Machine-op-inspct:
# 	Protected Subgroup ' Non-White', 1.38% covered
# 		Make occupation =  Exec-managerial with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Tech-support with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Craft-repair with effectiveness 0.00% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.00
# 	Protected Subgroup ' White', 1.20% covered
# 		Make occupation =  Craft-repair with effectiveness 3.70% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 6.48% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 11.11% and counterfactual cost = 1.0.
# 		Make occupation =  Tech-support with effectiveness 13.89% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 17.59% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 29.63% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], occupation =  Craft-repair with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Craft-repair with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 29.63% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 50.00% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.50
# 	Bias against  Non-White due to Equal Effectiveness within Budget (Micro). Unfairness score = 0.5.
# If age = (34.0, 41.0], capital-gain = 0, capital-loss = 0, marital-status =  Married-civ-spouse, occupation =  Craft-repair:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make occupation =  Sales with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 5.26% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 10.53% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 10.53% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 10.53% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 10.53% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 10.53% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 10.53% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 26.32% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 26.32% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.26
# 	Protected Subgroup ' White', 1.91% covered
# 		Make age = (41.0, 50.0] with effectiveness 3.49% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 13.95% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 19.77% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 43.60% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 47.09% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 69.19% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.69
# 	Bias against  Non-White due to Equal Effectiveness within Budget (Micro). Unfairness score = 0.429.
# If Workclass =  Self-emp-not-inc, capital-loss = 0, native-country =  United-States, relationship =  Married, sex =  Male:
# 	Protected Subgroup ' Non-White', 1.09% covered
# 		Make Workclass =  Local-gov with effectiveness 5.26% and counterfactual cost = 1.0.
# 		Make Workclass =  State-gov with effectiveness 5.26% and counterfactual cost = 1.0.
# 		Make Workclass =  Private with effectiveness 10.53% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 26.32% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 26.32% and counterfactual cost = 1.0.
# 		Make Workclass =  Private, capital-loss = 1887 with effectiveness 31.58% and counterfactual cost = 1.43.
# 		Make Workclass =  Private, capital-loss = 1902 with effectiveness 31.58% and counterfactual cost = 1.44.
# 		Make Workclass =  Private, capital-loss = 1977 with effectiveness 31.58% and counterfactual cost = 1.45.
# 		Make Workclass =  Private, relationship =  Not-in-family with effectiveness 31.58% and counterfactual cost = 11.0.
# 		Aggregate cost of the above recourses = 0.32
# 	Protected Subgroup ' White', 4.55% covered
# 		Make Workclass =  State-gov with effectiveness 10.73% and counterfactual cost = 1.0.
# 		Make Workclass =  Local-gov with effectiveness 15.37% and counterfactual cost = 1.0.
# 		Make Workclass =  Private with effectiveness 17.80% and counterfactual cost = 1.0.
# 		Make Workclass =  Self-emp-inc with effectiveness 31.95% and counterfactual cost = 1.0.
# 		Make Workclass =  Federal-gov with effectiveness 40.24% and counterfactual cost = 1.0.
# 		Make Workclass =  Private, capital-loss = 1887 with effectiveness 70.73% and counterfactual cost = 1.43.
# 		Make Workclass =  Private, capital-loss = 1902 with effectiveness 70.73% and counterfactual cost = 1.44.
# 		Make Workclass =  Private, capital-loss = 1977 with effectiveness 73.17% and counterfactual cost = 1.45.
# 		Make Workclass =  Private, relationship =  Not-in-family with effectiveness 73.17% and counterfactual cost = 11.0.
# 		Aggregate cost of the above recourses = 0.73
# 	Bias against  Non-White due to Equal Effectiveness within Budget (Micro). Unfairness score = 0.416.
# If age = (34.0, 41.0], capital-loss = 0, occupation =  Craft-repair, relationship =  Married:
# 	Protected Subgroup ' Non-White', 1.03% covered
# 		Make occupation =  Sales with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Adm-clerical with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0] with effectiveness 0.00% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 5.56% and counterfactual cost = 1.0.
# 		Make occupation =  Tech-support with effectiveness 5.56% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 11.11% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 11.11% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 27.78% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 27.78% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.28
# 	Protected Subgroup ' White', 1.91% covered
# 		Make occupation =  Adm-clerical with effectiveness 2.33% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0] with effectiveness 2.33% and counterfactual cost = 1.0.
# 		Make age = (41.0, 50.0] with effectiveness 3.49% and counterfactual cost = 1.0.
# 		Make occupation =  Sales with effectiveness 13.95% and counterfactual cost = 1.0.
# 		Make occupation =  Tech-support with effectiveness 18.60% and counterfactual cost = 1.0.
# 		Make occupation =  Prof-specialty with effectiveness 19.77% and counterfactual cost = 1.0.
# 		Make occupation =  Exec-managerial with effectiveness 43.60% and counterfactual cost = 1.0.
# 		Make age = (50.0, 90.0], occupation =  Adm-clerical with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Adm-clerical with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Sales with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Sales with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Prof-specialty with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Tech-support with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Prof-specialty with effectiveness 43.60% and counterfactual cost = 2.0.
# 		Make age = (50.0, 90.0], occupation =  Exec-managerial with effectiveness 47.09% and counterfactual cost = 2.0.
# 		Make age = (41.0, 50.0], occupation =  Exec-managerial with effectiveness 69.19% and counterfactual cost = 2.0.
# 		Aggregate cost of the above recourses = 0.69
# 	Bias against  Non-White due to Equal Effectiveness within Budget (Micro). Unfairness score = 0.414.

# %% [markdown]
# ## Get ranking of subgroups based on metrics

# %%
from facts.fairness_metrics_aggr import make_table, auto_budget_calculation

# %%
rules_with_both = {}
for ifc, all_thens in rules_with_cumulative_correctness.items():
    new_all_thens = {}
    for sg, (cov, thens_cum) in all_thens.items():
        thens_atom = rules_with_atomic_correctness[ifc][sg][1]
        thens_atom_dict = {then: atom_cor for then, atom_cor in thens_atom}
        new_all_thens[sg] = (cov, [(then, thens_atom_dict[then], cumcor) for then, cumcor, _cost in thens_cum])
    rules_with_both[ifc] = new_all_thens

# %%
budgets = auto_budget_calculation(rules_with_cumulative_correctness, cor_thres=0.5, percentiles=[0.3, 0.6, 0.9])

df = make_table(
    rules_with_both,
    sensitive_attribute_vals=[" Non-White", " White"],
    effectiveness_thresholds=[0.3, 0.7],
    cost_budgets=budgets,
    params=params
)
df.drop(['weighted-average', 'mean-cost-cinf'], axis=1, inplace=True)

# %%
#table of differences between Male and Female for each metric
diff = get_diff_table(df, sensitive_attribute_vals=[" White", " Non-White"], with_abs = True)
diff = diff.set_index('subgroup')
ranked = diff.drop(columns=[('Fair Effectiveness-Cost Trade-Off','bias')]).mask(diff == 0).rank(ascending = False,axis=0,method='dense')
ranked = ranked.replace(np.nan,"Fair")

# %%
rev_bias_metrics = ['Equal Effectiveness', 'Equal Effectiveness within Budget']
comb_df = get_comb_df(df, ranked, diff, rev_bias_metrics, sensitive_attribute_vals=[" White", " Non-White"])
analysis_df,rank_analysis_df = get_analysis_dfs(comb_df,ranked, sensitive_attribute_vals=["White", "Non-White"])

# %%
comb_df.head()
# Out:
#                                                   (Equal Cost of Effectiveness(Macro), 0.3)  \
#                                                                                        rank
# subgroup
# capital-loss = 0                                                                       Fair
# capital-gain = 0                                                                       32.0
# capital-gain = 0, capital-loss = 0                                                     32.0
# capital-loss = 0, native-country =  United-States                                      Fair
# Workclass =  Private                                                                   Fair
#
#                                                                         \
#                                                     score bias against
# subgroup
# capital-loss = 0                                   0.0000         Fair
# capital-gain = 0                                   0.0251    Non-White
# capital-gain = 0, capital-loss = 0                 0.0251    Non-White
# capital-loss = 0, native-country =  United-States  0.0000         Fair
# Workclass =  Private                               0.0000         Fair
#
#                                                   (Equal Cost of Effectiveness(Macro), 0.7)  \
#                                                                                        rank
# subgroup
# capital-loss = 0                                                                       Fair
# capital-gain = 0                                                                       Fair
# capital-gain = 0, capital-loss = 0                                                     Fair
# capital-loss = 0, native-country =  United-States                                      Fair
# Workclass =  Private                                                                   Fair
#
#                                                                       \
#                                                   score bias against
# subgroup
# capital-loss = 0                                    0.0         Fair
# capital-gain = 0                                    0.0         Fair
# capital-gain = 0, capital-loss = 0                  0.0         Fair
# capital-loss = 0, native-country =  United-States   0.0         Fair
# Workclass =  Private                                0.0         Fair
#
#                                                   (Equal Choice for Recourse, 0.3)  \
#                                                                               rank
# subgroup
# capital-loss = 0                                                              Fair
# capital-gain = 0                                                               9.0
# capital-gain = 0, capital-loss = 0                                             9.0
# capital-loss = 0, native-country =  United-States                             Fair
# Workclass =  Private                                                          Fair
#
#                                                                       \
#                                                   score bias against
# subgroup
# capital-loss = 0                                    0.0         Fair
# capital-gain = 0                                    2.0    Non-White
# capital-gain = 0, capital-loss = 0                  2.0    Non-White
# capital-loss = 0, native-country =  United-States   0.0         Fair
# Workclass =  Private                                0.0         Fair
#
#                                                   (Equal Choice for Recourse, 0.7)  \
#                                                                               rank
# subgroup
# capital-loss = 0                                                              Fair
# capital-gain = 0                                                              Fair
# capital-gain = 0, capital-loss = 0                                            Fair
# capital-loss = 0, native-country =  United-States                             Fair
# Workclass =  Private                                                          Fair
#
#                                                    ...  \
#                                                    ...
# subgroup                                           ...
# capital-loss = 0                                   ...
# capital-gain = 0                                   ...
# capital-gain = 0, capital-loss = 0                 ...
# capital-loss = 0, native-country =  United-States  ...
# Workclass =  Private                               ...
#
#                                                   (Equal Cost of Effectiveness(Micro), 0.3)  \
#                                                                                bias against
# subgroup
# capital-loss = 0                                                                       Fair
# capital-gain = 0                                                                  Non-White
# capital-gain = 0, capital-loss = 0                                                Non-White
# capital-loss = 0, native-country =  United-States                                      Fair
# Workclass =  Private                                                                   Fair
#
#                                                   (Equal Cost of Effectiveness(Micro), 0.7)  \
#                                                                                        rank
# subgroup
# capital-loss = 0                                                                       Fair
# capital-gain = 0                                                                       Fair
# capital-gain = 0, capital-loss = 0                                                     Fair
# capital-loss = 0, native-country =  United-States                                      Fair
# Workclass =  Private                                                                   Fair
#
#                                                                       \
#                                                   score bias against
# subgroup
# capital-loss = 0                                    0.0         Fair
# capital-gain = 0                                    0.0         Fair
# capital-gain = 0, capital-loss = 0                  0.0         Fair
# capital-loss = 0, native-country =  United-States   0.0         Fair
# Workclass =  Private                                0.0         Fair
#
#                                                   Equal(Conditional Mean Recourse)  \
#                                                                               rank
# subgroup
# capital-loss = 0                                                            7497.0
# capital-gain = 0                                                            5091.0
# capital-gain = 0, capital-loss = 0                                          5084.0
# capital-loss = 0, native-country =  United-States                           7495.0
# Workclass =  Private                                                          Fair
#
#                                                                           \
#                                                       score bias against
# subgroup
# capital-loss = 0                                   0.000156    Non-White
# capital-gain = 0                                   0.063698    Non-White
# capital-gain = 0, capital-loss = 0                 0.064657    Non-White
# capital-loss = 0, native-country =  United-States  0.000160        White
# Workclass =  Private                               0.000000         Fair
#
#                                                   Fair Effectiveness-Cost Trade-Off  \
#                                                                                rank
# subgroup
# capital-loss = 0                                                             4615.0
# capital-gain = 0                                                             3307.0
# capital-gain = 0, capital-loss = 0                                           3309.0
# capital-loss = 0, native-country =  United-States                            4027.0
# Workclass =  Private                                                         8820.0
#
#
#                                                       score bias against
# subgroup
# capital-loss = 0                                   0.114881    Non-White
# capital-gain = 0                                   0.143342    Non-White
# capital-gain = 0, capital-loss = 0                 0.143281    Non-White
# capital-loss = 0, native-country =  United-States  0.127129    Non-White
# Workclass =  Private                               0.043964    Non-White
#
# [5 rows x 36 columns]

# %%
analysis_df
# Out:
#                                                     Rank = 1 Count  \
# (Equal Cost of Effectiveness(Macro), 0.3)                     1731
# (Equal Cost of Effectiveness(Micro), 0.3)                     1720
# Equal(Conditional Mean Recourse)                              2545
# (Equal Cost of Effectiveness(Macro), 0.7)                      325
# (Equal Cost of Effectiveness(Micro), 0.7)                      325
# (Equal Effectiveness within Budget, 1.150241502...               1
# Equal Effectiveness                                              1
# (Equal Effectiveness within Budget, 21.0)                        1
# Fair Effectiveness-Cost Trade-Off                                2
# (Equal Choice for Recourse, 0.7)                                 2
# (Equal Choice for Recourse, 0.3)                                 1
# (Equal Effectiveness within Budget, 10.07298072...               1
# Total Count                                                   6655
#
#                                                     White bias against Count  \
# (Equal Cost of Effectiveness(Macro), 0.3)                                148
# (Equal Cost of Effectiveness(Micro), 0.3)                                149
# Equal(Conditional Mean Recourse)                                        3892
# (Equal Cost of Effectiveness(Macro), 0.7)                                 58
# (Equal Cost of Effectiveness(Micro), 0.7)                                 58
# (Equal Effectiveness within Budget, 1.150241502...                        54
# Equal Effectiveness                                                    11884
# (Equal Effectiveness within Budget, 21.0)                               2490
# Fair Effectiveness-Cost Trade-Off                                       2272
# (Equal Choice for Recourse, 0.7)                                          73
# (Equal Choice for Recourse, 0.3)                                         215
# (Equal Effectiveness within Budget, 10.07298072...                      2227
# Total Count                                                            23520
#
#                                                     Non-White bias against Count
# (Equal Cost of Effectiveness(Macro), 0.3)                                   2802
# (Equal Cost of Effectiveness(Micro), 0.3)                                   2794
# Equal(Conditional Mean Recourse)                                            9800
# (Equal Cost of Effectiveness(Macro), 0.7)                                    526
# (Equal Cost of Effectiveness(Micro), 0.7)                                    522
# (Equal Effectiveness within Budget, 1.150241502...                           189
# Equal Effectiveness                                                         2512
# (Equal Effectiveness within Budget, 21.0)                                  11744
# Fair Effectiveness-Cost Trade-Off                                          14389
# (Equal Choice for Recourse, 0.7)                                             628
# (Equal Choice for Recourse, 0.3)                                            3718
# (Equal Effectiveness within Budget, 10.07298072...                         10316
# Total Count                                                                59940

# %%
rank_analysis_df
# Out:
#                                                     (Equal Cost of Effectiveness(Micro), 0.3)  \
# (Equal Cost of Effectiveness(Micro), 0.3)                                                 1.0
# Equal Effectiveness                                                                       1.0
# Fair Effectiveness-Cost Trade-Off                                                         1.0
# (Equal Choice for Recourse, 0.7)                                                         43.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                                30.0
# Equal(Conditional Mean Recourse)                                                         42.1
# (Equal Choice for Recourse, 0.3)                                                         18.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                                 1.1
# (Equal Effectiveness within Budget, 1.150241502...                                       43.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                30.0
# (Equal Effectiveness within Budget, 10.07298072...                                       17.0
# (Equal Effectiveness within Budget, 21.0)                                                 1.0
#
#                                                     Equal Effectiveness  \
# (Equal Cost of Effectiveness(Micro), 0.3)                        1909.8
# Equal Effectiveness                                                 1.0
# Fair Effectiveness-Cost Trade-Off                                  13.0
# (Equal Choice for Recourse, 0.7)                                 7602.0
# (Equal Cost of Effectiveness(Macro), 0.7)                        1734.5
# Equal(Conditional Mean Recourse)                                 7404.3
# (Equal Choice for Recourse, 0.3)                                11799.0
# (Equal Cost of Effectiveness(Macro), 0.3)                        1907.8
# (Equal Effectiveness within Budget, 1.150241502...                815.0
# (Equal Cost of Effectiveness(Micro), 0.7)                        1734.5
# (Equal Effectiveness within Budget, 10.07298072...                 14.0
# (Equal Effectiveness within Budget, 21.0)                           1.0
#
#                                                     Fair Effectiveness-Cost Trade-Off  \
# (Equal Cost of Effectiveness(Micro), 0.3)                                      2438.0
# Equal Effectiveness                                                               1.0
# Fair Effectiveness-Cost Trade-Off                                                 1.0
# (Equal Choice for Recourse, 0.7)                                                140.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                      1507.8
# Equal(Conditional Mean Recourse)                                               9040.6
# (Equal Choice for Recourse, 0.3)                                                909.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                      2434.9
# (Equal Effectiveness within Budget, 1.150241502...                             1275.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                      1507.8
# (Equal Effectiveness within Budget, 10.07298072...                               24.0
# (Equal Effectiveness within Budget, 21.0)                                         1.0
#
#                                                     (Equal Choice for Recourse, 0.7)  \
# (Equal Cost of Effectiveness(Micro), 0.3)                                        7.0
# Equal Effectiveness                                                              7.0
# Fair Effectiveness-Cost Trade-Off                                                7.0
# (Equal Choice for Recourse, 0.7)                                                 1.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                        5.8
# Equal(Conditional Mean Recourse)                                                 7.0
# (Equal Choice for Recourse, 0.3)                                                 7.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                        7.0
# (Equal Effectiveness within Budget, 1.150241502...                               6.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                        5.8
# (Equal Effectiveness within Budget, 10.07298072...                               4.0
# (Equal Effectiveness within Budget, 21.0)                                        7.0
#
#                                                     (Equal Cost of Effectiveness(Macro), 0.7)  \
# (Equal Cost of Effectiveness(Micro), 0.3)                                                21.0
# Equal Effectiveness                                                                      21.0
# Fair Effectiveness-Cost Trade-Off                                                        21.0
# (Equal Choice for Recourse, 0.7)                                                          2.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                                 1.0
# Equal(Conditional Mean Recourse)                                                         21.0
# (Equal Choice for Recourse, 0.3)                                                         21.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                                21.0
# (Equal Effectiveness within Budget, 1.150241502...                                        1.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                 1.0
# (Equal Effectiveness within Budget, 10.07298072...                                        1.0
# (Equal Effectiveness within Budget, 21.0)                                                21.0
#
#                                                     Equal(Conditional Mean Recourse)  \
# (Equal Cost of Effectiveness(Micro), 0.3)                                     3386.3
# Equal Effectiveness                                                              1.0
# Fair Effectiveness-Cost Trade-Off                                               24.0
# (Equal Choice for Recourse, 0.7)                                               306.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                     3177.6
# Equal(Conditional Mean Recourse)                                                 1.0
# (Equal Choice for Recourse, 0.3)                                              5897.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                     3379.9
# (Equal Effectiveness within Budget, 1.150241502...                            7540.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                     3177.6
# (Equal Effectiveness within Budget, 10.07298072...                            4607.0
# (Equal Effectiveness within Budget, 21.0)                                        1.0
#
#                                                     (Equal Choice for Recourse, 0.3)  \
# (Equal Cost of Effectiveness(Micro), 0.3)                                        9.3
# Equal Effectiveness                                                             10.0
# Fair Effectiveness-Cost Trade-Off                                                9.0
# (Equal Choice for Recourse, 0.7)                                                10.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                        9.9
# Equal(Conditional Mean Recourse)                                                11.0
# (Equal Choice for Recourse, 0.3)                                                 1.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                        9.3
# (Equal Effectiveness within Budget, 1.150241502...                              11.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                        9.9
# (Equal Effectiveness within Budget, 10.07298072...                               9.0
# (Equal Effectiveness within Budget, 21.0)                                       10.0
#
#                                                     (Equal Cost of Effectiveness(Macro), 0.3)  \
# (Equal Cost of Effectiveness(Micro), 0.3)                                                 1.0
# Equal Effectiveness                                                                       1.0
# Fair Effectiveness-Cost Trade-Off                                                         1.0
# (Equal Choice for Recourse, 0.7)                                                         43.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                                30.1
# Equal(Conditional Mean Recourse)                                                         42.1
# (Equal Choice for Recourse, 0.3)                                                         18.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                                 1.0
# (Equal Effectiveness within Budget, 1.150241502...                                       43.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                30.1
# (Equal Effectiveness within Budget, 10.07298072...                                       17.0
# (Equal Effectiveness within Budget, 21.0)                                                 1.0
#
#                                                     (Equal Effectiveness within Budget, 1.150241502415024)  \
# (Equal Cost of Effectiveness(Micro), 0.3)                                                       222.1
# Equal Effectiveness                                                                             223.0
# Fair Effectiveness-Cost Trade-Off                                                               223.0
# (Equal Choice for Recourse, 0.7)                                                                223.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                                       217.0
# Equal(Conditional Mean Recourse)                                                                223.0
# (Equal Choice for Recourse, 0.3)                                                                223.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                                       222.1
# (Equal Effectiveness within Budget, 1.150241502...                                                1.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                       217.0
# (Equal Effectiveness within Budget, 10.07298072...                                              223.0
# (Equal Effectiveness within Budget, 21.0)                                                       223.0
#
#                                                     (Equal Cost of Effectiveness(Micro), 0.7)  \
# (Equal Cost of Effectiveness(Micro), 0.3)                                                20.0
# Equal Effectiveness                                                                      20.0
# Fair Effectiveness-Cost Trade-Off                                                        20.0
# (Equal Choice for Recourse, 0.7)                                                          2.0
# (Equal Cost of Effectiveness(Macro), 0.7)                                                 1.0
# Equal(Conditional Mean Recourse)                                                         20.0
# (Equal Choice for Recourse, 0.3)                                                         20.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                                20.0
# (Equal Effectiveness within Budget, 1.150241502...                                        1.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                 1.0
# (Equal Effectiveness within Budget, 10.07298072...                                        1.0
# (Equal Effectiveness within Budget, 21.0)                                                20.0
#
#                                                     (Equal Effectiveness within Budget, 10.072980729807298)  \
# (Equal Cost of Effectiveness(Micro), 0.3)                                                      2911.7
# Equal Effectiveness                                                                             107.0
# Fair Effectiveness-Cost Trade-Off                                                               122.0
# (Equal Choice for Recourse, 0.7)                                                                 26.5
# (Equal Cost of Effectiveness(Macro), 0.7)                                                      3227.1
# Equal(Conditional Mean Recourse)                                                               7979.9
# (Equal Choice for Recourse, 0.3)                                                                303.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                                      2902.0
# (Equal Effectiveness within Budget, 1.150241502...                                              478.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                                      3227.1
# (Equal Effectiveness within Budget, 10.07298072...                                                1.0
# (Equal Effectiveness within Budget, 21.0)                                                       107.0
#
#                                                     (Equal Effectiveness within Budget, 21.0)
# (Equal Cost of Effectiveness(Micro), 0.3)                                              2068.7
# Equal Effectiveness                                                                       1.0
# Fair Effectiveness-Cost Trade-Off                                                        12.5
# (Equal Choice for Recourse, 0.7)                                                       3831.5
# (Equal Cost of Effectiveness(Macro), 0.7)                                              1976.2
# Equal(Conditional Mean Recourse)                                                       7380.8
# (Equal Choice for Recourse, 0.3)                                                      11666.0
# (Equal Cost of Effectiveness(Macro), 0.3)                                              2065.5
# (Equal Effectiveness within Budget, 1.150241502...                                      813.0
# (Equal Cost of Effectiveness(Micro), 0.7)                                              1976.2
# (Equal Effectiveness within Budget, 10.07298072...                                       14.0
# (Equal Effectiveness within Budget, 21.0)                                                 1.0

# %%
#top_rank = ranked[(ranked[('mincost-above-th', 0.7)]==1) | (ranked[('number-above-th', 0.7)]==1) |  (ranked['total-effectiveness']==1) | (ranked['total-effectiveness']==1) | (ranked[('eff-within-budget', 10.0)]==1) | (ranked[('eff-within-budget', 18.0)]==1) | (ranked[('eff-within-budget', 5.076880768807688)]==1) | (ranked[('cost-of-effectiveness', 0.7)]==1) | (ranked[('cost-of-effectiveness', 0.3)]==1) | (ranked[('KStest', 'value')]==1)]

# %%
# ranked_indexed = top_rank.set_index([top_rank.index, "subgroup"])
# ranked_fair = ranked_indexed == 'Fair'
# ranked_more_than_2000 = ranked_indexed.mask(ranked_indexed=='Fair') >= 1000
# new_rank = ranked_indexed[ranked_fair.apply(lambda row: row.sum() >=4 , axis=1) | ranked_more_than_2000.apply(lambda row : row.sum() >= 6,axis=1)]
# new_rank.head()

# %%
# sgs = [
#     ranked.iloc[9841].subgroup,
# ]

# rules_sgs_atomic = {ifc: rules_with_atomic_correctness[ifc] for ifc in sgs}
# rules_sgs_cumulative = {ifc: rules_with_cumulative_correctness[ifc] for ifc in sgs}

# %%
# df.iloc[4228].to_frame().T

# %%
# top_rules, subgroup_costs = facts.select_rules_subset(
#     rules_sgs_atomic,
#     metric="min-above-thr",
#     sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
#     cor_threshold=0.7,
#     filter_sequence = [
#         # "remove-contained",
#         "remove-below-thr",        
#         #"remove-fair-rules", 
#         "keep-only-min-change"
#     ],
#     params=params
# )

# print_recourse_report(
#     top_rules,
#     subgroup_costs=subgroup_costs,
#     show_subgroup_costs=True
# )

# %%
# top_rules, subgroup_costs = facts.select_rules_subset_cumulative(
#     rules_sgs_cumulative,
#     metric="max-upto-cost",
#     sort_strategy="generic-sorting-ignore-exists-subgroup-empty",
#     top_count=top_count,
#     cost_threshold = 10,
#     filter_sequence = [
#         # "remove-contained",
#         # "remove-fair-rules",
#         "keep-cheap-rules-above-thr-cor",
#         # "keep-only-min-change",
        
#     ],
#     params=params
# )

# print_recourse_report_cumulative(
#     top_rules,
#     subgroup_costs=subgroup_costs,
#     show_subgroup_costs=True,
#     show_then_costs=True,
#     correctness_metric=True
# )
